# %%
import yfinance as yf
import pandas as pd
import numpy as np
from ta.momentum import RSIIndicator, StochasticOscillator
from ta.trend import MACD
from tqdm import tqdm

# Ticker symbols for the 12 stocks
tickers = [
    "HSBA.L", "BARC.L", "LLOY.L", "STAN.L", "NWG.L",
    "PRU.L", "LGEN.L", "AV.L", "PHNX.L", "LSEG.L",
    "MNG.L", "HL.L"
]

# Download historical OHLCV from 2014-01-01 to 2023-12-31
def download_data(ticker):
    data = yf.download(ticker, start="2014-01-01", end="2023-12-31")
    data = data.dropna()
    return data

stock_data = {ticker: download_data(ticker) for ticker in tqdm(tickers)}
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# 100%|██████████| 12/12 [00:05<00:00,  2.01it/s]

# %%
def compute_features(df):
    df = df.copy()

    # Ensure Close, High, Low are Series (1D)
    close = df["Close"].squeeze()
    high = df["High"].squeeze()
    low = df["Low"].squeeze()
    volume = df["Volume"].squeeze()

    print(f"Close dtype: {type(close)}, shape: {close.shape}")

    # Daily return
    df["Return"] = close.pct_change()

    # 30-day rolling volatility (target)
    df["Volatility"] = df["Return"].rolling(window=30).std()

    # RSI (14 days)
    df["RSI"] = RSIIndicator(close=close, window=14).rsi()

    # Momentum (5 days)
    df["MOM"] = close - close.shift(5)

    # OBV
    df["OBV"] = (np.sign(close.diff()) * volume).fillna(0).cumsum()

    # MACD
    macd = MACD(close=close, window_slow=26, window_fast=12, window_sign=9)
    df["MACD_LINE"] = macd.macd()
    df["MACD_SIGNAL"] = macd.macd_signal()
    df["MACD_HIST"] = macd.macd_diff()

    # Stochastic Oscillator
    stoch = StochasticOscillator(high=high, low=low, close=close, window=14, smooth_window=3)
    df["STO_K"] = stoch.stoch()           # formerly %K
    df["STO_D"] = stoch.stoch_signal()    # formerly %D

    # Lagged volatilities (t-1 to t-6)
    for i in range(1, 7):
        df[f"Vol_t_{i}"] = df["Volatility"].shift(i)

    # Volatility t+1 (our target)
    df["Vol_target"] = df["Volatility"].shift(-1)

    # Drop rows with NaNs
    df = df.dropna()

    return df

# %%
import os
import pickle

feature_data = {}
for ticker in tqdm(tickers):
    feature_data[ticker] = compute_features(stock_data[ticker])

feature_data_path = "uk_feature_data.pkl"

if os.path.exists(feature_data_path):
    print("📦 Loading saved feature data from uk_feature_data.pkl...")
    with open(feature_data_path, "rb") as f:
        feature_data = pickle.load(f)
else:
    print("⚙️ Computing feature data...")
    feature_data = {ticker: compute_features(stock_data[ticker]) for ticker in tqdm(tickers)}
    with open(feature_data_path, "wb") as f:
        pickle.dump(feature_data, f)
    print("💾 Saved feature data to uk_feature_data.pkl")
# Out:
# 100%|██████████| 12/12 [00:00<00:00, 78.28it/s]
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2525,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2525,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2525,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2525,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2525,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2525,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2525,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2525,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2525,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2525,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (1058,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2525,)
# ⚙️ Computing feature data...
#   0%|          | 0/12 [00:00<?, ?it/s]
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2525,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2525,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2525,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2525,)
# 100%|██████████| 12/12 [00:00<00:00, 80.03it/s]
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2525,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2525,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2525,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2525,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2525,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2525,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (1058,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2525,)
# 💾 Saved feature data to uk_feature_data.pkl

# %%
from arch import arch_model
import warnings

def add_garch_predictions(df, ticker=None, verbose=True):
    df = df.copy()
    returns = df["Return"].dropna().values
    preds = []
    window_size = 500
    scale_factor = 100  # recommended by arch package

    if verbose:
        print(f"\n🔍 GARCH modeling for {ticker} — total points: {len(returns)}")

    for i in range(window_size, len(returns)):
        train_window = returns[i-window_size:i] * scale_factor  # rescale

        try:
            with warnings.catch_warnings():
                warnings.simplefilter("ignore")
                model = arch_model(train_window, vol='Garch', p=1, q=1, dist='normal', rescale=False)
                model_fit = model.fit(disp="off")
                forecast = model_fit.forecast(horizon=1)
                pred_vol_scaled = np.sqrt(forecast.variance.values[-1][0])
                pred_vol = pred_vol_scaled / scale_factor  # unscale
        except Exception as e:
            if verbose:
                print(f"⚠️ Failed at i={i} — {e}")
            pred_vol = np.nan

        preds.append(pred_vol)

        if verbose and i % 250 == 0:
            print(f"  → Index {i} | Pred Vol (unscaled): {pred_vol:.5f}")

    full_preds = [np.nan] * window_size + preds
    df["GARCH_pred"] = full_preds

    before = len(df)
    df = df.dropna()
    after = len(df)

    if verbose:
        print(f"✅ Done {ticker} | Rows dropped: {before - after} | Final: {after} rows")

    return df

# %%
# === Try loading precomputed garch_data from disk ===
garch_data_path = "uk_garch_data.pkl"

if os.path.exists(garch_data_path):
    print("📦 Loading saved GARCH data from uk_garch_data.pkl...")
    with open(garch_data_path, "rb") as f:
        garch_data = pickle.load(f)
    print("✅ Loaded GARCH data successfully!")
else:
    print("⚙️ Computing GARCH data from scratch...")
    garch_data = {}
    for ticker in tickers:
        print(f"\n====================== {ticker} ======================")
        garch_data[ticker] = add_garch_predictions(feature_data[ticker], ticker=ticker)

    # Save to disk
    with open(garch_data_path, "wb") as f:
        pickle.dump(garch_data, f)
    print("💾 Saved GARCH data to uk_garch_data.pkl")
# Out:
# ⚙️ Computing GARCH data from scratch...
#
# ====================== HSBA.L ======================
#
# 🔍 GARCH modeling for HSBA.L — total points: 2488
#   → Index 500 | Pred Vol (unscaled): 0.02942
#   → Index 750 | Pred Vol (unscaled): 0.01212
#   → Index 1000 | Pred Vol (unscaled): 0.00856
#   → Index 1250 | Pred Vol (unscaled): 0.01115
#   → Index 1500 | Pred Vol (unscaled): 0.01169
#   → Index 1750 | Pred Vol (unscaled): 0.02449
#   → Index 2000 | Pred Vol (unscaled): 0.01618
#   → Index 2250 | Pred Vol (unscaled): 0.01594
# ✅ Done HSBA.L | Rows dropped: 500 | Final: 1988 rows
#
# ====================== BARC.L ======================
#
# 🔍 GARCH modeling for BARC.L — total points: 2488
#   → Index 500 | Pred Vol (unscaled): 0.03619
#   → Index 750 | Pred Vol (unscaled): 0.01737
#   → Index 1000 | Pred Vol (unscaled): 0.01589
#   → Index 1250 | Pred Vol (unscaled): 0.01405
#   → Index 1500 | Pred Vol (unscaled): 0.01421
#   → Index 1750 | Pred Vol (unscaled): 0.02405
#   → Index 2000 | Pred Vol (unscaled): 0.02061
#   → Index 2250 | Pred Vol (unscaled): 0.01716
# ✅ Done BARC.L | Rows dropped: 500 | Final: 1988 rows
#
# ====================== LLOY.L ======================
#
# 🔍 GARCH modeling for LLOY.L — total points: 2488
#   → Index 500 | Pred Vol (unscaled): 0.02405
#   → Index 750 | Pred Vol (unscaled): 0.01309
#   → Index 1000 | Pred Vol (unscaled): 0.01065
#   → Index 1250 | Pred Vol (unscaled): 0.01426
#   → Index 1500 | Pred Vol (unscaled): 0.01345
#   → Index 1750 | Pred Vol (unscaled): 0.01621
#   → Index 2000 | Pred Vol (unscaled): 0.01860
#   → Index 2250 | Pred Vol (unscaled): 0.01582
# ✅ Done LLOY.L | Rows dropped: 500 | Final: 1988 rows
#
# ====================== STAN.L ======================
#
# 🔍 GARCH modeling for STAN.L — total points: 2488
#   → Index 500 | Pred Vol (unscaled): 0.06251
#   → Index 750 | Pred Vol (unscaled): 0.01645
#   → Index 1000 | Pred Vol (unscaled): 0.01375
#   → Index 1250 | Pred Vol (unscaled): 0.01482
#   → Index 1500 | Pred Vol (unscaled): 0.01404
#   → Index 1750 | Pred Vol (unscaled): 0.02421
#   → Index 2000 | Pred Vol (unscaled): 0.02099
#   → Index 2250 | Pred Vol (unscaled): 0.01875
# ✅ Done STAN.L | Rows dropped: 500 | Final: 1988 rows
#
# ====================== NWG.L ======================
#
# 🔍 GARCH modeling for NWG.L — total points: 2488
#   → Index 500 | Pred Vol (unscaled): 0.04558
#   → Index 750 | Pred Vol (unscaled): 0.01887
#   → Index 1000 | Pred Vol (unscaled): 0.01520
#   → Index 1250 | Pred Vol (unscaled): 0.01544
#   → Index 1500 | Pred Vol (unscaled): 0.01610
#   → Index 1750 | Pred Vol (unscaled): 0.02127
#   → Index 2000 | Pred Vol (unscaled): 0.01653
#   → Index 2250 | Pred Vol (unscaled): 0.01706
# ✅ Done NWG.L | Rows dropped: 500 | Final: 1988 rows
#
# ====================== PRU.L ======================
#
# 🔍 GARCH modeling for PRU.L — total points: 2488
#   → Index 500 | Pred Vol (unscaled): 0.04523
#   → Index 750 | Pred Vol (unscaled): 0.01616
#   → Index 1000 | Pred Vol (unscaled): 0.01259
#   → Index 1250 | Pred Vol (unscaled): 0.01159
#   → Index 1500 | Pred Vol (unscaled): 0.01792
#   → Index 1750 | Pred Vol (unscaled): 0.01808
#   → Index 2000 | Pred Vol (unscaled): 0.01932
#   → Index 2250 | Pred Vol (unscaled): 0.02102
# ✅ Done PRU.L | Rows dropped: 500 | Final: 1988 rows
#
# ====================== LGEN.L ======================
#
# 🔍 GARCH modeling for LGEN.L — total points: 2488
#   → Index 500 | Pred Vol (unscaled): 0.02940
#   → Index 750 | Pred Vol (unscaled): 0.01514
#   → Index 1000 | Pred Vol (unscaled): 0.01023
#   → Index 1250 | Pred Vol (unscaled): 0.01334
#   → Index 1500 | Pred Vol (unscaled): 0.01488
#   → Index 1750 | Pred Vol (unscaled): 0.01793
#   → Index 2000 | Pred Vol (unscaled): 0.01603
#   → Index 2250 | Pred Vol (unscaled): 0.01538
# ✅ Done LGEN.L | Rows dropped: 500 | Final: 1988 rows
#
# ====================== AV.L ======================
#
# 🔍 GARCH modeling for AV.L — total points: 2488
#   → Index 500 | Pred Vol (unscaled): 0.02594
#   → Index 750 | Pred Vol (unscaled): 0.01441
#   → Index 1000 | Pred Vol (unscaled): 0.01052
#   → Index 1250 | Pred Vol (unscaled): 0.01318
#   → Index 1500 | Pred Vol (unscaled): 0.01299
#   → Index 1750 | Pred Vol (unscaled): 0.01429
#   → Index 2000 | Pred Vol (unscaled): 0.01384
#   → Index 2250 | Pred Vol (unscaled): 0.01429
# ✅ Done AV.L | Rows dropped: 500 | Final: 1988 rows
#
# ====================== PHNX.L ======================
#
# 🔍 GARCH modeling for PHNX.L — total points: 2488
#   → Index 500 | Pred Vol (unscaled): 0.01616
#   → Index 750 | Pred Vol (unscaled): 0.01115
#   → Index 1000 | Pred Vol (unscaled): 0.00936
#   → Index 1250 | Pred Vol (unscaled): 0.01117
#   → Index 1500 | Pred Vol (unscaled): 0.01374
#   → Index 1750 | Pred Vol (unscaled): 0.01275
#   → Index 2000 | Pred Vol (unscaled): 0.01397
#   → Index 2250 | Pred Vol (unscaled): 0.01224
# ✅ Done PHNX.L | Rows dropped: 500 | Final: 1988 rows
#
# ====================== LSEG.L ======================
#
# 🔍 GARCH modeling for LSEG.L — total points: 2488
#   → Index 500 | Pred Vol (unscaled): 0.03387
#   → Index 750 | Pred Vol (unscaled): 0.01441
#   → Index 1000 | Pred Vol (unscaled): 0.01506
#   → Index 1250 | Pred Vol (unscaled): 0.01180
#   → Index 1500 | Pred Vol (unscaled): 0.01513
#   → Index 1750 | Pred Vol (unscaled): 0.01621
#   → Index 2000 | Pred Vol (unscaled): 0.01604
#   → Index 2250 | Pred Vol (unscaled): 0.01675
# ✅ Done LSEG.L | Rows dropped: 500 | Final: 1988 rows
#
# ====================== MNG.L ======================
#
# 🔍 GARCH modeling for MNG.L — total points: 1021
#   → Index 500 | Pred Vol (unscaled): 0.02450
#   → Index 750 | Pred Vol (unscaled): 0.01608
#   → Index 1000 | Pred Vol (unscaled): 0.01446
# ✅ Done MNG.L | Rows dropped: 500 | Final: 521 rows
#
# ====================== HL.L ======================
#
# 🔍 GARCH modeling for HL.L — total points: 2488
#   → Index 500 | Pred Vol (unscaled): 0.01999
#   → Index 750 | Pred Vol (unscaled): 0.01679
#   → Index 1000 | Pred Vol (unscaled): 0.01339
#   → Index 1250 | Pred Vol (unscaled): 0.01992
#   → Index 1500 | Pred Vol (unscaled): 0.02332
#   → Index 1750 | Pred Vol (unscaled): 0.02100
#   → Index 2000 | Pred Vol (unscaled): 0.01533
#   → Index 2250 | Pred Vol (unscaled): 0.01950
# ✅ Done HL.L | Rows dropped: 500 | Final: 1988 rows
# 💾 Saved GARCH data to uk_garch_data.pkl

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
import numpy as np
import warnings
warnings.filterwarnings("ignore")

def evaluate(y_true, y_pred):
    return {
        "R2": r2_score(y_true, y_pred),
        "RMSE": mean_squared_error(y_true, y_pred, squared=False),
        "MSE": mean_squared_error(y_true, y_pred),
        "MAE": mean_absolute_error(y_true, y_pred),
    }

def train_ml_models_baseline(df, ticker="TICKER"):
    print(f"\n📈 Training ML models for {ticker}...")

    # Feature and target selection
    features = [
        'RSI', 'MOM', 'OBV', 'MACD_LINE', 'MACD_SIGNAL', 'MACD_HIST',
        'STO_K', 'STO_D',
        'Vol_t_1', 'Vol_t_2', 'Vol_t_3', 'Vol_t_4', 'Vol_t_5', 'Vol_t_6'
    ]

    X = df[features].copy()
    # Sanitize column names just in case LightGBM is sensitive
    X.columns = [str(col).replace("-", "_").replace("%", "PCT").replace(".", "_DOT_") for col in X.columns]

    y = df["Vol_target"]

    # Static train-test split (same as paper: 2014–2020 train, 2021–2023 test)
    split_idx = int(len(df) * 0.7)
    X_train, X_test = X.iloc[:split_idx], X.iloc[split_idx:]
    y_train, y_test = y.iloc[:split_idx], y.iloc[split_idx:]

    models = {
        "KNN": KNeighborsRegressor(),
        "AdaBoost": AdaBoostRegressor(),
        "CatBoost": CatBoostRegressor(verbose=0),
        #"LightGBM": LGBMRegressor(),
        "XGBoost": XGBRegressor(verbosity=0),
        "RandomForest": RandomForestRegressor()
    }

    results = {}

    for name, model in models.items():
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        metrics = evaluate(y_test, y_pred)
        results[name] = metrics
        print(f"✅ {name} — R²: {metrics['R2']:.4f}, RMSE: {metrics['RMSE']:.4f}, MAE: {metrics['MAE']:.4f}")

    return results
# Out:
# /shared/home/ads066/.local/lib/python3.11/site-packages/xgboost/core.py:377: FutureWarning: Your system has an old version of glibc (< 2.28). We will stop supporting Linux distros with glibc older than 2.28 after **May 31, 2025**. Please upgrade to a recent Linux distro (with glibc >= 2.28) to use future versions of XGBoost.
# Note: You have installed the 'manylinux2014' variant of XGBoost. Certain features such as GPU algorithms or federated learning are not available. To use these features, please upgrade to a recent Linux distro with glibc 2.28+, and install the 'manylinux_2_28' variant.
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

def evaluate(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    return {
        "R2": r2_score(y_true, y_pred),
        "RMSE": np.sqrt(mse),
        "MSE": mse,
        "MAE": mean_absolute_error(y_true, y_pred),
    }

def train_all_stocks_ml_baseline(garch_data_dict, results_path="uk_ml_baseline_results.csv"):
    # Check if results already exist
    if os.path.exists(results_path):
        print(f"📦 Loading existing results from {results_path}...")
        return pd.read_csv(results_path)

    final_results = []

    for ticker, df in garch_data_dict.items():
        print(f"\n================= {ticker} =================")
        results = train_ml_models_baseline(df, ticker=ticker)

        for model_name, metrics in results.items():
            final_results.append({
                "Stock": ticker,
                "Model": model_name,
                "R2": round(metrics["R2"], 4),
                "RMSE": round(metrics["RMSE"], 4),
                "MSE": round(metrics["MSE"], 6),
                "MAE": round(metrics["MAE"], 4),
            })

    # Save results
    results_df = pd.DataFrame(final_results)
    results_df.to_csv(results_path, index=False)
    print(f"💾 Saved results to {results_path}")

    return results_df

# Run training or load existing results
ml_all_results = train_all_stocks_ml_baseline(garch_data)
ml_all_results_sorted = ml_all_results.sort_values(by="R2", ascending=False)
display(ml_all_results_sorted)
# Out:
# ================= HSBA.L =================
#
# 📈 Training ML models for HSBA.L...
# ✅ KNN — R²: -1.9733, RMSE: 0.0078, MAE: 0.0065
# ✅ AdaBoost — R²: 0.8309, RMSE: 0.0018, MAE: 0.0014
# ✅ CatBoost — R²: 0.9031, RMSE: 0.0014, MAE: 0.0010
# ✅ XGBoost — R²: 0.8868, RMSE: 0.0015, MAE: 0.0010
# ✅ RandomForest — R²: 0.9020, RMSE: 0.0014, MAE: 0.0010
#
# ================= BARC.L =================
#
# 📈 Training ML models for BARC.L...
# ✅ KNN — R²: -6.4560, RMSE: 0.0151, MAE: 0.0124
# ✅ AdaBoost — R²: 0.8268, RMSE: 0.0023, MAE: 0.0017
# ✅ CatBoost — R²: 0.8365, RMSE: 0.0022, MAE: 0.0017
# ✅ XGBoost — R²: 0.8610, RMSE: 0.0021, MAE: 0.0015
# ✅ RandomForest — R²: 0.9131, RMSE: 0.0016, MAE: 0.0011
#
# ================= LLOY.L =================
#
# 📈 Training ML models for LLOY.L...
# ✅ KNN — R²: -7.1010, RMSE: 0.0171, MAE: 0.0144
# ✅ AdaBoost — R²: 0.8575, RMSE: 0.0023, MAE: 0.0019
# ✅ CatBoost — R²: 0.9306, RMSE: 0.0016, MAE: 0.0011
# ✅ XGBoost — R²: 0.9244, RMSE: 0.0016, MAE: 0.0011
# ✅ RandomForest — R²: 0.9343, RMSE: 0.0015, MAE: 0.0010
#
# ================= STAN.L =================
#
# 📈 Training ML models for STAN.L...
# ✅ KNN — R²: -0.8655, RMSE: 0.0095, MAE: 0.0073
# ✅ AdaBoost — R²: 0.7732, RMSE: 0.0033, MAE: 0.0023
# ✅ CatBoost — R²: 0.8489, RMSE: 0.0027, MAE: 0.0017
# ✅ XGBoost — R²: 0.8369, RMSE: 0.0028, MAE: 0.0018
# ✅ RandomForest — R²: 0.7956, RMSE: 0.0032, MAE: 0.0020
#
# ================= NWG.L =================
#
# 📈 Training ML models for NWG.L...
# ✅ KNN — R²: -1.7518, RMSE: 0.0089, MAE: 0.0071
# ✅ AdaBoost — R²: 0.8310, RMSE: 0.0022, MAE: 0.0018
# ✅ CatBoost — R²: 0.9149, RMSE: 0.0016, MAE: 0.0010
# ✅ XGBoost — R²: 0.9006, RMSE: 0.0017, MAE: 0.0011
# ✅ RandomForest — R²: 0.8835, RMSE: 0.0018, MAE: 0.0011
#
# ================= PRU.L =================
#
# 📈 Training ML models for PRU.L...
# ✅ KNN — R²: -1.0800, RMSE: 0.0088, MAE: 0.0070
# ✅ AdaBoost — R²: 0.8293, RMSE: 0.0025, MAE: 0.0019
# ✅ CatBoost — R²: 0.9009, RMSE: 0.0019, MAE: 0.0013
# ✅ XGBoost — R²: 0.8405, RMSE: 0.0025, MAE: 0.0017
# ✅ RandomForest — R²: 0.9021, RMSE: 0.0019, MAE: 0.0013
#
# ================= LGEN.L =================
#
# 📈 Training ML models for LGEN.L...
# ✅ KNN — R²: -15.4235, RMSE: 0.0210, MAE: 0.0148
# ✅ AdaBoost — R²: 0.7361, RMSE: 0.0027, MAE: 0.0023
# ✅ CatBoost — R²: 0.9399, RMSE: 0.0013, MAE: 0.0009
# ✅ XGBoost — R²: 0.9454, RMSE: 0.0012, MAE: 0.0008
# ✅ RandomForest — R²: 0.9355, RMSE: 0.0013, MAE: 0.0009
#
# ================= AV.L =================
#
# 📈 Training ML models for AV.L...
# ✅ KNN — R²: -1.8193, RMSE: 0.0090, MAE: 0.0068
# ✅ AdaBoost — R²: 0.8386, RMSE: 0.0022, MAE: 0.0015
# ✅ CatBoost — R²: 0.8912, RMSE: 0.0018, MAE: 0.0012
# ✅ XGBoost — R²: 0.7807, RMSE: 0.0025, MAE: 0.0015
# ✅ RandomForest — R²: 0.9089, RMSE: 0.0016, MAE: 0.0010
#
# ================= PHNX.L =================
#
# 📈 Training ML models for PHNX.L...
# ✅ KNN — R²: -2.0487, RMSE: 0.0067, MAE: 0.0049
# ✅ AdaBoost — R²: 0.7246, RMSE: 0.0020, MAE: 0.0016
# ✅ CatBoost — R²: 0.9180, RMSE: 0.0011, MAE: 0.0008
# ✅ XGBoost — R²: 0.8552, RMSE: 0.0015, MAE: 0.0010
# ✅ RandomForest — R²: 0.8775, RMSE: 0.0013, MAE: 0.0009
#
# ================= LSEG.L =================
#
# 📈 Training ML models for LSEG.L...
# ✅ KNN — R²: -0.6699, RMSE: 0.0066, MAE: 0.0057
# ✅ AdaBoost — R²: 0.6697, RMSE: 0.0029, MAE: 0.0025
# ✅ CatBoost — R²: 0.8426, RMSE: 0.0020, MAE: 0.0016
# ✅ XGBoost — R²: 0.6715, RMSE: 0.0029, MAE: 0.0020
# ✅ RandomForest — R²: 0.8953, RMSE: 0.0016, MAE: 0.0012
#
# ================= MNG.L =================
#
# 📈 Training ML models for MNG.L...
# ✅ KNN — R²: -12.3093, RMSE: 0.0061, MAE: 0.0054
# ✅ AdaBoost — R²: -0.0432, RMSE: 0.0017, MAE: 0.0013
# ✅ CatBoost — R²: -0.5855, RMSE: 0.0021, MAE: 0.0016
# ✅ XGBoost — R²: -1.4303, RMSE: 0.0026, MAE: 0.0020
# ✅ RandomForest — R²: -0.4215, RMSE: 0.0020, MAE: 0.0014
#
# ================= HL.L =================
#
# 📈 Training ML models for HL.L...
# ✅ KNN — R²: -0.2050, RMSE: 0.0072, MAE: 0.0055
# ✅ AdaBoost — R²: 0.7749, RMSE: 0.0031, MAE: 0.0022
# ✅ CatBoost — R²: 0.8758, RMSE: 0.0023, MAE: 0.0016
# ✅ XGBoost — R²: 0.8656, RMSE: 0.0024, MAE: 0.0015
# ✅ RandomForest — R²: 0.8727, RMSE: 0.0023, MAE: 0.0014
# 💾 Saved results to uk_ml_baseline_results.csv
#      Stock         Model       R2    RMSE       MSE     MAE
# 33  LGEN.L       XGBoost   0.9454  0.0012  0.000001  0.0008
# 32  LGEN.L      CatBoost   0.9399  0.0013  0.000002  0.0009
# 34  LGEN.L  RandomForest   0.9355  0.0013  0.000002  0.0009
# 14  LLOY.L  RandomForest   0.9343  0.0015  0.000002  0.0010
# 12  LLOY.L      CatBoost   0.9306  0.0016  0.000002  0.0011
# 13  LLOY.L       XGBoost   0.9244  0.0016  0.000003  0.0011
# 42  PHNX.L      CatBoost   0.9180  0.0011  0.000001  0.0008
# 22   NWG.L      CatBoost   0.9149  0.0016  0.000002  0.0010
# 9   BARC.L  RandomForest   0.9131  0.0016  0.000003  0.0011
# 39    AV.L  RandomForest   0.9089  0.0016  0.000003  0.0010
# 2   HSBA.L      CatBoost   0.9031  0.0014  0.000002  0.0010
# 29   PRU.L  RandomForest   0.9021  0.0019  0.000004  0.0013
# 4   HSBA.L  RandomForest   0.9020  0.0014  0.000002  0.0010
# 27   PRU.L      CatBoost   0.9009  0.0019  0.000004  0.0013
# 23   NWG.L       XGBoost   0.9006  0.0017  0.000003  0.0011
# 49  LSEG.L  RandomForest   0.8953  0.0016  0.000003  0.0012
# 37    AV.L      CatBoost   0.8912  0.0018  0.000003  0.0012
# 3   HSBA.L       XGBoost   0.8868  0.0015  0.000002  0.0010
# 24   NWG.L  RandomForest   0.8835  0.0018  0.000003  0.0011
# 44  PHNX.L  RandomForest   0.8775  0.0013  0.000002  0.0009
# 57    HL.L      CatBoost   0.8758  0.0023  0.000005  0.0016
# 59    HL.L  RandomForest   0.8727  0.0023  0.000005  0.0014
# 58    HL.L       XGBoost   0.8656  0.0024  0.000006  0.0015
# 8   BARC.L       XGBoost   0.8610  0.0021  0.000004  0.0015
# 11  LLOY.L      AdaBoost   0.8575  0.0023  0.000005  0.0019
# 43  PHNX.L       XGBoost   0.8552  0.0015  0.000002  0.0010
# 17  STAN.L      CatBoost   0.8489  0.0027  0.000007  0.0017
# 47  LSEG.L      CatBoost   0.8426  0.0020  0.000004  0.0016
# 28   PRU.L       XGBoost   0.8405  0.0025  0.000006  0.0017
# 36    AV.L      AdaBoost   0.8386  0.0022  0.000005  0.0015
# 18  STAN.L       XGBoost   0.8369  0.0028  0.000008  0.0018
# 7   BARC.L      CatBoost   0.8365  0.0022  0.000005  0.0017
# 21   NWG.L      AdaBoost   0.8310  0.0022  0.000005  0.0018
# 1   HSBA.L      AdaBoost   0.8309  0.0018  0.000003  0.0014
# 26   PRU.L      AdaBoost   0.8293  0.0025  0.000006  0.0019
# 6   BARC.L      AdaBoost   0.8268  0.0023  0.000005  0.0017
# 19  STAN.L  RandomForest   0.7956  0.0032  0.000010  0.0020
# 38    AV.L       XGBoost   0.7807  0.0025  0.000006  0.0015
# 56    HL.L      AdaBoost   0.7749  0.0031  0.000010  0.0022
# 16  STAN.L      AdaBoost   0.7732  0.0033  0.000011  0.0023
# 31  LGEN.L      AdaBoost   0.7361  0.0027  0.000007  0.0023
# 41  PHNX.L      AdaBoost   0.7246  0.0020  0.000004  0.0016
# 48  LSEG.L       XGBoost   0.6715  0.0029  0.000009  0.0020
# 46  LSEG.L      AdaBoost   0.6697  0.0029  0.000009  0.0025
# 51   MNG.L      AdaBoost  -0.0432  0.0017  0.000003  0.0013
# 55    HL.L           KNN  -0.2050  0.0072  0.000052  0.0055
# 54   MNG.L  RandomForest  -0.4215  0.0020  0.000004  0.0014
# 52   MNG.L      CatBoost  -0.5855  0.0021  0.000005  0.0016
# 45  LSEG.L           KNN  -0.6699  0.0066  0.000043  0.0057
# 15  STAN.L           KNN  -0.8655  0.0095  0.000091  0.0073
# 25   PRU.L           KNN  -1.0800  0.0088  0.000078  0.0070
# 53   MNG.L       XGBoost  -1.4303  0.0026  0.000007  0.0020
# 20   NWG.L           KNN  -1.7518  0.0089  0.000079  0.0071
# 35    AV.L           KNN  -1.8193  0.0090  0.000081  0.0068
# 0   HSBA.L           KNN  -1.9733  0.0078  0.000060  0.0065
# 40  PHNX.L           KNN  -2.0487  0.0067  0.000045  0.0049
# 5   BARC.L           KNN  -6.4560  0.0151  0.000227  0.0124
# 10  LLOY.L           KNN  -7.1010  0.0171  0.000292  0.0144
# 50   MNG.L           KNN -12.3093  0.0061  0.000038  0.0054
# 30  LGEN.L           KNN -15.4235  0.0210  0.000443  0.0148

# %%
from arch import arch_model
import numpy as np
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

def evaluate_series(y_true, y_pred):
    return {
        "R2": r2_score(y_true, y_pred),
        "RMSE": mean_squared_error(y_true, y_pred, squared=False),
        "MSE": mean_squared_error(y_true, y_pred),
        "MAE": mean_absolute_error(y_true, y_pred),
    }

def forecast_volatility_arch(df, model_type="GARCH", ticker="TICKER", verbose=True):
    df = df.copy()

    # Flatten columns if MultiIndex
    if isinstance(df.columns, pd.MultiIndex):
        df.columns = ['_'.join([str(i) for i in col if i]) for col in df.columns]

    if "Vol_target" not in df.columns or "Return" not in df.columns:
        raise KeyError(f"Missing 'Vol_target' or 'Return' in {ticker}")

    returns = df["Return"].dropna().values
    preds = []
    window_size = 500
    scale_factor = 100  # fix for scale warning

    if verbose:
        print(f"\n🔮 Running {model_type} for {ticker}...")

    for i in range(window_size, len(returns)):
        train_window = returns[i-window_size:i] * scale_factor

        try:
            if model_type == "GARCH":
                model = arch_model(train_window, vol='GARCH', p=1, q=1, dist='normal', rescale=False)
            elif model_type == "GJR":
                model = arch_model(train_window, vol='GARCH', p=1, o=1, q=1, dist='normal', rescale=False)
            elif model_type == "EGARCH":
                model = arch_model(train_window, vol='EGARCH', p=1, q=1, dist='normal', rescale=False)
            else:
                raise ValueError("Invalid model_type")

            model_fit = model.fit(disp="off")
            forecast = model_fit.forecast(horizon=1)
            pred_vol = np.sqrt(forecast.variance.values[-1][0]) / scale_factor

        except Exception as e:
            if verbose:
                print(f"⚠️ {model_type} failed at index {i}: {e}")
            pred_vol = np.nan

        preds.append(pred_vol)

        if verbose and i % 250 == 0:
            print(f"  → {model_type} | index {i} | vol: {pred_vol:.5f}")

    df[f"{model_type}_pred"] = [np.nan] * window_size + preds
    df = df.dropna(subset=["Vol_target", f"{model_type}_pred"])

    metrics = evaluate_series(df["Vol_target"], df[f"{model_type}_pred"])
    if verbose:
        print(f"✅ {model_type} for {ticker} — R²: {metrics['R2']:.4f}, RMSE: {metrics['RMSE']:.4f}, MAE: {metrics['MAE']:.4f}")

    return df, metrics

# %%
import os
import pandas as pd

def evaluate_all_series_models(garch_data_dict, results_path="uk_ts_model_results.csv"):
    # If results already exist, load them
    if os.path.exists(results_path):
        print(f"📦 Loading saved time series results from {results_path}...")
        return pd.read_csv(results_path)

    results = []

    for ticker, df in garch_data_dict.items():
        for model_type in ["GARCH", "GJR", "EGARCH"]:
            print(f"\n================= {ticker} - {model_type} =================")
            try:
                _, metrics = forecast_volatility_arch(df, model_type=model_type, ticker=ticker, verbose=True)
                results.append({
                    "Stock": ticker,
                    "Model": model_type,
                    "R2": round(metrics["R2"], 4),
                    "RMSE": round(metrics["RMSE"], 4),
                    "MSE": round(metrics["MSE"], 6),
                    "MAE": round(metrics["MAE"], 4),
                })
            except Exception as e:
                print(f"⚠️ Skipping {ticker} - {model_type}: {e}")

    df_results = pd.DataFrame(results)
    df_results.to_csv(results_path, index=False)
    print(f"💾 Saved time series model results to {results_path}")

    return df_results

ts_model_results = evaluate_all_series_models(garch_data)
ts_model_results_sorted = ts_model_results.sort_values(by="R2", ascending=False)
display(ts_model_results_sorted)
# Out:
# ================= HSBA.L - GARCH =================
#
# 🔮 Running GARCH for HSBA.L...
#   → GARCH | index 500 | vol: 0.00856
#   → GARCH | index 750 | vol: 0.01115
#   → GARCH | index 1000 | vol: 0.01169
#   → GARCH | index 1250 | vol: 0.02449
#   → GARCH | index 1500 | vol: 0.01618
#   → GARCH | index 1750 | vol: 0.01594
# ✅ GARCH for HSBA.L — R²: 0.8111, RMSE: 0.0028, MAE: 0.0022
#
# ================= HSBA.L - GJR =================
#
# 🔮 Running GJR for HSBA.L...
#   → GJR | index 500 | vol: 0.00856
#   → GJR | index 750 | vol: 0.01115
#   → GJR | index 1000 | vol: 0.01166
#   → GJR | index 1250 | vol: 0.02230
#   → GJR | index 1500 | vol: 0.01402
#   → GJR | index 1750 | vol: 0.01526
# ✅ GJR for HSBA.L — R²: 0.8071, RMSE: 0.0028, MAE: 0.0022
#
# ================= HSBA.L - EGARCH =================
#
# 🔮 Running EGARCH for HSBA.L...
#   → EGARCH | index 500 | vol: 0.01111
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 750 | vol: 0.01150
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 1000 | vol: 0.01335
#   → EGARCH | index 1250 | vol: 0.02188
#   → EGARCH | index 1500 | vol: 0.01536
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 1750 | vol: 0.01625
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# ✅ EGARCH for HSBA.L — R²: -7694078.1156, RMSE: 17.7119, MAE: 0.4735
#
# ================= BARC.L - GARCH =================
#
# 🔮 Running GARCH for BARC.L...
#   → GARCH | index 500 | vol: 0.01589
#   → GARCH | index 750 | vol: 0.01405
#   → GARCH | index 1000 | vol: 0.01421
#   → GARCH | index 1250 | vol: 0.02405
#   → GARCH | index 1500 | vol: 0.02061
#   → GARCH | index 1750 | vol: 0.01716
# ✅ GARCH for BARC.L — R²: 0.7692, RMSE: 0.0048, MAE: 0.0033
#
# ================= BARC.L - GJR =================
#
# 🔮 Running GJR for BARC.L...
#   → GJR | index 500 | vol: 0.01506
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → GJR | index 750 | vol: 0.01418
#   → GJR | index 1000 | vol: 0.01429
#   → GJR | index 1250 | vol: 0.02447
#   → GJR | index 1500 | vol: 0.01936
#   → GJR | index 1750 | vol: 0.01576
# ✅ GJR for BARC.L — R²: 0.7405, RMSE: 0.0051, MAE: 0.0034
#
# ================= BARC.L - EGARCH =================
#
# 🔮 Running EGARCH for BARC.L...
#   → EGARCH | index 500 | vol: 0.01685
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 750 | vol: 3.26931
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 1000 | vol: 0.01454
#   → EGARCH | index 1250 | vol: 0.02492
#   → EGARCH | index 1500 | vol: 0.02193
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 1750 | vol: 0.01728
# ✅ EGARCH for BARC.L — R²: -81.9846, RMSE: 0.0917, MAE: 0.0097
#
# ================= LLOY.L - GARCH =================
#
# 🔮 Running GARCH for LLOY.L...
#   → GARCH | index 500 | vol: 0.01065
#   → GARCH | index 750 | vol: 0.01426
#   → GARCH | index 1000 | vol: 0.01345
#   → GARCH | index 1250 | vol: 0.01621
#   → GARCH | index 1500 | vol: 0.01860
#   → GARCH | index 1750 | vol: 0.01582
# ✅ GARCH for LLOY.L — R²: 0.6189, RMSE: 0.0057, MAE: 0.0037
#
# ================= LLOY.L - GJR =================
#
# 🔮 Running GJR for LLOY.L...
#   → GJR | index 500 | vol: 0.01047
#   → GJR | index 750 | vol: 0.01330
#   → GJR | index 1000 | vol: 0.01326
#   → GJR | index 1250 | vol: 0.01681
#   → GJR | index 1500 | vol: 0.01705
#   → GJR | index 1750 | vol: 0.01422
# ✅ GJR for LLOY.L — R²: 0.6282, RMSE: 0.0056, MAE: 0.0037
#
# ================= LLOY.L - EGARCH =================
#
# 🔮 Running EGARCH for LLOY.L...
#   → EGARCH | index 500 | vol: 0.01034
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 750 | vol: 0.01417
#   → EGARCH | index 1000 | vol: 0.01502
#   → EGARCH | index 1250 | vol: 0.01777
#   → EGARCH | index 1500 | vol: 0.01923
#   → EGARCH | index 1750 | vol: 0.01502
# ✅ EGARCH for LLOY.L — R²: -22.8766, RMSE: 0.0451, MAE: 0.0082
#
# ================= STAN.L - GARCH =================
#
# 🔮 Running GARCH for STAN.L...
#   → GARCH | index 500 | vol: 0.01375
#   → GARCH | index 750 | vol: 0.01482
#   → GARCH | index 1000 | vol: 0.01404
#   → GARCH | index 1250 | vol: 0.02421
#   → GARCH | index 1500 | vol: 0.02099
#   → GARCH | index 1750 | vol: 0.01875
# ✅ GARCH for STAN.L — R²: 0.6799, RMSE: 0.0047, MAE: 0.0034
#
# ================= STAN.L - GJR =================
#
# 🔮 Running GJR for STAN.L...
#   → GJR | index 500 | vol: 0.01375
#   → GJR | index 750 | vol: 0.01514
#   → GJR | index 1000 | vol: 0.01405
#   → GJR | index 1250 | vol: 0.02007
#   → GJR | index 1500 | vol: 0.01940
#   → GJR | index 1750 | vol: 0.01876
# ✅ GJR for STAN.L — R²: 0.6278, RMSE: 0.0051, MAE: 0.0035
#
# ================= STAN.L - EGARCH =================
#
# 🔮 Running EGARCH for STAN.L...
#   → EGARCH | index 500 | vol: 0.02169
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# ...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 1000 | vol: 0.01544
#   → EGARCH | index 1250 | vol: 0.01697
#   → EGARCH | index 1500 | vol: 0.01435
#   → EGARCH | index 1750 | vol: 0.01586
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# ✅ EGARCH for LSEG.L — R²: -1.1951, RMSE: 0.0104, MAE: 0.0046
#
# ================= MNG.L - GARCH =================
#
# 🔮 Running GARCH for MNG.L...
#   → GARCH | index 500 | vol: 0.01446
# ✅ GARCH for MNG.L — R²: -10.3701, RMSE: 0.0043, MAE: 0.0042
#
# ================= MNG.L - GJR =================
#
# 🔮 Running GJR for MNG.L...
#   → GJR | index 500 | vol: 0.01441
# ✅ GJR for MNG.L — R²: -3.9232, RMSE: 0.0028, MAE: 0.0027
#
# ================= MNG.L - EGARCH =================
#
# 🔮 Running EGARCH for MNG.L...
#   → EGARCH | index 500 | vol: 0.01322
# ✅ EGARCH for MNG.L — R²: -7.7037, RMSE: 0.0038, MAE: 0.0036
#
# ================= HL.L - GARCH =================
#
# 🔮 Running GARCH for HL.L...
#   → GARCH | index 500 | vol: 0.01339
#   → GARCH | index 750 | vol: 0.01992
#   → GARCH | index 1000 | vol: 0.02332
#   → GARCH | index 1250 | vol: 0.02100
#   → GARCH | index 1500 | vol: 0.01533
#   → GARCH | index 1750 | vol: 0.01950
# ✅ GARCH for HL.L — R²: 0.2969, RMSE: 0.0072, MAE: 0.0048
#
# ================= HL.L - GJR =================
#
# 🔮 Running GJR for HL.L...
#   → GJR | index 500 | vol: 0.01270
#   → GJR | index 750 | vol: 0.01778
#   → GJR | index 1000 | vol: 0.01956
#   → GJR | index 1250 | vol: 0.02025
#   → GJR | index 1500 | vol: 0.01533
#   → GJR | index 1750 | vol: 0.01980
# ✅ GJR for HL.L — R²: 0.2238, RMSE: 0.0075, MAE: 0.0050
#
# ================= HL.L - EGARCH =================
#
# 🔮 Running EGARCH for HL.L...
#   → EGARCH | index 500 | vol: 0.01392
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 750 | vol: 0.01910
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 1000 | vol: 0.02331
#   → EGARCH | index 1250 | vol: 0.02259
#   → EGARCH | index 1500 | vol: 0.13821
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 1750 | vol: 0.01914
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# ✅ EGARCH for HL.L — R²: -147.5227, RMSE: 0.1039, MAE: 0.0142
# 💾 Saved time series model results to uk_ts_model_results.csv
#      Stock   Model             R2           RMSE            MSE            MAE
# 0   HSBA.L   GARCH   8.111000e-01   2.800000e-03   8.000000e-06   2.200000e-03
# 1   HSBA.L     GJR   8.071000e-01   2.800000e-03   8.000000e-06   2.200000e-03
# 22    AV.L     GJR   7.864000e-01   3.900000e-03   1.500000e-05   2.700000e-03
# 19  LGEN.L     GJR   7.840000e-01   5.500000e-03   3.100000e-05   3.400000e-03
# 18  LGEN.L   GARCH   7.703000e-01   5.700000e-03   3.200000e-05   3.300000e-03
# 3   BARC.L   GARCH   7.692000e-01   4.800000e-03   2.300000e-05   3.300000e-03
# 4   BARC.L     GJR   7.405000e-01   5.100000e-03   2.600000e-05   3.400000e-03
# 13   NWG.L     GJR   7.104000e-01   4.600000e-03   2.100000e-05   3.400000e-03
# 21    AV.L   GARCH   6.926000e-01   4.700000e-03   2.200000e-05   3.000000e-03
# 15   PRU.L   GARCH   6.881000e-01   5.500000e-03   3.100000e-05   4.000000e-03
# 25  PHNX.L     GJR   6.856000e-01   4.500000e-03   2.100000e-05   2.800000e-03
# 9   STAN.L   GARCH   6.799000e-01   4.700000e-03   2.300000e-05   3.400000e-03
# 24  PHNX.L   GARCH   6.727000e-01   4.600000e-03   2.100000e-05   2.700000e-03
# 26  PHNX.L  EGARCH   6.677000e-01   4.700000e-03   2.200000e-05   2.600000e-03
# 7   LLOY.L     GJR   6.282000e-01   5.600000e-03   3.200000e-05   3.700000e-03
# 10  STAN.L     GJR   6.278000e-01   5.100000e-03   2.600000e-05   3.500000e-03
# 6   LLOY.L   GARCH   6.189000e-01   5.700000e-03   3.200000e-05   3.700000e-03
# 12   NWG.L   GARCH   5.695000e-01   5.600000e-03   3.100000e-05   3.600000e-03
# 16   PRU.L     GJR   5.220000e-01   6.800000e-03   4.700000e-05   4.700000e-03
# 27  LSEG.L   GARCH   4.317000e-01   5.300000e-03   2.800000e-05   3.700000e-03
# 33    HL.L   GARCH   2.969000e-01   7.200000e-03   5.100000e-05   4.800000e-03
# 28  LSEG.L     GJR   2.898000e-01   5.900000e-03   3.500000e-05   4.000000e-03
# 34    HL.L     GJR   2.238000e-01   7.500000e-03   5.600000e-05   5.000000e-03
# 14   NWG.L  EGARCH  -4.215000e-01   1.020000e-02   1.030000e-04   4.700000e-03
# 29  LSEG.L  EGARCH  -1.195100e+00   1.040000e-02   1.090000e-04   4.600000e-03
# 31   MNG.L     GJR  -3.923200e+00   2.800000e-03   8.000000e-06   2.700000e-03
# 32   MNG.L  EGARCH  -7.703700e+00   3.800000e-03   1.400000e-05   3.600000e-03
# 17   PRU.L  EGARCH  -8.755700e+00   3.090000e-02   9.550000e-04   7.200000e-03
# 30   MNG.L   GARCH  -1.037010e+01   4.300000e-03   1.900000e-05   4.200000e-03
# 8   LLOY.L  EGARCH  -2.287660e+01   4.510000e-02   2.033000e-03   8.200000e-03
# 23    AV.L  EGARCH  -4.250730e+01   5.570000e-02   3.097000e-03   9.400000e-03
# 5   BARC.L  EGARCH  -8.198460e+01   9.170000e-02   8.415000e-03   9.700000e-03
# 35    HL.L  EGARCH  -1.475227e+02   1.039000e-01   1.080000e-02   1.420000e-02
# 2   HSBA.L  EGARCH  -7.694078e+06   1.771190e+01   3.137130e+02   4.735000e-01
# 20  LGEN.L  EGARCH -1.657048e+237  4.839320e+116  2.341902e+233  1.254535e+115
# 11  STAN.L  EGARCH -1.583287e+269  3.339928e+132  1.115512e+265  8.658360e+130

# %%
def train_fusion_model(df, model_name, ts_feature="GARCH_pred", ticker="TICKER"):
    from sklearn.model_selection import train_test_split
    from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
    from sklearn.neighbors import KNeighborsRegressor
    from catboost import CatBoostRegressor
    from lightgbm import LGBMRegressor
    from xgboost import XGBRegressor

    models = {
        "KNN": KNeighborsRegressor(),
        "AdaBoost": AdaBoostRegressor(),
        "CatBoost": CatBoostRegressor(verbose=0),
        "XGBoost": XGBRegressor(verbosity=0),
        "RandomForest": RandomForestRegressor()
    }

    if model_name not in models:
        raise ValueError(f"Model '{model_name}' not recognized.")

    df = df.copy()

    # Flatten if needed
    if isinstance(df.columns, pd.MultiIndex):
        df.columns = ['_'.join([str(i) for i in col if i]) for col in df.columns]

    if ts_feature not in df.columns:
        raise ValueError(f"'{ts_feature}' not found in DataFrame for {ticker}")

    feature_cols = [
        'RSI', 'MOM', 'OBV', 'MACD_LINE', 'MACD_SIGNAL', 'MACD_HIST',
        'STO_K', 'STO_D', 'Vol_t_1', 'Vol_t_2', 'Vol_t_3',
        'Vol_t_4', 'Vol_t_5', 'Vol_t_6', ts_feature
    ]

    X = df[feature_cols].copy()
    y = df["Vol_target"]

    split_idx = int(len(df) * 0.7)
    X_train, X_test = X.iloc[:split_idx], X.iloc[split_idx:]
    y_train, y_test = y.iloc[:split_idx], y.iloc[split_idx:]

    model = models[model_name]
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    metrics = evaluate_series(y_test, y_pred)

    print(f"✅ {model_name} + {ts_feature} for {ticker} — R²: {metrics['R2']:.4f}, RMSE: {metrics['RMSE']:.4f}, MAE: {metrics['MAE']:.4f}")

    return metrics

# %%
import os
import pandas as pd

# Reuse existing forecast function
for ticker in tqdm(garch_data.keys()):
    for model_type in ["GJR", "EGARCH"]:
        print(f"\n📈 Adding {model_type}_pred to {ticker}...")
        df = garch_data[ticker]

        try:
            df, _ = forecast_volatility_arch(df, model_type=model_type, ticker=ticker, verbose=False)
            garch_data[ticker] = df  # Update with new column
        except Exception as e:
            print(f"⚠️ {model_type} failed for {ticker}: {e}")

def train_all_fusion_models(garch_data_dict, results_path="uk_fusion_model_results.csv"):
    # Load existing results if file exists
    if os.path.exists(results_path):
        print(f"📦 Loading saved fusion model results from {results_path}...")
        return pd.read_csv(results_path)

    results = []

    for ticker, df in garch_data_dict.items():
        for ts_feature in ["GARCH_pred", "GJR_pred", "EGARCH_pred"]:
            if ts_feature not in df.columns:
                print(f"⚠️ Skipping {ticker} - missing {ts_feature}")
                continue

            for model_name in ["RandomForest", "XGBoost", "CatBoost", "AdaBoost", "KNN"]:
                try:
                    metrics = train_fusion_model(df, model_name, ts_feature=ts_feature, ticker=ticker)
                    results.append({
                        "Stock": ticker,
                        "Fusion_Model": f"{ts_feature}+{model_name}",
                        "R2": round(metrics["R2"], 4),
                        "RMSE": round(metrics["RMSE"], 4),
                        "MSE": round(metrics["MSE"], 6),
                        "MAE": round(metrics["MAE"], 4),
                    })
                except Exception as e:
                    print(f"⚠️ {ticker} {ts_feature}+{model_name} failed: {e}")

    fusion_df = pd.DataFrame(results)
    fusion_df.to_csv(results_path, index=False)
    print(f"💾 Saved fusion model results to {results_path}")

    return fusion_df

fusion_results_df = train_all_fusion_models(garch_data)
fusion_results_sorted = fusion_results_df.sort_values(by="R2", ascending=False)
display(fusion_results_sorted)
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
# 📈 Adding GJR_pred to HSBA.L...
#
# 📈 Adding EGARCH_pred to HSBA.L...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   8%|▊         | 1/12 [00:39<07:19, 39.96s/it]
# 📈 Adding GJR_pred to BARC.L...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# 📈 Adding EGARCH_pred to BARC.L...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  17%|█▋        | 2/12 [01:18<06:34, 39.42s/it]
# 📈 Adding GJR_pred to LLOY.L...
#
# 📈 Adding EGARCH_pred to LLOY.L...
#  25%|██▌       | 3/12 [01:56<05:47, 38.61s/it]
# 📈 Adding GJR_pred to STAN.L...
#
# 📈 Adding EGARCH_pred to STAN.L...
#  33%|███▎      | 4/12 [02:34<05:06, 38.31s/it]
# 📈 Adding GJR_pred to NWG.L...
#
# 📈 Adding EGARCH_pred to NWG.L...
#  42%|████▏     | 5/12 [03:12<04:28, 38.33s/it]
# 📈 Adding GJR_pred to PRU.L...
#
# 📈 Adding EGARCH_pred to PRU.L...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  50%|█████     | 6/12 [03:47<03:43, 37.21s/it]
# 📈 Adding GJR_pred to LGEN.L...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# 📈 Adding EGARCH_pred to LGEN.L...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  58%|█████▊    | 7/12 [04:26<03:07, 37.59s/it]
# 📈 Adding GJR_pred to AV.L...
#
# 📈 Adding EGARCH_pred to AV.L...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  67%|██████▋   | 8/12 [05:06<02:33, 38.34s/it]
# 📈 Adding GJR_pred to PHNX.L...
#
# 📈 Adding EGARCH_pred to PHNX.L...
#  75%|███████▌  | 9/12 [05:41<01:52, 37.39s/it]
# 📈 Adding GJR_pred to LSEG.L...
#
# 📈 Adding EGARCH_pred to LSEG.L...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  83%|████████▎ | 10/12 [06:14<01:12, 36.16s/it]
# 📈 Adding GJR_pred to MNG.L...
#  92%|█████████▏| 11/12 [06:15<00:25, 25.19s/it]
# 📈 Adding EGARCH_pred to MNG.L...
# ⚠️ EGARCH failed for MNG.L: Length of values (500) does not match length of index (21)
#
# 📈 Adding GJR_pred to HL.L...
#
# 📈 Adding EGARCH_pred to HL.L...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# 100%|██████████| 12/12 [06:57<00:00, 34.77s/it]
# ✅ RandomForest + GARCH_pred for HSBA.L — R²: 0.7989, RMSE: 0.0019, MAE: 0.0014
# ✅ XGBoost + GARCH_pred for HSBA.L — R²: 0.6569, RMSE: 0.0024, MAE: 0.0018
# ✅ CatBoost + GARCH_pred for HSBA.L — R²: 0.6906, RMSE: 0.0023, MAE: 0.0018
# ✅ AdaBoost + GARCH_pred for HSBA.L — R²: 0.6953, RMSE: 0.0023, MAE: 0.0019
# ✅ KNN + GARCH_pred for HSBA.L — R²: -6.5551, RMSE: 0.0114, MAE: 0.0100
# ✅ RandomForest + GJR_pred for HSBA.L — R²: 0.8385, RMSE: 0.0017, MAE: 0.0012
# ✅ XGBoost + GJR_pred for HSBA.L — R²: 0.7013, RMSE: 0.0023, MAE: 0.0016
# ✅ CatBoost + GJR_pred for HSBA.L — R²: 0.6944, RMSE: 0.0023, MAE: 0.0018
# ✅ AdaBoost + GJR_pred for HSBA.L — R²: 0.7411, RMSE: 0.0021, MAE: 0.0017
# ✅ KNN + GJR_pred for HSBA.L — R²: -6.5551, RMSE: 0.0114, MAE: 0.0100
# ✅ RandomForest + EGARCH_pred for HSBA.L — R²: 0.8264, RMSE: 0.0017, MAE: 0.0013
# ✅ XGBoost + EGARCH_pred for HSBA.L — R²: 0.6992, RMSE: 0.0023, MAE: 0.0016
# ✅ CatBoost + EGARCH_pred for HSBA.L — R²: 0.6937, RMSE: 0.0023, MAE: 0.0019
# ✅ AdaBoost + EGARCH_pred for HSBA.L — R²: 0.7638, RMSE: 0.0020, MAE: 0.0016
# ✅ KNN + EGARCH_pred for HSBA.L — R²: -6.5551, RMSE: 0.0114, MAE: 0.0100
# ✅ RandomForest + GARCH_pred for BARC.L — R²: 0.9193, RMSE: 0.0014, MAE: 0.0010
# ✅ XGBoost + GARCH_pred for BARC.L — R²: 0.8787, RMSE: 0.0017, MAE: 0.0013
# ✅ CatBoost + GARCH_pred for BARC.L — R²: 0.8672, RMSE: 0.0018, MAE: 0.0013
# ✅ AdaBoost + GARCH_pred for BARC.L — R²: 0.8450, RMSE: 0.0019, MAE: 0.0014
# ✅ KNN + GARCH_pred for BARC.L — R²: -6.4383, RMSE: 0.0132, MAE: 0.0107
# ✅ RandomForest + GJR_pred for BARC.L — R²: 0.9144, RMSE: 0.0014, MAE: 0.0010
# ✅ XGBoost + GJR_pred for BARC.L — R²: 0.8844, RMSE: 0.0016, MAE: 0.0012
# ✅ CatBoost + GJR_pred for BARC.L — R²: 0.8835, RMSE: 0.0017, MAE: 0.0012
# ✅ AdaBoost + GJR_pred for BARC.L — R²: 0.8537, RMSE: 0.0019, MAE: 0.0014
# ✅ KNN + GJR_pred for BARC.L — R²: -6.4383, RMSE: 0.0132, MAE: 0.0107
# ✅ RandomForest + EGARCH_pred for BARC.L — R²: 0.9162, RMSE: 0.0014, MAE: 0.0010
# ✅ XGBoost + EGARCH_pred for BARC.L — R²: 0.8988, RMSE: 0.0015, MAE: 0.0012
# ✅ CatBoost + EGARCH_pred for BARC.L — R²: 0.8804, RMSE: 0.0017, MAE: 0.0012
# ✅ AdaBoost + EGARCH_pred for BARC.L — R²: 0.8269, RMSE: 0.0020, MAE: 0.0016
# ✅ KNN + EGARCH_pred for BARC.L — R²: -6.4383, RMSE: 0.0132, MAE: 0.0107
# ✅ RandomForest + GARCH_pred for LLOY.L — R²: 0.9125, RMSE: 0.0013, MAE: 0.0010
# ✅ XGBoost + GARCH_pred for LLOY.L — R²: 0.8534, RMSE: 0.0016, MAE: 0.0013
# ✅ CatBoost + GARCH_pred for LLOY.L — R²: 0.8212, RMSE: 0.0018, MAE: 0.0015
# ✅ AdaBoost + GARCH_pred for LLOY.L — R²: 0.7586, RMSE: 0.0021, MAE: 0.0018
# ✅ KNN + GARCH_pred for LLOY.L — R²: -3.7275, RMSE: 0.0092, MAE: 0.0076
# ✅ RandomForest + GJR_pred for LLOY.L — R²: 0.9086, RMSE: 0.0013, MAE: 0.0010
# ✅ XGBoost + GJR_pred for LLOY.L — R²: 0.8567, RMSE: 0.0016, MAE: 0.0013
# ✅ CatBoost + GJR_pred for LLOY.L — R²: 0.8237, RMSE: 0.0018, MAE: 0.0015
# ✅ AdaBoost + GJR_pred for LLOY.L — R²: 0.7022, RMSE: 0.0023, MAE: 0.0019
# ✅ KNN + GJR_pred for LLOY.L — R²: -3.7275, RMSE: 0.0092, MAE: 0.0076
# ✅ RandomForest + EGARCH_pred for LLOY.L — R²: 0.9109, RMSE: 0.0013, MAE: 0.0010
# ✅ XGBoost + EGARCH_pred for LLOY.L — R²: 0.8693, RMSE: 0.0015, MAE: 0.0012
# ✅ CatBoost + EGARCH_pred for LLOY.L — R²: 0.8495, RMSE: 0.0016, MAE: 0.0013
# ✅ AdaBoost + EGARCH_pred for LLOY.L — R²: 0.7128, RMSE: 0.0023, MAE: 0.0019
# ✅ KNN + EGARCH_pred for LLOY.L — R²: -3.7275, RMSE: 0.0092, MAE: 0.0076
# ✅ RandomForest + GARCH_pred for STAN.L — R²: 0.8508, RMSE: 0.0025, MAE: 0.0016
# ✅ XGBoost + GARCH_pred for STAN.L — R²: 0.7924, RMSE: 0.0030, MAE: 0.0020
# ✅ CatBoost + GARCH_pred for STAN.L — R²: 0.8061, RMSE: 0.0029, MAE: 0.0022
# ✅ AdaBoost + GARCH_pred for STAN.L — R²: 0.7463, RMSE: 0.0033, MAE: 0.0027
# ✅ KNN + GARCH_pred for STAN.L — R²: -0.1824, RMSE: 0.0071, MAE: 0.0060
# ✅ RandomForest + GJR_pred for STAN.L — R²: 0.8626, RMSE: 0.0024, MAE: 0.0016
# ✅ XGBoost + GJR_pred for STAN.L — R²: 0.8379, RMSE: 0.0026, MAE: 0.0019
# ✅ CatBoost + GJR_pred for STAN.L — R²: 0.7857, RMSE: 0.0030, MAE: 0.0023
# ✅ AdaBoost + GJR_pred for STAN.L — R²: 0.7680, RMSE: 0.0031, MAE: 0.0024
# ✅ KNN + GJR_pred for STAN.L — R²: -0.1824, RMSE: 0.0071, MAE: 0.0060
# ✅ RandomForest + EGARCH_pred for STAN.L — R²: 0.8483, RMSE: 0.0025, MAE: 0.0017
# ✅ XGBoost + EGARCH_pred for STAN.L — R²: 0.8074, RMSE: 0.0028, MAE: 0.0021
# ✅ CatBoost + EGARCH_pred for STAN.L — R²: 0.8234, RMSE: 0.0027, MAE: 0.0021
# ✅ AdaBoost + EGARCH_pred for STAN.L — R²: 0.7434, RMSE: 0.0033, MAE: 0.0026
# ✅ KNN + EGARCH_pred for STAN.L — R²: -0.1824, RMSE: 0.0071, MAE: 0.0060
# ✅ RandomForest + GARCH_pred for NWG.L — R²: 0.8927, RMSE: 0.0018, MAE: 0.0011
# ✅ XGBoost + GARCH_pred for NWG.L — R²: 0.8772, RMSE: 0.0020, MAE: 0.0013
# ✅ CatBoost + GARCH_pred for NWG.L — R²: 0.8723, RMSE: 0.0020, MAE: 0.0014
# ✅ AdaBoost + GARCH_pred for NWG.L — R²: 0.8677, RMSE: 0.0020, MAE: 0.0015
# ✅ KNN + GARCH_pred for NWG.L — R²: -0.7072, RMSE: 0.0073, MAE: 0.0062
# ✅ RandomForest + GJR_pred for NWG.L — R²: 0.8860, RMSE: 0.0019, MAE: 0.0011
# ✅ XGBoost + GJR_pred for NWG.L — R²: 0.8808, RMSE: 0.0019, MAE: 0.0012
# ✅ CatBoost + GJR_pred for NWG.L — R²: 0.8641, RMSE: 0.0021, MAE: 0.0015
# ✅ AdaBoost + GJR_pred for NWG.L — R²: 0.8566, RMSE: 0.0021, MAE: 0.0016
# ✅ KNN + GJR_pred for NWG.L — R²: -0.7072, RMSE: 0.0073, MAE: 0.0062
# ✅ RandomForest + EGARCH_pred for NWG.L — R²: 0.8826, RMSE: 0.0019, MAE: 0.0013
# ✅ XGBoost + EGARCH_pred for NWG.L — R²: 0.8599, RMSE: 0.0021, MAE: 0.0014
# ✅ CatBoost + EGARCH_pred for NWG.L — R²: 0.8568, RMSE: 0.0021, MAE: 0.0016
# ✅ AdaBoost + EGARCH_pred for NWG.L — R²: 0.8644, RMSE: 0.0021, MAE: 0.0015
# ✅ KNN + EGARCH_pred for NWG.L — R²: -0.7072, RMSE: 0.0073, MAE: 0.0062
# ✅ RandomForest + GARCH_pred for PRU.L — R²: 0.9117, RMSE: 0.0017, MAE: 0.0012
# ✅ XGBoost + GARCH_pred for PRU.L — R²: 0.8980, RMSE: 0.0019, MAE: 0.0013
# ✅ CatBoost + GARCH_pred for PRU.L — R²: 0.8861, RMSE: 0.0020, MAE: 0.0014
# ✅ AdaBoost + GARCH_pred for PRU.L — R²: 0.7727, RMSE: 0.0028, MAE: 0.0023
# ✅ KNN + GARCH_pred for PRU.L — R²: -2.3008, RMSE: 0.0107, MAE: 0.0077
# ✅ RandomForest + GJR_pred for PRU.L — R²: 0.9133, RMSE: 0.0017, MAE: 0.0011
# ✅ XGBoost + GJR_pred for PRU.L — R²: 0.9103, RMSE: 0.0018, MAE: 0.0012
# ✅ CatBoost + GJR_pred for PRU.L — R²: 0.8858, RMSE: 0.0020, MAE: 0.0014
# ✅ AdaBoost + GJR_pred for PRU.L — R²: 0.7348, RMSE: 0.0030, MAE: 0.0025
# ✅ KNN + GJR_pred for PRU.L — R²: -2.3008, RMSE: 0.0107, MAE: 0.0077
# ✅ RandomForest + EGARCH_pred for PRU.L — R²: 0.9082, RMSE: 0.0018, MAE: 0.0012
# ✅ XGBoost + EGARCH_pred for PRU.L — R²: 0.8828, RMSE: 0.0020, MAE: 0.0014
# ✅ CatBoost + EGARCH_pred for PRU.L — R²: 0.8884, RMSE: 0.0020, MAE: 0.0014
# ✅ AdaBoost + EGARCH_pred for PRU.L — R²: 0.7087, RMSE: 0.0032, MAE: 0.0025
# ✅ KNN + EGARCH_pred for PRU.L — R²: -2.3008, RMSE: 0.0107, MAE: 0.0077
# ✅ RandomForest + GARCH_pred for LGEN.L — R²: 0.8692, RMSE: 0.0015, MAE: 0.0012
# ✅ XGBoost + GARCH_pred for LGEN.L — R²: 0.6227, RMSE: 0.0026, MAE: 0.0023
# ✅ CatBoost + GARCH_pred for LGEN.L — R²: 0.8259, RMSE: 0.0018, MAE: 0.0014
# ✅ AdaBoost + GARCH_pred for LGEN.L — R²: 0.8370, RMSE: 0.0017, MAE: 0.0012
# ✅ KNN + GARCH_pred for LGEN.L — R²: -55.8425, RMSE: 0.0317, MAE: 0.0280
# ✅ RandomForest + GJR_pred for LGEN.L — R²: 0.9040, RMSE: 0.0013, MAE: 0.0010
# ✅ XGBoost + GJR_pred for LGEN.L — R²: 0.6414, RMSE: 0.0025, MAE: 0.0022
# ✅ CatBoost + GJR_pred for LGEN.L — R²: 0.8151, RMSE: 0.0018, MAE: 0.0015
# ✅ AdaBoost + GJR_pred for LGEN.L — R²: 0.8187, RMSE: 0.0018, MAE: 0.0012
# ✅ KNN + GJR_pred for LGEN.L — R²: -55.8425, RMSE: 0.0317, MAE: 0.0280
# ✅ RandomForest + EGARCH_pred for LGEN.L — R²: 0.8587, RMSE: 0.0016, MAE: 0.0013
# ✅ XGBoost + EGARCH_pred for LGEN.L — R²: 0.6320, RMSE: 0.0026, MAE: 0.0022
# ✅ CatBoost + EGARCH_pred for LGEN.L — R²: 0.8427, RMSE: 0.0017, MAE: 0.0013
# ✅ AdaBoost + EGARCH_pred for LGEN.L — R²: 0.8374, RMSE: 0.0017, MAE: 0.0012
# ✅ KNN + EGARCH_pred for LGEN.L — R²: -55.8425, RMSE: 0.0317, MAE: 0.0280
# ✅ RandomForest + GARCH_pred for AV.L — R²: 0.8599, RMSE: 0.0014, MAE: 0.0010
# ✅ XGBoost + GARCH_pred for AV.L — R²: 0.8046, RMSE: 0.0017, MAE: 0.0012
# ✅ CatBoost + GARCH_pred for AV.L — R²: 0.8246, RMSE: 0.0016, MAE: 0.0012
# ✅ AdaBoost + GARCH_pred for AV.L — R²: 0.6175, RMSE: 0.0023, MAE: 0.0020
# ✅ KNN + GARCH_pred for AV.L — R²: -5.3393, RMSE: 0.0095, MAE: 0.0069
# ✅ RandomForest + GJR_pred for AV.L — R²: 0.8503, RMSE: 0.0015, MAE: 0.0010
# ✅ XGBoost + GJR_pred for AV.L — R²: 0.7945, RMSE: 0.0017, MAE: 0.0013
# ✅ CatBoost + GJR_pred for AV.L — R²: 0.8213, RMSE: 0.0016, MAE: 0.0012
# ✅ AdaBoost + GJR_pred for AV.L — R²: 0.5602, RMSE: 0.0025, MAE: 0.0022
# ✅ KNN + GJR_pred for AV.L — R²: -5.3393, RMSE: 0.0095, MAE: 0.0069
# ✅ RandomForest + EGARCH_pred for AV.L — R²: 0.8539, RMSE: 0.0014, MAE: 0.0011
# ✅ XGBoost + EGARCH_pred for AV.L — R²: 0.8028, RMSE: 0.0017, MAE: 0.0012
# ✅ CatBoost + EGARCH_pred for AV.L — R²: 0.8373, RMSE: 0.0015, MAE: 0.0012
# ✅ AdaBoost + EGARCH_pred for AV.L — R²: 0.6137, RMSE: 0.0023, MAE: 0.0021
# ✅ KNN + EGARCH_pred for AV.L — R²: -5.3393, RMSE: 0.0095, MAE: 0.0069
# ✅ RandomForest + GARCH_pred for PHNX.L — R²: 0.8548, RMSE: 0.0014, MAE: 0.0010
# ✅ XGBoost + GARCH_pred for PHNX.L — R²: 0.8225, RMSE: 0.0016, MAE: 0.0011
# ✅ CatBoost + GARCH_pred for PHNX.L — R²: 0.8616, RMSE: 0.0014, MAE: 0.0010
# ✅ AdaBoost + GARCH_pred for PHNX.L — R²: 0.6767, RMSE: 0.0021, MAE: 0.0017
# ✅ KNN + GARCH_pred for PHNX.L — R²: -2.8230, RMSE: 0.0072, MAE: 0.0063
# ✅ RandomForest + GJR_pred for PHNX.L — R²: 0.8773, RMSE: 0.0013, MAE: 0.0009
# ✅ XGBoost + GJR_pred for PHNX.L — R²: 0.8556, RMSE: 0.0014, MAE: 0.0010
# ✅ CatBoost + GJR_pred for PHNX.L — R²: 0.8561, RMSE: 0.0014, MAE: 0.0010
# ✅ AdaBoost + GJR_pred for PHNX.L — R²: 0.6855, RMSE: 0.0021, MAE: 0.0017
# ✅ KNN + GJR_pred for PHNX.L — R²: -2.8230, RMSE: 0.0072, MAE: 0.0063
# ✅ RandomForest + EGARCH_pred for PHNX.L — R²: 0.8842, RMSE: 0.0013, MAE: 0.0009
# ✅ XGBoost + EGARCH_pred for PHNX.L — R²: 0.8700, RMSE: 0.0013, MAE: 0.0010
# ✅ CatBoost + EGARCH_pred for PHNX.L — R²: 0.8669, RMSE: 0.0014, MAE: 0.0010
# ✅ AdaBoost + EGARCH_pred for PHNX.L — R²: 0.6503, RMSE: 0.0022, MAE: 0.0018
# ✅ KNN + EGARCH_pred for PHNX.L — R²: -2.8230, RMSE: 0.0072, MAE: 0.0063
# ✅ RandomForest + GARCH_pred for LSEG.L — R²: 0.2576, RMSE: 0.0026, MAE: 0.0022
# ✅ XGBoost + GARCH_pred for LSEG.L — R²: 0.0181, RMSE: 0.0030, MAE: 0.0026
# ✅ CatBoost + GARCH_pred for LSEG.L — R²: -0.0327, RMSE: 0.0031, MAE: 0.0026
# ✅ AdaBoost + GARCH_pred for LSEG.L — R²: -1.2493, RMSE: 0.0045, MAE: 0.0042
# ✅ KNN + GARCH_pred for LSEG.L — R²: -0.5300, RMSE: 0.0038, MAE: 0.0029
# ✅ RandomForest + GJR_pred for LSEG.L — R²: 0.2750, RMSE: 0.0026, MAE: 0.0022
# ✅ XGBoost + GJR_pred for LSEG.L — R²: 0.0704, RMSE: 0.0029, MAE: 0.0025
# ✅ CatBoost + GJR_pred for LSEG.L — R²: 0.0817, RMSE: 0.0029, MAE: 0.0025
# ✅ AdaBoost + GJR_pred for LSEG.L — R²: -1.5719, RMSE: 0.0049, MAE: 0.0045
# ✅ KNN + GJR_pred for LSEG.L — R²: -0.5300, RMSE: 0.0038, MAE: 0.0029
# ✅ RandomForest + EGARCH_pred for LSEG.L — R²: 0.2153, RMSE: 0.0027, MAE: 0.0023
# ✅ XGBoost + EGARCH_pred for LSEG.L — R²: 0.0219, RMSE: 0.0030, MAE: 0.0026
# ✅ CatBoost + EGARCH_pred for LSEG.L — R²: 0.0301, RMSE: 0.0030, MAE: 0.0025
# ✅ AdaBoost + EGARCH_pred for LSEG.L — R²: -1.1894, RMSE: 0.0045, MAE: 0.0041
# ✅ KNN + EGARCH_pred for LSEG.L — R²: -0.5300, RMSE: 0.0038, MAE: 0.0029
# ✅ RandomForest + GARCH_pred for MNG.L — R²: -1.1540, RMSE: 0.0011, MAE: 0.0008
# ✅ XGBoost + GARCH_pred for MNG.L — R²: -2.2155, RMSE: 0.0013, MAE: 0.0011
# ✅ CatBoost + GARCH_pred for MNG.L — R²: -1.2156, RMSE: 0.0011, MAE: 0.0008
# ✅ AdaBoost + GARCH_pred for MNG.L — R²: -0.6329, RMSE: 0.0009, MAE: 0.0006
# ✅ KNN + GARCH_pred for MNG.L — R²: -2.9416, RMSE: 0.0015, MAE: 0.0013
# ✅ RandomForest + GJR_pred for MNG.L — R²: -1.1215, RMSE: 0.0011, MAE: 0.0008
# ✅ XGBoost + GJR_pred for MNG.L — R²: -2.2155, RMSE: 0.0013, MAE: 0.0011
# ✅ CatBoost + GJR_pred for MNG.L — R²: -1.1972, RMSE: 0.0011, MAE: 0.0008
# ✅ AdaBoost + GJR_pred for MNG.L — R²: -1.0656, RMSE: 0.0011, MAE: 0.0008
# ✅ KNN + GJR_pred for MNG.L — R²: -2.9416, RMSE: 0.0015, MAE: 0.0013
# ⚠️ Skipping MNG.L - missing EGARCH_pred
# ✅ RandomForest + GARCH_pred for HL.L — R²: 0.8931, RMSE: 0.0017, MAE: 0.0013
# ✅ XGBoost + GARCH_pred for HL.L — R²: 0.8912, RMSE: 0.0017, MAE: 0.0012
# ✅ CatBoost + GARCH_pred for HL.L — R²: 0.8054, RMSE: 0.0023, MAE: 0.0019
# ✅ AdaBoost + GARCH_pred for HL.L — R²: 0.8232, RMSE: 0.0022, MAE: 0.0018
# ✅ KNN + GARCH_pred for HL.L — R²: -3.1549, RMSE: 0.0105, MAE: 0.0092
# ✅ RandomForest + GJR_pred for HL.L — R²: 0.8999, RMSE: 0.0016, MAE: 0.0012
# ✅ XGBoost + GJR_pred for HL.L — R²: 0.8984, RMSE: 0.0016, MAE: 0.0011
# ✅ CatBoost + GJR_pred for HL.L — R²: 0.8278, RMSE: 0.0021, MAE: 0.0018
# ✅ AdaBoost + GJR_pred for HL.L — R²: 0.8084, RMSE: 0.0023, MAE: 0.0019
# ✅ KNN + GJR_pred for HL.L — R²: -3.1549, RMSE: 0.0105, MAE: 0.0092
# ✅ RandomForest + EGARCH_pred for HL.L — R²: 0.8527, RMSE: 0.0020, MAE: 0.0014
# ✅ XGBoost + EGARCH_pred for HL.L — R²: 0.8631, RMSE: 0.0019, MAE: 0.0013
# ✅ CatBoost + EGARCH_pred for HL.L — R²: 0.8491, RMSE: 0.0020, MAE: 0.0015
# ✅ AdaBoost + EGARCH_pred for HL.L — R²: 0.8244, RMSE: 0.0022, MAE: 0.0018
# ✅ KNN + EGARCH_pred for HL.L — R²: -3.1549, RMSE: 0.0105, MAE: 0.0092
# 💾 Saved fusion model results to uk_fusion_model_results.csv
#       Stock              Fusion_Model       R2    RMSE       MSE     MAE
# 15   BARC.L   GARCH_pred+RandomForest   0.9193  0.0014  0.000002  0.0010
# 25   BARC.L  EGARCH_pred+RandomForest   0.9162  0.0014  0.000002  0.0010
# 20   BARC.L     GJR_pred+RandomForest   0.9144  0.0014  0.000002  0.0010
# 80    PRU.L     GJR_pred+RandomForest   0.9133  0.0017  0.000003  0.0011
# 30   LLOY.L   GARCH_pred+RandomForest   0.9125  0.0013  0.000002  0.0010
# ..      ...                       ...      ...     ...       ...     ...
# 9    HSBA.L              GJR_pred+KNN  -6.5551  0.0114  0.000131  0.0100
# 4    HSBA.L            GARCH_pred+KNN  -6.5551  0.0114  0.000131  0.0100
# 104  LGEN.L           EGARCH_pred+KNN -55.8425  0.0317  0.001007  0.0280
# 99   LGEN.L              GJR_pred+KNN -55.8425  0.0317  0.001007  0.0280
# 94   LGEN.L            GARCH_pred+KNN -55.8425  0.0317  0.001007  0.0280
#
# [175 rows x 6 columns]
