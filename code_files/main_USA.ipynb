# %%
import yfinance as yf
import pandas as pd
import numpy as np
from ta.momentum import RSIIndicator, StochasticOscillator
from ta.trend import MACD
from tqdm import tqdm

# Ticker symbols for the 12 stocks
tickers = [
    "JPM", "BAC", "WFC", "GS", "MS", "PNC",
    "BMO", "STT", "HSBC", "AXP", "FITB", "MTB"
]

# Download historical OHLCV from 2014-01-01 to 2023-12-31
def download_data(ticker):
    data = yf.download(ticker, start="2014-01-01", end="2023-12-31")
    data = data.dropna()
    return data

stock_data = {ticker: download_data(ticker) for ticker in tqdm(tickers)}
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# 100%|██████████| 12/12 [00:03<00:00,  3.08it/s]

# %%
def compute_features(df):
    df = df.copy()

    # Ensure Close, High, Low are Series (1D)
    close = df["Close"].squeeze()
    high = df["High"].squeeze()
    low = df["Low"].squeeze()
    volume = df["Volume"].squeeze()

    print(f"Close dtype: {type(close)}, shape: {close.shape}")

    # Daily return
    df["Return"] = close.pct_change()

    # 30-day rolling volatility (target)
    df["Volatility"] = df["Return"].rolling(window=30).std()

    # RSI (14 days)
    df["RSI"] = RSIIndicator(close=close, window=14).rsi()

    # Momentum (5 days)
    df["MOM"] = close - close.shift(5)

    # OBV
    df["OBV"] = (np.sign(close.diff()) * volume).fillna(0).cumsum()

    # MACD
    macd = MACD(close=close, window_slow=26, window_fast=12, window_sign=9)
    df["MACD_LINE"] = macd.macd()
    df["MACD_SIGNAL"] = macd.macd_signal()
    df["MACD_HIST"] = macd.macd_diff()

    # Stochastic Oscillator
    stoch = StochasticOscillator(high=high, low=low, close=close, window=14, smooth_window=3)
    df["STO_K"] = stoch.stoch()           # formerly %K
    df["STO_D"] = stoch.stoch_signal()    # formerly %D

    # Lagged volatilities (t-1 to t-6)
    for i in range(1, 7):
        df[f"Vol_t_{i}"] = df["Volatility"].shift(i)

    # Volatility t+1 (our target)
    df["Vol_target"] = df["Volatility"].shift(-1)

    # Drop rows with NaNs
    df = df.dropna()

    return df

# %%
import os
import pickle

feature_data = {}
for ticker in tqdm(tickers):
    feature_data[ticker] = compute_features(stock_data[ticker])

feature_data_path = "feature_data.pkl"

if os.path.exists(feature_data_path):
    print("📦 Loading saved feature data from feature_data.pkl...")
    with open(feature_data_path, "rb") as f:
        feature_data = pickle.load(f)
else:
    print("⚙️ Computing feature data...")
    feature_data = {ticker: compute_features(stock_data[ticker]) for ticker in tqdm(tickers)}
    with open(feature_data_path, "wb") as f:
        pickle.dump(feature_data, f)
    print("💾 Saved feature data to feature_data.pkl")
# Out:
# 100%|██████████| 12/12 [00:00<00:00, 81.55it/s]
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2516,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2516,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2516,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2516,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2516,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2516,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2516,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2516,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2516,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2516,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2516,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2516,)
# 📦 Loading saved feature data from feature_data.pkl...

# %%
from arch import arch_model
import warnings

def add_garch_predictions(df, ticker=None, verbose=True):
    df = df.copy()
    returns = df["Return"].dropna().values
    preds = []
    window_size = 500
    scale_factor = 100  # recommended by arch package

    if verbose:
        print(f"\n🔍 GARCH modeling for {ticker} — total points: {len(returns)}")

    for i in range(window_size, len(returns)):
        train_window = returns[i-window_size:i] * scale_factor  # rescale

        try:
            with warnings.catch_warnings():
                warnings.simplefilter("ignore")
                model = arch_model(train_window, vol='Garch', p=1, q=1, dist='normal', rescale=False)
                model_fit = model.fit(disp="off")
                forecast = model_fit.forecast(horizon=1)
                pred_vol_scaled = np.sqrt(forecast.variance.values[-1][0])
                pred_vol = pred_vol_scaled / scale_factor  # unscale
        except Exception as e:
            if verbose:
                print(f"⚠️ Failed at i={i} — {e}")
            pred_vol = np.nan

        preds.append(pred_vol)

        if verbose and i % 250 == 0:
            print(f"  → Index {i} | Pred Vol (unscaled): {pred_vol:.5f}")

    full_preds = [np.nan] * window_size + preds
    df["GARCH_pred"] = full_preds

    before = len(df)
    df = df.dropna()
    after = len(df)

    if verbose:
        print(f"✅ Done {ticker} | Rows dropped: {before - after} | Final: {after} rows")

    return df

# %%
# === Try loading precomputed garch_data from disk ===
garch_data_path = "garch_data.pkl"

if os.path.exists(garch_data_path):
    print("📦 Loading saved GARCH data from garch_data.pkl...")
    with open(garch_data_path, "rb") as f:
        garch_data = pickle.load(f)
    print("✅ Loaded GARCH data successfully!")
else:
    print("⚙️ Computing GARCH data from scratch...")
    garch_data = {}
    for ticker in tickers:
        print(f"\n====================== {ticker} ======================")
        garch_data[ticker] = add_garch_predictions(feature_data[ticker], ticker=ticker)

    # Save to disk
    with open(garch_data_path, "wb") as f:
        pickle.dump(garch_data, f)
    print("💾 Saved GARCH data to garch_data.pkl")
# Out:
# 📦 Loading saved GARCH data from garch_data.pkl...
# ✅ Loaded GARCH data successfully!

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
import numpy as np
import warnings
warnings.filterwarnings("ignore")

def evaluate(y_true, y_pred):
    return {
        "R2": r2_score(y_true, y_pred),
        "RMSE": mean_squared_error(y_true, y_pred, squared=False),
        "MSE": mean_squared_error(y_true, y_pred),
        "MAE": mean_absolute_error(y_true, y_pred),
    }

def train_ml_models_baseline(df, ticker="TICKER"):
    print(f"\n📈 Training ML models for {ticker}...")

    # Feature and target selection
    features = [
        'RSI', 'MOM', 'OBV', 'MACD_LINE', 'MACD_SIGNAL', 'MACD_HIST',
        'STO_K', 'STO_D',
        'Vol_t_1', 'Vol_t_2', 'Vol_t_3', 'Vol_t_4', 'Vol_t_5', 'Vol_t_6'
    ]

    X = df[features].copy()
    # Sanitize column names just in case LightGBM is sensitive
    X.columns = [str(col).replace("-", "_").replace("%", "PCT").replace(".", "_DOT_") for col in X.columns]

    y = df["Vol_target"]

    # Static train-test split (same as paper: 2014–2020 train, 2021–2023 test)
    split_idx = int(len(df) * 0.7)
    X_train, X_test = X.iloc[:split_idx], X.iloc[split_idx:]
    y_train, y_test = y.iloc[:split_idx], y.iloc[split_idx:]

    models = {
        "KNN": KNeighborsRegressor(),
        "AdaBoost": AdaBoostRegressor(),
        "CatBoost": CatBoostRegressor(verbose=0),
        #"LightGBM": LGBMRegressor(),
        "XGBoost": XGBRegressor(verbosity=0),
        "RandomForest": RandomForestRegressor()
    }

    results = {}

    for name, model in models.items():
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        metrics = evaluate(y_test, y_pred)
        results[name] = metrics
        print(f"✅ {name} — R²: {metrics['R2']:.4f}, RMSE: {metrics['RMSE']:.4f}, MAE: {metrics['MAE']:.4f}")

    return results
# Out:
# /shared/home/ads066/.local/lib/python3.11/site-packages/xgboost/core.py:377: FutureWarning: Your system has an old version of glibc (< 2.28). We will stop supporting Linux distros with glibc older than 2.28 after **May 31, 2025**. Please upgrade to a recent Linux distro (with glibc >= 2.28) to use future versions of XGBoost.
# Note: You have installed the 'manylinux2014' variant of XGBoost. Certain features such as GPU algorithms or federated learning are not available. To use these features, please upgrade to a recent Linux distro with glibc 2.28+, and install the 'manylinux_2_28' variant.
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

def evaluate(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    return {
        "R2": r2_score(y_true, y_pred),
        "RMSE": np.sqrt(mse),
        "MSE": mse,
        "MAE": mean_absolute_error(y_true, y_pred),
    }

def train_all_stocks_ml_baseline(garch_data_dict, results_path="ml_baseline_results.csv"):
    # Check if results already exist
    if os.path.exists(results_path):
        print(f"📦 Loading existing results from {results_path}...")
        return pd.read_csv(results_path)

    final_results = []

    for ticker, df in garch_data_dict.items():
        print(f"\n================= {ticker} =================")
        results = train_ml_models_baseline(df, ticker=ticker)

        for model_name, metrics in results.items():
            final_results.append({
                "Stock": ticker,
                "Model": model_name,
                "R2": round(metrics["R2"], 4),
                "RMSE": round(metrics["RMSE"], 4),
                "MSE": round(metrics["MSE"], 6),
                "MAE": round(metrics["MAE"], 4),
            })

    # Save results
    results_df = pd.DataFrame(final_results)
    results_df.to_csv(results_path, index=False)
    print(f"💾 Saved results to {results_path}")

    return results_df

# Run training or load existing results
ml_all_results = train_all_stocks_ml_baseline(garch_data)
ml_all_results_sorted = ml_all_results.sort_values(by="R2", ascending=False)
display(ml_all_results_sorted)
# Out:
# ================= JPM =================
#
# 📈 Training ML models for JPM...
# ✅ KNN — R²: -1.5234, RMSE: 0.0073, MAE: 0.0050
# ✅ AdaBoost — R²: 0.8564, RMSE: 0.0017, MAE: 0.0014
# ✅ CatBoost — R²: 0.8297, RMSE: 0.0019, MAE: 0.0014
# ✅ XGBoost — R²: 0.8127, RMSE: 0.0020, MAE: 0.0013
# ✅ RandomForest — R²: 0.9079, RMSE: 0.0014, MAE: 0.0010
#
# ================= BAC =================
#
# 📈 Training ML models for BAC...
# ✅ KNN — R²: -1.5992, RMSE: 0.0063, MAE: 0.0050
# ✅ AdaBoost — R²: 0.7429, RMSE: 0.0020, MAE: 0.0014
# ✅ CatBoost — R²: 0.7564, RMSE: 0.0019, MAE: 0.0014
# ✅ XGBoost — R²: 0.8309, RMSE: 0.0016, MAE: 0.0011
# ✅ RandomForest — R²: 0.6704, RMSE: 0.0023, MAE: 0.0015
#
# ================= WFC =================
#
# 📈 Training ML models for WFC...
# ✅ KNN — R²: -1.2453, RMSE: 0.0069, MAE: 0.0054
# ✅ AdaBoost — R²: 0.8091, RMSE: 0.0020, MAE: 0.0016
# ✅ CatBoost — R²: 0.8709, RMSE: 0.0016, MAE: 0.0012
# ✅ XGBoost — R²: 0.8655, RMSE: 0.0017, MAE: 0.0012
# ✅ RandomForest — R²: 0.8840, RMSE: 0.0016, MAE: 0.0011
#
# ================= GS =================
#
# 📈 Training ML models for GS...
# ✅ KNN — R²: -1.5996, RMSE: 0.0051, MAE: 0.0038
# ✅ AdaBoost — R²: 0.7193, RMSE: 0.0017, MAE: 0.0013
# ✅ CatBoost — R²: 0.7948, RMSE: 0.0014, MAE: 0.0010
# ✅ XGBoost — R²: 0.8110, RMSE: 0.0014, MAE: 0.0010
# ✅ RandomForest — R²: 0.8482, RMSE: 0.0012, MAE: 0.0009
#
# ================= MS =================
#
# 📈 Training ML models for MS...
# ✅ KNN — R²: -0.5045, RMSE: 0.0046, MAE: 0.0038
# ✅ AdaBoost — R²: 0.8392, RMSE: 0.0015, MAE: 0.0011
# ✅ CatBoost — R²: 0.8213, RMSE: 0.0016, MAE: 0.0012
# ✅ XGBoost — R²: 0.8465, RMSE: 0.0015, MAE: 0.0010
# ✅ RandomForest — R²: 0.8679, RMSE: 0.0014, MAE: 0.0010
#
# ================= PNC =================
#
# 📈 Training ML models for PNC...
# ✅ KNN — R²: -2.6854, RMSE: 0.0074, MAE: 0.0057
# ✅ AdaBoost — R²: 0.8349, RMSE: 0.0016, MAE: 0.0012
# ✅ CatBoost — R²: 0.7699, RMSE: 0.0019, MAE: 0.0013
# ✅ XGBoost — R²: 0.8549, RMSE: 0.0015, MAE: 0.0011
# ✅ RandomForest — R²: 0.8794, RMSE: 0.0013, MAE: 0.0010
#
# ================= BMO =================
#
# 📈 Training ML models for BMO...
# ✅ KNN — R²: -0.8419, RMSE: 0.0040, MAE: 0.0034
# ✅ AdaBoost — R²: 0.5860, RMSE: 0.0019, MAE: 0.0014
# ✅ CatBoost — R²: 0.4227, RMSE: 0.0022, MAE: 0.0014
# ✅ XGBoost — R²: 0.7649, RMSE: 0.0014, MAE: 0.0010
# ✅ RandomForest — R²: 0.7177, RMSE: 0.0016, MAE: 0.0010
#
# ================= STT =================
#
# 📈 Training ML models for STT...
# ✅ KNN — R²: -1.0919, RMSE: 0.0081, MAE: 0.0066
# ✅ AdaBoost — R²: 0.7974, RMSE: 0.0025, MAE: 0.0019
# ✅ CatBoost — R²: 0.8824, RMSE: 0.0019, MAE: 0.0012
# ✅ XGBoost — R²: 0.8658, RMSE: 0.0021, MAE: 0.0012
# ✅ RandomForest — R²: 0.8749, RMSE: 0.0020, MAE: 0.0013
#
# ================= HSBC =================
#
# 📈 Training ML models for HSBC...
# ✅ KNN — R²: -1.1933, RMSE: 0.0075, MAE: 0.0063
# ✅ AdaBoost — R²: 0.8928, RMSE: 0.0017, MAE: 0.0012
# ✅ CatBoost — R²: 0.9235, RMSE: 0.0014, MAE: 0.0010
# ✅ XGBoost — R²: 0.9025, RMSE: 0.0016, MAE: 0.0011
# ✅ RandomForest — R²: 0.9168, RMSE: 0.0015, MAE: 0.0010
#
# ================= AXP =================
#
# 📈 Training ML models for AXP...
# ✅ KNN — R²: -5.9124, RMSE: 0.0136, MAE: 0.0102
# ✅ AdaBoost — R²: 0.6792, RMSE: 0.0029, MAE: 0.0022
# ✅ CatBoost — R²: 0.7042, RMSE: 0.0028, MAE: 0.0022
# ✅ XGBoost — R²: 0.7062, RMSE: 0.0028, MAE: 0.0021
# ✅ RandomForest — R²: 0.7908, RMSE: 0.0024, MAE: 0.0018
#
# ================= FITB =================
#
# 📈 Training ML models for FITB...
# ✅ KNN — R²: -3.0225, RMSE: 0.0112, MAE: 0.0084
# ✅ AdaBoost — R²: 0.8464, RMSE: 0.0022, MAE: 0.0015
# ✅ CatBoost — R²: 0.7650, RMSE: 0.0027, MAE: 0.0017
# ✅ XGBoost — R²: 0.8714, RMSE: 0.0020, MAE: 0.0014
# ✅ RandomForest — R²: 0.8794, RMSE: 0.0019, MAE: 0.0013
#
# ================= MTB =================
#
# 📈 Training ML models for MTB...
# ✅ KNN — R²: -2.7376, RMSE: 0.0089, MAE: 0.0069
# ✅ AdaBoost — R²: 0.7397, RMSE: 0.0024, MAE: 0.0015
# ✅ CatBoost — R²: 0.7441, RMSE: 0.0023, MAE: 0.0015
# ✅ XGBoost — R²: 0.7108, RMSE: 0.0025, MAE: 0.0014
# ✅ RandomForest — R²: 0.7900, RMSE: 0.0021, MAE: 0.0013
# 💾 Saved results to ml_baseline_results.csv
#    Stock         Model      R2    RMSE       MSE     MAE
# 42  HSBC      CatBoost  0.9235  0.0014  0.000002  0.0010
# 44  HSBC  RandomForest  0.9168  0.0015  0.000002  0.0010
# 4    JPM  RandomForest  0.9079  0.0014  0.000002  0.0010
# 43  HSBC       XGBoost  0.9025  0.0016  0.000003  0.0011
# 41  HSBC      AdaBoost  0.8928  0.0017  0.000003  0.0012
# 14   WFC  RandomForest  0.8840  0.0016  0.000002  0.0011
# 37   STT      CatBoost  0.8824  0.0019  0.000004  0.0012
# 29   PNC  RandomForest  0.8794  0.0013  0.000002  0.0010
# 54  FITB  RandomForest  0.8794  0.0019  0.000004  0.0013
# 39   STT  RandomForest  0.8749  0.0020  0.000004  0.0013
# 53  FITB       XGBoost  0.8714  0.0020  0.000004  0.0014
# 12   WFC      CatBoost  0.8709  0.0016  0.000003  0.0012
# 24    MS  RandomForest  0.8679  0.0014  0.000002  0.0010
# 38   STT       XGBoost  0.8658  0.0021  0.000004  0.0012
# 13   WFC       XGBoost  0.8655  0.0017  0.000003  0.0012
# 1    JPM      AdaBoost  0.8564  0.0017  0.000003  0.0014
# 28   PNC       XGBoost  0.8549  0.0015  0.000002  0.0011
# 19    GS  RandomForest  0.8482  0.0012  0.000002  0.0009
# 23    MS       XGBoost  0.8465  0.0015  0.000002  0.0010
# 51  FITB      AdaBoost  0.8464  0.0022  0.000005  0.0015
# 21    MS      AdaBoost  0.8392  0.0015  0.000002  0.0011
# 26   PNC      AdaBoost  0.8349  0.0016  0.000002  0.0012
# 8    BAC       XGBoost  0.8309  0.0016  0.000003  0.0011
# 2    JPM      CatBoost  0.8297  0.0019  0.000004  0.0014
# 22    MS      CatBoost  0.8213  0.0016  0.000003  0.0012
# 3    JPM       XGBoost  0.8127  0.0020  0.000004  0.0013
# 18    GS       XGBoost  0.8110  0.0014  0.000002  0.0010
# 11   WFC      AdaBoost  0.8091  0.0020  0.000004  0.0016
# 36   STT      AdaBoost  0.7974  0.0025  0.000006  0.0019
# 17    GS      CatBoost  0.7948  0.0014  0.000002  0.0010
# 49   AXP  RandomForest  0.7908  0.0024  0.000006  0.0018
# 59   MTB  RandomForest  0.7900  0.0021  0.000004  0.0013
# 27   PNC      CatBoost  0.7699  0.0019  0.000003  0.0013
# 52  FITB      CatBoost  0.7650  0.0027  0.000007  0.0017
# 33   BMO       XGBoost  0.7649  0.0014  0.000002  0.0010
# 7    BAC      CatBoost  0.7564  0.0019  0.000004  0.0014
# 57   MTB      CatBoost  0.7441  0.0023  0.000005  0.0015
# 6    BAC      AdaBoost  0.7429  0.0020  0.000004  0.0014
# 56   MTB      AdaBoost  0.7397  0.0024  0.000006  0.0015
# 16    GS      AdaBoost  0.7193  0.0017  0.000003  0.0013
# 34   BMO  RandomForest  0.7177  0.0016  0.000002  0.0010
# 58   MTB       XGBoost  0.7108  0.0025  0.000006  0.0014
# 48   AXP       XGBoost  0.7062  0.0028  0.000008  0.0021
# 47   AXP      CatBoost  0.7042  0.0028  0.000008  0.0022
# 46   AXP      AdaBoost  0.6792  0.0029  0.000009  0.0022
# 9    BAC  RandomForest  0.6704  0.0023  0.000005  0.0015
# 31   BMO      AdaBoost  0.5860  0.0019  0.000004  0.0014
# 32   BMO      CatBoost  0.4227  0.0022  0.000005  0.0014
# 20    MS           KNN -0.5045  0.0046  0.000022  0.0038
# 30   BMO           KNN -0.8419  0.0040  0.000016  0.0034
# 35   STT           KNN -1.0919  0.0081  0.000066  0.0066
# 40  HSBC           KNN -1.1933  0.0075  0.000056  0.0063
# 10   WFC           KNN -1.2453  0.0069  0.000047  0.0054
# 0    JPM           KNN -1.5234  0.0073  0.000053  0.0050
# 5    BAC           KNN -1.5992  0.0063  0.000040  0.0050
# 15    GS           KNN -1.5996  0.0051  0.000026  0.0038
# 25   PNC           KNN -2.6854  0.0074  0.000055  0.0057
# 55   MTB           KNN -2.7376  0.0089  0.000079  0.0069
# 50  FITB           KNN -3.0225  0.0112  0.000126  0.0084
# 45   AXP           KNN -5.9124  0.0136  0.000184  0.0102

# %%
from arch import arch_model
import numpy as np
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

def evaluate_series(y_true, y_pred):
    return {
        "R2": r2_score(y_true, y_pred),
        "RMSE": mean_squared_error(y_true, y_pred, squared=False),
        "MSE": mean_squared_error(y_true, y_pred),
        "MAE": mean_absolute_error(y_true, y_pred),
    }

def forecast_volatility_arch(df, model_type="GARCH", ticker="TICKER", verbose=True):
    df = df.copy()

    # Flatten columns if MultiIndex
    if isinstance(df.columns, pd.MultiIndex):
        df.columns = ['_'.join([str(i) for i in col if i]) for col in df.columns]

    if "Vol_target" not in df.columns or "Return" not in df.columns:
        raise KeyError(f"Missing 'Vol_target' or 'Return' in {ticker}")

    returns = df["Return"].dropna().values
    preds = []
    window_size = 500
    scale_factor = 100  # fix for scale warning

    if verbose:
        print(f"\n🔮 Running {model_type} for {ticker}...")

    for i in range(window_size, len(returns)):
        train_window = returns[i-window_size:i] * scale_factor

        try:
            if model_type == "GARCH":
                model = arch_model(train_window, vol='GARCH', p=1, q=1, dist='normal', rescale=False)
            elif model_type == "GJR":
                model = arch_model(train_window, vol='GARCH', p=1, o=1, q=1, dist='normal', rescale=False)
            elif model_type == "EGARCH":
                model = arch_model(train_window, vol='EGARCH', p=1, q=1, dist='normal', rescale=False)
            else:
                raise ValueError("Invalid model_type")

            model_fit = model.fit(disp="off")
            forecast = model_fit.forecast(horizon=1)
            pred_vol = np.sqrt(forecast.variance.values[-1][0]) / scale_factor

        except Exception as e:
            if verbose:
                print(f"⚠️ {model_type} failed at index {i}: {e}")
            pred_vol = np.nan

        preds.append(pred_vol)

        if verbose and i % 250 == 0:
            print(f"  → {model_type} | index {i} | vol: {pred_vol:.5f}")

    df[f"{model_type}_pred"] = [np.nan] * window_size + preds
    df = df.dropna(subset=["Vol_target", f"{model_type}_pred"])

    metrics = evaluate_series(df["Vol_target"], df[f"{model_type}_pred"])
    if verbose:
        print(f"✅ {model_type} for {ticker} — R²: {metrics['R2']:.4f}, RMSE: {metrics['RMSE']:.4f}, MAE: {metrics['MAE']:.4f}")

    return df, metrics

# %%
import os
import pandas as pd

def evaluate_all_series_models(garch_data_dict, results_path="ts_model_results.csv"):
    # If results already exist, load them
    if os.path.exists(results_path):
        print(f"📦 Loading saved time series results from {results_path}...")
        return pd.read_csv(results_path)

    results = []

    for ticker, df in garch_data_dict.items():
        for model_type in ["GARCH", "GJR", "EGARCH"]:
            print(f"\n================= {ticker} - {model_type} =================")
            try:
                _, metrics = forecast_volatility_arch(df, model_type=model_type, ticker=ticker, verbose=True)
                results.append({
                    "Stock": ticker,
                    "Model": model_type,
                    "R2": round(metrics["R2"], 4),
                    "RMSE": round(metrics["RMSE"], 4),
                    "MSE": round(metrics["MSE"], 6),
                    "MAE": round(metrics["MAE"], 4),
                })
            except Exception as e:
                print(f"⚠️ Skipping {ticker} - {model_type}: {e}")

    df_results = pd.DataFrame(results)
    df_results.to_csv(results_path, index=False)
    print(f"💾 Saved time series model results to {results_path}")

    return df_results

ts_model_results = evaluate_all_series_models(garch_data)
ts_model_results_sorted = ts_model_results.sort_values(by="R2", ascending=False)
display(ts_model_results_sorted)
# Out:
# ================= JPM - GARCH =================
#
# 🔮 Running GARCH for JPM...
#   → GARCH | index 500 | vol: 0.01690
#   → GARCH | index 750 | vol: 0.01127
#   → GARCH | index 1000 | vol: 0.01257
#   → GARCH | index 1250 | vol: 0.01920
#   → GARCH | index 1500 | vol: 0.01736
#   → GARCH | index 1750 | vol: 0.01353
# ✅ GARCH for JPM — R²: 0.6922, RMSE: 0.0055, MAE: 0.0033
#
# ================= JPM - GJR =================
#
# 🔮 Running GJR for JPM...
#   → GJR | index 500 | vol: 0.01666
#   → GJR | index 750 | vol: 0.01196
#   → GJR | index 1000 | vol: 0.01291
#   → GJR | index 1250 | vol: 0.01614
#   → GJR | index 1500 | vol: 0.01767
#   → GJR | index 1750 | vol: 0.01386
# ✅ GJR for JPM — R²: 0.6877, RMSE: 0.0056, MAE: 0.0035
#
# ================= JPM - EGARCH =================
#
# 🔮 Running EGARCH for JPM...
#   → EGARCH | index 500 | vol: 0.01579
#   → EGARCH | index 750 | vol: 0.01153
#   → EGARCH | index 1000 | vol: 0.01271
#   → EGARCH | index 1250 | vol: 0.02082
#   → EGARCH | index 1500 | vol: 0.01914
#   → EGARCH | index 1750 | vol: 0.01362
# ✅ EGARCH for JPM — R²: 0.7428, RMSE: 0.0051, MAE: 0.0032
#
# ================= BAC - GARCH =================
#
# 🔮 Running GARCH for BAC...
#   → GARCH | index 500 | vol: 0.02003
#   → GARCH | index 750 | vol: 0.01351
#   → GARCH | index 1000 | vol: 0.01510
#   → GARCH | index 1250 | vol: 0.02411
#   → GARCH | index 1500 | vol: 0.01638
#   → GARCH | index 1750 | vol: 0.01474
# ✅ GARCH for BAC — R²: 0.7226, RMSE: 0.0054, MAE: 0.0036
#
# ================= BAC - GJR =================
#
# 🔮 Running GJR for BAC...
#   → GJR | index 500 | vol: 0.02005
#   → GJR | index 750 | vol: 0.01326
#   → GJR | index 1000 | vol: 0.01337
#   → GJR | index 1250 | vol: 0.02066
#   → GJR | index 1500 | vol: 0.01709
#   → GJR | index 1750 | vol: 0.01402
# ✅ GJR for BAC — R²: 0.6754, RMSE: 0.0059, MAE: 0.0040
#
# ================= BAC - EGARCH =================
#
# 🔮 Running EGARCH for BAC...
#   → EGARCH | index 500 | vol: 0.01919
#   → EGARCH | index 750 | vol: 0.01326
#   → EGARCH | index 1000 | vol: 0.01517
#   → EGARCH | index 1250 | vol: 0.02650
#   → EGARCH | index 1500 | vol: 0.01748
#   → EGARCH | index 1750 | vol: 0.01446
# ✅ EGARCH for BAC — R²: 0.7473, RMSE: 0.0052, MAE: 0.0035
#
# ================= WFC - GARCH =================
#
# 🔮 Running GARCH for WFC...
#   → GARCH | index 500 | vol: 0.01256
#   → GARCH | index 750 | vol: 0.01158
#   → GARCH | index 1000 | vol: 0.01248
#   → GARCH | index 1250 | vol: 0.02807
#   → GARCH | index 1500 | vol: 0.02420
#   → GARCH | index 1750 | vol: 0.01872
# ✅ GARCH for WFC — R²: 0.6586, RMSE: 0.0064, MAE: 0.0040
#
# ================= WFC - GJR =================
#
# 🔮 Running GJR for WFC...
#   → GJR | index 500 | vol: 0.01306
#   → GJR | index 750 | vol: 0.01325
#   → GJR | index 1000 | vol: 0.01181
#   → GJR | index 1250 | vol: 0.02766
#   → GJR | index 1500 | vol: 0.02054
#   → GJR | index 1750 | vol: 0.01832
# ✅ GJR for WFC — R²: 0.5573, RMSE: 0.0072, MAE: 0.0043
#
# ================= WFC - EGARCH =================
#
# 🔮 Running EGARCH for WFC...
#   → EGARCH | index 500 | vol: 0.01195
#   → EGARCH | index 750 | vol: 0.01078
#   → EGARCH | index 1000 | vol: 0.01230
#   → EGARCH | index 1250 | vol: 0.03016
#   → EGARCH | index 1500 | vol: 0.02203
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 1750 | vol: 0.01852
# ✅ EGARCH for WFC — R²: 0.5503, RMSE: 0.0073, MAE: 0.0043
#
# ================= GS - GARCH =================
#
# 🔮 Running GARCH for GS...
#   → GARCH | index 500 | vol: 0.01663
#   → GARCH | index 750 | vol: 0.01878
#   → GARCH | index 1000 | vol: 0.01377
#   → GARCH | index 1250 | vol: 0.02125
#   → GARCH | index 1500 | vol: 0.02081
#   → GARCH | index 1750 | vol: 0.01815
# ✅ GARCH for GS — R²: 0.7639, RMSE: 0.0044, MAE: 0.0029
#
# ================= GS - GJR =================
#
# 🔮 Running GJR for GS...
#   → GJR | index 500 | vol: 0.01574
#   → GJR | index 750 | vol: 0.01514
#   → GJR | index 1000 | vol: 0.01413
#   → GJR | index 1250 | vol: 0.01945
#   → GJR | index 1500 | vol: 0.02117
#   → GJR | index 1750 | vol: 0.01818
# ✅ GJR for GS — R²: 0.7466, RMSE: 0.0046, MAE: 0.0030
#
# ================= GS - EGARCH =================
#
# 🔮 Running EGARCH for GS...
#   → EGARCH | index 500 | vol: 0.01642
#   → EGARCH | index 750 | vol: 0.01635
#   → EGARCH | index 1000 | vol: 0.01484
#   → EGARCH | index 1250 | vol: 0.02189
#   → EGARCH | index 1500 | vol: 0.02065
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 1750 | vol: 0.01868
# ✅ EGARCH for GS — R²: 0.1570, RMSE: 0.0084, MAE: 0.0039
#
# ================= MS - GARCH =================
#
# 🔮 Running GARCH for MS...
#   → GARCH | index 500 | vol: 0.02405
#   → GARCH | index 750 | vol: 0.01561
#   → GARCH | index 1000 | vol: 0.01523
#   → GARCH | index 1250 | vol: 0.02452
#   → GARCH | index 1500 | vol: 0.01810
#   → GARCH | index 1750 | vol: 0.01808
# ✅ GARCH for MS — R²: 0.5941, RMSE: 0.0064, MAE: 0.0035
#
# ================= MS - GJR =================
#
# 🔮 Running GJR for MS...
#   → GJR | index 500 | vol: 0.02400
#   → GJR | index 750 | vol: 0.01742
#   → GJR | index 1000 | vol: 0.01516
#   → GJR | index 1250 | vol: 0.02316
#   → GJR | index 1500 | vol: 0.01830
#   → GJR | index 1750 | vol: 0.01515
# ✅ GJR for MS — R²: 0.5313, RMSE: 0.0068, MAE: 0.0037
#
# ================= MS - EGARCH =================
#
# 🔮 Running EGARCH for MS...
#   → EGARCH | index 500 | vol: 0.02236
#   → EGARCH | index 750 | vol: 0.01641
#   → EGARCH | index 1000 | vol: 0.01518
#   → EGARCH | index 1250 | vol: 0.02547
#   → EGARCH | index 1500 | vol: 0.01916
#   → EGARCH | index 1750 | vol: 0.01754
# ✅ EGARCH for MS — R²: 0.6602, RMSE: 0.0058, MAE: 0.0033
#
# ================= PNC - GARCH =================
#
# 🔮 Running GARCH for PNC...
#   → GARCH | index 500 | vol: 0.01311
#   → GARCH | index 750 | vol: 0.01140
#   → GARCH | index 1000 | vol: 0.01222
#   → GARCH | index 1250 | vol: 0.02332
#   → GARCH | index 1500 | vol: 0.01743
#   → GARCH | index 1750 | vol: 0.01688
# ✅ GARCH for PNC — R²: 0.6839, RMSE: 0.0058, MAE: 0.0037
#
# ================= PNC - GJR =================
#
# 🔮 Running GJR for PNC...
#   → GJR | index 500 | vol: 0.01222
#   → GJR | index 750 | vol: 0.01175
#   → GJR | index 1000 | vol: 0.01148
#   → GJR | index 1250 | vol: 0.02059
#   → GJR | index 1500 | vol: 0.01777
#   → GJR | index 1750 | vol: 0.01623
# ✅ GJR for PNC — R²: 0.5434, RMSE: 0.0070, MAE: 0.0043
#
# ================= PNC - EGARCH =================
#
# 🔮 Running EGARCH for PNC...
#   → EGARCH | index 500 | vol: 0.01221
#   → EGARCH | index 750 | vol: 0.01146
#   → EGARCH | index 1000 | vol: 0.01268
#   → EGARCH | index 1250 | vol: 0.02562
#   → EGARCH | index 1500 | vol: 0.01874
#   → EGARCH | index 1750 | vol: 0.01685
# ✅ EGARCH for PNC — R²: 0.7194, RMSE: 0.0055, MAE: 0.0036
#
# ================= BMO - GARCH =================
#
# 🔮 Running GARCH for BMO...
#   → GARCH | index 500 | vol: 0.01315
#   → GARCH | index 750 | vol: 0.00765
#   → GARCH | index 1000 | vol: 0.00761
#   → GARCH | index 1250 | vol: 0.01291
#   → GARCH | index 1500 | vol: 0.01362
#   → GARCH | index 1750 | vol: 0.01268
# ✅ GARCH for BMO — R²: 0.6444, RMSE: 0.0060, MAE: 0.0027
#
# ================= BMO - GJR =================
#
# 🔮 Running GJR for BMO...
#   → GJR | index 500 | vol: 0.01498
#   → GJR | index 750 | vol: 0.00769
#   → GJR | index 1000 | vol: 0.00794
#   → GJR | index 1250 | vol: 0.01235
#   → GJR | index 1500 | vol: 0.01318
#   → GJR | index 1750 | vol: 0.01289
# ✅ GJR for BMO — R²: 0.6046, RMSE: 0.0063, MAE: 0.0030
#
# ================= BMO - EGARCH =================
#
# 🔮 Running EGARCH for BMO...
#   → EGARCH | index 500 | vol: 0.01166
#   → EGARCH | index 750 | vol: 0.00773
#   → EGARCH | index 1000 | vol: 0.00766
#   → EGARCH | index 1250 | vol: 0.01404
#   → EGARCH | index 1500 | vol: 0.01533
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 1750 | vol: 0.01337
# ✅ EGARCH for BMO — R²: -23.3702, RMSE: 0.0494, MAE: 0.0057
#
# ================= STT - GARCH =================
#
# 🔮 Running GARCH for STT...
#   → GARCH | index 500 | vol: 0.02045
#   → GARCH | index 750 | vol: 0.01185
#   → GARCH | index 1000 | vol: 0.01693
#   → GARCH | index 1250 | vol: 0.02242
#   → GARCH | index 1500 | vol: 0.02108
#   → GARCH | index 1750 | vol: 0.02460
# ✅ GARCH for STT — R²: 0.3840, RMSE: 0.0079, MAE: 0.0048
#
# ================= STT - GJR =================
#
# 🔮 Running GJR for STT...
#   → GJR | index 500 | vol: 0.02203
#   → GJR | index 750 | vol: 0.01238
#   → GJR | index 1000 | vol: 0.01686
#   → GJR | index 1250 | vol: 0.02245
#   → GJR | index 1500 | vol: 0.02186
#   → GJR | index 1750 | vol: 0.01871
# ✅ GJR for STT — R²: 0.3471, RMSE: 0.0081, MAE: 0.0050
#
# ================= STT - EGARCH =================
#
# 🔮 Running EGARCH for STT...
#   → EGARCH | index 500 | vol: 0.01968
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 750 | vol: 0.01625
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 1000 | vol: 0.01785
#   → EGARCH | index 1250 | vol: 0.02362
#   → EGARCH | index 1500 | vol: 0.02166
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 1750 | vol: 0.02236
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# ✅ EGARCH for STT — R²: -1912724400272633579878880521499081567555923300122595609976021582348956225540161757799846233176851099247935724551237783070927009221227122730860823691614571862897947012940381048359246154956800.0000, RMSE: 439977145944921002444778670180095309364215941403883048833823181322453707878212674630541377536.0000, MAE: 11440527021158815471528765186462279848246366163780774238004829039214598909805770891969167360.0000
#
# ================= HSBC - GARCH =================
#
# 🔮 Running GARCH for HSBC...
#   → GARCH | index 500 | vol: 0.01235
#   → GARCH | index 750 | vol: 0.00942
#   → GARCH | index 1000 | vol: 0.01050
#   → GARCH | index 1250 | vol: 0.02186
#   → GARCH | index 1500 | vol: 0.01624
#   → GARCH | index 1750 | vol: 0.01508
# ✅ GARCH for HSBC — R²: 0.8060, RMSE: 0.0030, MAE: 0.0023
#
# ================= HSBC - GJR =================
#
# 🔮 Running GJR for HSBC...
#   → GJR | index 500 | vol: 0.01095
#   → GJR | index 750 | vol: 0.00942
#   → GJR | index 1000 | vol: 0.01073
#   → GJR | index 1250 | vol: 0.01990
#   → GJR | index 1500 | vol: 0.01406
#   → GJR | index 1750 | vol: 0.01320
# ✅ GJR for HSBC — R²: 0.8021, RMSE: 0.0031, MAE: 0.0024
#
# ================= HSBC - EGARCH =================
#
# 🔮 Running EGARCH for HSBC...
#   → EGARCH | index 500 | vol: 0.01057
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 750 | vol: 0.00988
#   → EGARCH | index 1000 | vol: 0.01080
#   → EGARCH | index 1250 | vol: 0.02132
#   → EGARCH | index 1500 | vol: 0.01628
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 1750 | vol: 0.01497
# ✅ EGARCH for HSBC — R²: -17.3948, RMSE: 0.0294, MAE: 0.0061
#
# ================= AXP - GARCH =================
#
# 🔮 Running GARCH for AXP...
#   → GARCH | index 500 | vol: 0.03067
#   → GARCH | index 750 | vol: 0.00895
#   → GARCH | index 1000 | vol: 0.01328
#   → GARCH | index 1250 | vol: 0.02742
#   → GARCH | index 1500 | vol: 0.02953
#   → GARCH | index 1750 | vol: 0.02388
# ✅ GARCH for AXP — R²: 0.6768, RMSE: 0.0070, MAE: 0.0042
#
# ================= AXP - GJR =================
#
# 🔮 Running GJR for AXP...
#   → GJR | index 500 | vol: 0.03085
#   → GJR | index 750 | vol: 0.00931
#   → GJR | index 1000 | vol: 0.01343
#   → GJR | index 1250 | vol: 0.02338
#   → GJR | index 1500 | vol: 0.01913
#   → GJR | index 1750 | vol: 0.01678
# ✅ GJR for AXP — R²: 0.6140, RMSE: 0.0077, MAE: 0.0045
#
# ================= AXP - EGARCH =================
#
# 🔮 Running EGARCH for AXP...
#   → EGARCH | index 500 | vol: 0.02387
#   → EGARCH | index 750 | vol: 0.00904
#   → EGARCH | index 1000 | vol: 0.01365
#   → EGARCH | index 1250 | vol: 0.02968
#   → EGARCH | index 1500 | vol: 0.02867
#   → EGARCH | index 1750 | vol: 0.02436
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# ✅ EGARCH for AXP — R²: -.0000, RMSE: 3486371742959041454324793795805067686438143134305763550918874898502141879987755441050061922360026488757295159676902509632595979734182158165936374284288.0000, MAE: 90654549898190915052088386537480954908024922000888963292783890544937789872304737182796420105679178602761153012516494437883609947589781552543960137728.0000
#
# ================= FITB - GARCH =================
#
# 🔮 Running GARCH for FITB...
#   → GARCH | index 500 | vol: 0.01833
#   → GARCH | index 750 | vol: 0.01317
#   → GARCH | index 1000 | vol: 0.01539
#   → GARCH | index 1250 | vol: 0.02847
#   → GARCH | index 1500 | vol: 0.02161
#   → GARCH | index 1750 | vol: 0.01814
# ✅ GARCH for FITB — R²: 0.6310, RMSE: 0.0081, MAE: 0.0049
#
# ================= FITB - GJR =================
#
# 🔮 Running GJR for FITB...
#   → GJR | index 500 | vol: 0.01766
#   → GJR | index 750 | vol: 0.01322
#   → GJR | index 1000 | vol: 0.01552
#   → GJR | index 1250 | vol: 0.02499
#   → GJR | index 1500 | vol: 0.02053
#   → GJR | index 1750 | vol: 0.01782
# ✅ GJR for FITB — R²: 0.4964, RMSE: 0.0095, MAE: 0.0055
#
# ================= FITB - EGARCH =================
#
# 🔮 Running EGARCH for FITB...
#   → EGARCH | index 500 | vol: 0.01719
#   → EGARCH | index 750 | vol: 0.01351
#   → EGARCH | index 1000 | vol: 0.01585
#   → EGARCH | index 1250 | vol: 0.03176
#   → EGARCH | index 1500 | vol: 0.02111
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 1750 | vol: 0.01823
# ✅ EGARCH for FITB — R²: 0.7327, RMSE: 0.0069, MAE: 0.0045
#
# ================= MTB - GARCH =================
#
# 🔮 Running GARCH for MTB...
#   → GARCH | index 500 | vol: 0.01542
#   → GARCH | index 750 | vol: 0.01387
#   → GARCH | index 1000 | vol: 0.01370
#   → GARCH | index 1250 | vol: 0.02472
#   → GARCH | index 1500 | vol: 0.02372
#   → GARCH | index 1750 | vol: 0.01995
# ✅ GARCH for MTB — R²: 0.6418, RMSE: 0.0067, MAE: 0.0042
#
# ================= MTB - GJR =================
#
# 🔮 Running GJR for MTB...
#   → GJR | index 500 | vol: 0.01497
#   → GJR | index 750 | vol: 0.01162
#   → GJR | index 1000 | vol: 0.01275
#   → GJR | index 1250 | vol: 0.02400
#   → GJR | index 1500 | vol: 0.02398
#   → GJR | index 1750 | vol: 0.01975
# ✅ GJR for MTB — R²: 0.6425, RMSE: 0.0067, MAE: 0.0043
#
# ================= MTB - EGARCH =================
#
# 🔮 Running EGARCH for MTB...
#   → EGARCH | index 500 | vol: 0.01484
#   → EGARCH | index 750 | vol: 0.01418
#   → EGARCH | index 1000 | vol: 0.01389
#   → EGARCH | index 1250 | vol: 0.02742
#   → EGARCH | index 1500 | vol: 0.02690
#   → EGARCH | index 1750 | vol: 0.02022
# ✅ EGARCH for MTB — R²: 0.7108, RMSE: 0.0060, MAE: 0.0039
# 💾 Saved time series model results to ts_model_results.csv
#    Stock   Model             R2           RMSE            MSE            MAE
# 24  HSBC   GARCH   8.060000e-01   3.000000e-03   9.000000e-06   2.300000e-03
# 25  HSBC     GJR   8.021000e-01   3.100000e-03   9.000000e-06   2.400000e-03
# 9     GS   GARCH   7.639000e-01   4.400000e-03   2.000000e-05   2.900000e-03
# 5    BAC  EGARCH   7.473000e-01   5.200000e-03   2.700000e-05   3.500000e-03
# 10    GS     GJR   7.466000e-01   4.600000e-03   2.100000e-05   3.000000e-03
# 2    JPM  EGARCH   7.428000e-01   5.100000e-03   2.600000e-05   3.200000e-03
# 32  FITB  EGARCH   7.327000e-01   6.900000e-03   4.800000e-05   4.500000e-03
# 3    BAC   GARCH   7.226000e-01   5.400000e-03   3.000000e-05   3.600000e-03
# 17   PNC  EGARCH   7.194000e-01   5.500000e-03   3.000000e-05   3.600000e-03
# 35   MTB  EGARCH   7.108000e-01   6.000000e-03   3.600000e-05   3.900000e-03
# 0    JPM   GARCH   6.922000e-01   5.500000e-03   3.100000e-05   3.300000e-03
# 1    JPM     GJR   6.877000e-01   5.600000e-03   3.100000e-05   3.500000e-03
# 15   PNC   GARCH   6.839000e-01   5.800000e-03   3.400000e-05   3.700000e-03
# 27   AXP   GARCH   6.768000e-01   7.000000e-03   4.900000e-05   4.200000e-03
# 4    BAC     GJR   6.754000e-01   5.900000e-03   3.500000e-05   4.000000e-03
# 14    MS  EGARCH   6.602000e-01   5.800000e-03   3.400000e-05   3.300000e-03
# 6    WFC   GARCH   6.586000e-01   6.400000e-03   4.000000e-05   4.000000e-03
# 18   BMO   GARCH   6.444000e-01   6.000000e-03   3.600000e-05   2.700000e-03
# 34   MTB     GJR   6.425000e-01   6.700000e-03   4.500000e-05   4.300000e-03
# 33   MTB   GARCH   6.418000e-01   6.700000e-03   4.500000e-05   4.200000e-03
# 30  FITB   GARCH   6.310000e-01   8.100000e-03   6.600000e-05   4.900000e-03
# 28   AXP     GJR   6.140000e-01   7.700000e-03   5.900000e-05   4.500000e-03
# 19   BMO     GJR   6.046000e-01   6.300000e-03   4.000000e-05   3.000000e-03
# 12    MS   GARCH   5.941000e-01   6.400000e-03   4.100000e-05   3.500000e-03
# 7    WFC     GJR   5.573000e-01   7.200000e-03   5.200000e-05   4.300000e-03
# 8    WFC  EGARCH   5.503000e-01   7.300000e-03   5.300000e-05   4.300000e-03
# 16   PNC     GJR   5.434000e-01   7.000000e-03   4.900000e-05   4.300000e-03
# 13    MS     GJR   5.313000e-01   6.800000e-03   4.700000e-05   3.700000e-03
# 31  FITB     GJR   4.964000e-01   9.500000e-03   9.000000e-05   5.500000e-03
# 21   STT   GARCH   3.840000e-01   7.900000e-03   6.200000e-05   4.800000e-03
# 22   STT     GJR   3.471000e-01   8.100000e-03   6.600000e-05   5.000000e-03
# 11    GS  EGARCH   1.570000e-01   8.400000e-03   7.000000e-05   3.900000e-03
# 26  HSBC  EGARCH  -1.739480e+01   2.940000e-02   8.660000e-04   6.100000e-03
# 20   BMO  EGARCH  -2.337020e+01   4.940000e-02   2.438000e-03   5.700000e-03
# 23   STT  EGARCH -1.912724e+189   4.399771e+92  1.935799e+185   1.144053e+91
# 29   AXP  EGARCH           -inf  3.486372e+150  1.215479e+301  9.065455e+148

# %%
def train_fusion_model(df, model_name, ts_feature="GARCH_pred", ticker="TICKER"):
    from sklearn.model_selection import train_test_split
    from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
    from sklearn.neighbors import KNeighborsRegressor
    from catboost import CatBoostRegressor
    from lightgbm import LGBMRegressor
    from xgboost import XGBRegressor

    models = {
        "KNN": KNeighborsRegressor(),
        "AdaBoost": AdaBoostRegressor(),
        "CatBoost": CatBoostRegressor(verbose=0),
        "XGBoost": XGBRegressor(verbosity=0),
        "RandomForest": RandomForestRegressor()
    }

    if model_name not in models:
        raise ValueError(f"Model '{model_name}' not recognized.")

    df = df.copy()

    # Flatten if needed
    if isinstance(df.columns, pd.MultiIndex):
        df.columns = ['_'.join([str(i) for i in col if i]) for col in df.columns]

    if ts_feature not in df.columns:
        raise ValueError(f"'{ts_feature}' not found in DataFrame for {ticker}")

    feature_cols = [
        'RSI', 'MOM', 'OBV', 'MACD_LINE', 'MACD_SIGNAL', 'MACD_HIST',
        'STO_K', 'STO_D', 'Vol_t_1', 'Vol_t_2', 'Vol_t_3',
        'Vol_t_4', 'Vol_t_5', 'Vol_t_6', ts_feature
    ]

    X = df[feature_cols].copy()
    y = df["Vol_target"]

    split_idx = int(len(df) * 0.7)
    X_train, X_test = X.iloc[:split_idx], X.iloc[split_idx:]
    y_train, y_test = y.iloc[:split_idx], y.iloc[split_idx:]

    model = models[model_name]
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    metrics = evaluate_series(y_test, y_pred)

    print(f"✅ {model_name} + {ts_feature} for {ticker} — R²: {metrics['R2']:.4f}, RMSE: {metrics['RMSE']:.4f}, MAE: {metrics['MAE']:.4f}")

    return metrics

# %%
import os
import pandas as pd

# Reuse existing forecast function
for ticker in tqdm(garch_data.keys()):
    for model_type in ["GJR", "EGARCH"]:
        print(f"\n📈 Adding {model_type}_pred to {ticker}...")
        df = garch_data[ticker]

        try:
            df, _ = forecast_volatility_arch(df, model_type=model_type, ticker=ticker, verbose=False)
            garch_data[ticker] = df  # Update with new column
        except Exception as e:
            print(f"⚠️ {model_type} failed for {ticker}: {e}")

def train_all_fusion_models(garch_data_dict, results_path="fusion_model_results.csv"):
    # Load existing results if file exists
    if os.path.exists(results_path):
        print(f"📦 Loading saved fusion model results from {results_path}...")
        return pd.read_csv(results_path)

    results = []

    for ticker, df in garch_data_dict.items():
        for ts_feature in ["GARCH_pred", "GJR_pred", "EGARCH_pred"]:
            if ts_feature not in df.columns:
                print(f"⚠️ Skipping {ticker} - missing {ts_feature}")
                continue

            for model_name in ["RandomForest", "XGBoost", "CatBoost", "AdaBoost", "KNN"]:
                try:
                    metrics = train_fusion_model(df, model_name, ts_feature=ts_feature, ticker=ticker)
                    results.append({
                        "Stock": ticker,
                        "Fusion_Model": f"{ts_feature}+{model_name}",
                        "R2": round(metrics["R2"], 4),
                        "RMSE": round(metrics["RMSE"], 4),
                        "MSE": round(metrics["MSE"], 6),
                        "MAE": round(metrics["MAE"], 4),
                    })
                except Exception as e:
                    print(f"⚠️ {ticker} {ts_feature}+{model_name} failed: {e}")

    fusion_df = pd.DataFrame(results)
    fusion_df.to_csv(results_path, index=False)
    print(f"💾 Saved fusion model results to {results_path}")

    return fusion_df

fusion_results_df = train_all_fusion_models(garch_data)
fusion_results_sorted = fusion_results_df.sort_values(by="R2", ascending=False)
display(fusion_results_sorted)
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
# 📈 Adding GJR_pred to JPM...
#
# 📈 Adding EGARCH_pred to JPM...
#   8%|▊         | 1/12 [00:33<06:05, 33.25s/it]
# 📈 Adding GJR_pred to BAC...
#
# 📈 Adding EGARCH_pred to BAC...
#  17%|█▋        | 2/12 [01:07<05:40, 34.01s/it]
# 📈 Adding GJR_pred to WFC...
#
# 📈 Adding EGARCH_pred to WFC...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  25%|██▌       | 3/12 [01:43<05:14, 35.00s/it]
# 📈 Adding GJR_pred to GS...
#
# 📈 Adding EGARCH_pred to GS...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  33%|███▎      | 4/12 [02:21<04:49, 36.17s/it]
# 📈 Adding GJR_pred to MS...
#
# 📈 Adding EGARCH_pred to MS...
#  42%|████▏     | 5/12 [02:56<04:08, 35.53s/it]
# 📈 Adding GJR_pred to PNC...
#
# 📈 Adding EGARCH_pred to PNC...
#  50%|█████     | 6/12 [03:29<03:27, 34.57s/it]
# 📈 Adding GJR_pred to BMO...
#
# 📈 Adding EGARCH_pred to BMO...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  58%|█████▊    | 7/12 [04:06<02:57, 35.50s/it]
# 📈 Adding GJR_pred to STT...
#
# 📈 Adding EGARCH_pred to STT...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  67%|██████▋   | 8/12 [04:43<02:24, 36.13s/it]
# 📈 Adding GJR_pred to HSBC...
#
# 📈 Adding EGARCH_pred to HSBC...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  75%|███████▌  | 9/12 [05:21<01:49, 36.54s/it]
# 📈 Adding GJR_pred to AXP...
#
# 📈 Adding EGARCH_pred to AXP...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  83%|████████▎ | 10/12 [05:57<01:12, 36.32s/it]
# 📈 Adding GJR_pred to FITB...
#
# 📈 Adding EGARCH_pred to FITB...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  92%|█████████▏| 11/12 [06:29<00:35, 35.12s/it]
# 📈 Adding GJR_pred to MTB...
#
# 📈 Adding EGARCH_pred to MTB...
# 100%|██████████| 12/12 [07:01<00:00, 35.12s/it]
# ✅ RandomForest + GARCH_pred for JPM — R²: 0.8409, RMSE: 0.0019, MAE: 0.0013
# ✅ XGBoost + GARCH_pred for JPM — R²: 0.7580, RMSE: 0.0023, MAE: 0.0017
# ✅ CatBoost + GARCH_pred for JPM — R²: 0.7518, RMSE: 0.0023, MAE: 0.0020
# ✅ AdaBoost + GARCH_pred for JPM — R²: 0.5750, RMSE: 0.0031, MAE: 0.0026
# ✅ KNN + GARCH_pred for JPM — R²: -3.4382, RMSE: 0.0099, MAE: 0.0081
# ✅ RandomForest + GJR_pred for JPM — R²: 0.8374, RMSE: 0.0019, MAE: 0.0013
# ✅ XGBoost + GJR_pred for JPM — R²: 0.7710, RMSE: 0.0022, MAE: 0.0016
# ✅ CatBoost + GJR_pred for JPM — R²: 0.7033, RMSE: 0.0026, MAE: 0.0022
# ✅ AdaBoost + GJR_pred for JPM — R²: 0.6130, RMSE: 0.0029, MAE: 0.0025
# ✅ KNN + GJR_pred for JPM — R²: -3.4382, RMSE: 0.0099, MAE: 0.0081
# ✅ RandomForest + EGARCH_pred for JPM — R²: 0.8498, RMSE: 0.0018, MAE: 0.0013
# ✅ XGBoost + EGARCH_pred for JPM — R²: 0.7867, RMSE: 0.0022, MAE: 0.0016
# ✅ CatBoost + EGARCH_pred for JPM — R²: 0.7406, RMSE: 0.0024, MAE: 0.0020
# ✅ AdaBoost + EGARCH_pred for JPM — R²: 0.3536, RMSE: 0.0038, MAE: 0.0033
# ✅ KNN + EGARCH_pred for JPM — R²: -3.4382, RMSE: 0.0099, MAE: 0.0081
# ✅ RandomForest + GARCH_pred for BAC — R²: 0.8485, RMSE: 0.0015, MAE: 0.0013
# ✅ XGBoost + GARCH_pred for BAC — R²: 0.5326, RMSE: 0.0027, MAE: 0.0021
# ✅ CatBoost + GARCH_pred for BAC — R²: 0.4801, RMSE: 0.0029, MAE: 0.0023
# ✅ AdaBoost + GARCH_pred for BAC — R²: 0.5510, RMSE: 0.0027, MAE: 0.0022
# ✅ KNN + GARCH_pred for BAC — R²: -38.3875, RMSE: 0.0249, MAE: 0.0204
# ✅ RandomForest + GJR_pred for BAC — R²: 0.8461, RMSE: 0.0016, MAE: 0.0013
# ✅ XGBoost + GJR_pred for BAC — R²: 0.6586, RMSE: 0.0023, MAE: 0.0018
# ✅ CatBoost + GJR_pred for BAC — R²: 0.4565, RMSE: 0.0029, MAE: 0.0023
# ✅ AdaBoost + GJR_pred for BAC — R²: 0.4838, RMSE: 0.0029, MAE: 0.0024
# ✅ KNN + GJR_pred for BAC — R²: -38.3875, RMSE: 0.0249, MAE: 0.0204
# ✅ RandomForest + EGARCH_pred for BAC — R²: 0.8278, RMSE: 0.0016, MAE: 0.0013
# ✅ XGBoost + EGARCH_pred for BAC — R²: 0.6200, RMSE: 0.0024, MAE: 0.0019
# ✅ CatBoost + EGARCH_pred for BAC — R²: 0.5461, RMSE: 0.0027, MAE: 0.0021
# ✅ AdaBoost + EGARCH_pred for BAC — R²: 0.5029, RMSE: 0.0028, MAE: 0.0023
# ✅ KNN + EGARCH_pred for BAC — R²: -38.3875, RMSE: 0.0249, MAE: 0.0204
# ✅ RandomForest + GARCH_pred for WFC — R²: 0.8548, RMSE: 0.0016, MAE: 0.0013
# ✅ XGBoost + GARCH_pred for WFC — R²: 0.7455, RMSE: 0.0022, MAE: 0.0017
# ✅ CatBoost + GARCH_pred for WFC — R²: 0.7013, RMSE: 0.0023, MAE: 0.0018
# ✅ AdaBoost + GARCH_pred for WFC — R²: 0.4791, RMSE: 0.0031, MAE: 0.0026
# ✅ KNN + GARCH_pred for WFC — R²: -1.4876, RMSE: 0.0068, MAE: 0.0060
# ✅ RandomForest + GJR_pred for WFC — R²: 0.8880, RMSE: 0.0014, MAE: 0.0011
# ✅ XGBoost + GJR_pred for WFC — R²: 0.8085, RMSE: 0.0019, MAE: 0.0014
# ✅ CatBoost + GJR_pred for WFC — R²: 0.7181, RMSE: 0.0023, MAE: 0.0017
# ✅ AdaBoost + GJR_pred for WFC — R²: 0.4055, RMSE: 0.0033, MAE: 0.0028
# ✅ KNN + GJR_pred for WFC — R²: -1.4876, RMSE: 0.0068, MAE: 0.0060
# ✅ RandomForest + EGARCH_pred for WFC — R²: 0.8910, RMSE: 0.0014, MAE: 0.0011
# ✅ XGBoost + EGARCH_pred for WFC — R²: 0.7983, RMSE: 0.0019, MAE: 0.0015
# ✅ CatBoost + EGARCH_pred for WFC — R²: 0.7472, RMSE: 0.0022, MAE: 0.0016
# ✅ AdaBoost + EGARCH_pred for WFC — R²: 0.6638, RMSE: 0.0025, MAE: 0.0021
# ✅ KNN + EGARCH_pred for WFC — R²: -1.4876, RMSE: 0.0068, MAE: 0.0060
# ✅ RandomForest + GARCH_pred for GS — R²: 0.7488, RMSE: 0.0013, MAE: 0.0009
# ✅ XGBoost + GARCH_pred for GS — R²: 0.6800, RMSE: 0.0015, MAE: 0.0011
# ✅ CatBoost + GARCH_pred for GS — R²: 0.5401, RMSE: 0.0018, MAE: 0.0014
# ✅ AdaBoost + GARCH_pred for GS — R²: 0.4595, RMSE: 0.0019, MAE: 0.0015
# ✅ KNN + GARCH_pred for GS — R²: -10.6423, RMSE: 0.0089, MAE: 0.0069
# ✅ RandomForest + GJR_pred for GS — R²: 0.7535, RMSE: 0.0013, MAE: 0.0009
# ✅ XGBoost + GJR_pred for GS — R²: 0.6420, RMSE: 0.0016, MAE: 0.0012
# ✅ CatBoost + GJR_pred for GS — R²: 0.5166, RMSE: 0.0018, MAE: 0.0014
# ✅ AdaBoost + GJR_pred for GS — R²: 0.3229, RMSE: 0.0021, MAE: 0.0016
# ✅ KNN + GJR_pred for GS — R²: -10.6423, RMSE: 0.0089, MAE: 0.0069
# ✅ RandomForest + EGARCH_pred for GS — R²: 0.7790, RMSE: 0.0012, MAE: 0.0009
# ✅ XGBoost + EGARCH_pred for GS — R²: 0.6240, RMSE: 0.0016, MAE: 0.0012
# ✅ CatBoost + EGARCH_pred for GS — R²: 0.5344, RMSE: 0.0018, MAE: 0.0014
# ✅ AdaBoost + EGARCH_pred for GS — R²: 0.5001, RMSE: 0.0018, MAE: 0.0014
# ✅ KNN + EGARCH_pred for GS — R²: -10.6423, RMSE: 0.0089, MAE: 0.0069
# ✅ RandomForest + GARCH_pred for MS — R²: 0.8153, RMSE: 0.0015, MAE: 0.0010
# ✅ XGBoost + GARCH_pred for MS — R²: 0.7902, RMSE: 0.0016, MAE: 0.0010
# ✅ CatBoost + GARCH_pred for MS — R²: 0.6322, RMSE: 0.0021, MAE: 0.0015
# ✅ AdaBoost + GARCH_pred for MS — R²: 0.7219, RMSE: 0.0018, MAE: 0.0011
# ✅ KNN + GARCH_pred for MS — R²: -1.2685, RMSE: 0.0052, MAE: 0.0043
# ✅ RandomForest + GJR_pred for MS — R²: 0.8194, RMSE: 0.0015, MAE: 0.0010
# ✅ XGBoost + GJR_pred for MS — R²: 0.7898, RMSE: 0.0016, MAE: 0.0011
# ✅ CatBoost + GJR_pred for MS — R²: 0.6075, RMSE: 0.0022, MAE: 0.0015
# ✅ AdaBoost + GJR_pred for MS — R²: 0.7239, RMSE: 0.0018, MAE: 0.0012
# ✅ KNN + GJR_pred for MS — R²: -1.2685, RMSE: 0.0052, MAE: 0.0043
# ✅ RandomForest + EGARCH_pred for MS — R²: 0.8232, RMSE: 0.0015, MAE: 0.0010
# ✅ XGBoost + EGARCH_pred for MS — R²: 0.7753, RMSE: 0.0016, MAE: 0.0011
# ✅ CatBoost + EGARCH_pred for MS — R²: 0.6390, RMSE: 0.0021, MAE: 0.0015
# ✅ AdaBoost + EGARCH_pred for MS — R²: 0.6742, RMSE: 0.0020, MAE: 0.0013
# ✅ KNN + EGARCH_pred for MS — R²: -1.2685, RMSE: 0.0052, MAE: 0.0043
# ✅ RandomForest + GARCH_pred for PNC — R²: 0.8770, RMSE: 0.0014, MAE: 0.0010
# ✅ XGBoost + GARCH_pred for PNC — R²: 0.8375, RMSE: 0.0016, MAE: 0.0011
# ✅ CatBoost + GARCH_pred for PNC — R²: 0.8492, RMSE: 0.0015, MAE: 0.0011
# ✅ AdaBoost + GARCH_pred for PNC — R²: 0.6969, RMSE: 0.0021, MAE: 0.0016
# ✅ KNN + GARCH_pred for PNC — R²: -5.5188, RMSE: 0.0098, MAE: 0.0071
# ✅ RandomForest + GJR_pred for PNC — R²: 0.8746, RMSE: 0.0014, MAE: 0.0010
# ✅ XGBoost + GJR_pred for PNC — R²: 0.8545, RMSE: 0.0015, MAE: 0.0011
# ✅ CatBoost + GJR_pred for PNC — R²: 0.8429, RMSE: 0.0015, MAE: 0.0011
# ✅ AdaBoost + GJR_pred for PNC — R²: 0.7277, RMSE: 0.0020, MAE: 0.0015
# ✅ KNN + GJR_pred for PNC — R²: -5.5188, RMSE: 0.0098, MAE: 0.0071
# ✅ RandomForest + EGARCH_pred for PNC — R²: 0.8727, RMSE: 0.0014, MAE: 0.0010
# ✅ XGBoost + EGARCH_pred for PNC — R²: 0.8505, RMSE: 0.0015, MAE: 0.0010
# ✅ CatBoost + EGARCH_pred for PNC — R²: 0.8488, RMSE: 0.0015, MAE: 0.0012
# ✅ AdaBoost + EGARCH_pred for PNC — R²: 0.6452, RMSE: 0.0023, MAE: 0.0017
# ✅ KNN + EGARCH_pred for PNC — R²: -5.5188, RMSE: 0.0098, MAE: 0.0071
# ✅ RandomForest + GARCH_pred for BMO — R²: 0.9169, RMSE: 0.0009, MAE: 0.0007
# ✅ XGBoost + GARCH_pred for BMO — R²: 0.9073, RMSE: 0.0009, MAE: 0.0007
# ✅ CatBoost + GARCH_pred for BMO — R²: 0.7868, RMSE: 0.0014, MAE: 0.0011
# ✅ AdaBoost + GARCH_pred for BMO — R²: 0.7219, RMSE: 0.0016, MAE: 0.0013
# ✅ KNN + GARCH_pred for BMO — R²: -1.0199, RMSE: 0.0043, MAE: 0.0038
# ✅ RandomForest + GJR_pred for BMO — R²: 0.9141, RMSE: 0.0009, MAE: 0.0007
# ✅ XGBoost + GJR_pred for BMO — R²: 0.8992, RMSE: 0.0010, MAE: 0.0007
# ✅ CatBoost + GJR_pred for BMO — R²: 0.7529, RMSE: 0.0015, MAE: 0.0012
# ✅ AdaBoost + GJR_pred for BMO — R²: 0.6816, RMSE: 0.0017, MAE: 0.0014
# ✅ KNN + GJR_pred for BMO — R²: -1.0199, RMSE: 0.0043, MAE: 0.0038
# ✅ RandomForest + EGARCH_pred for BMO — R²: 0.9176, RMSE: 0.0009, MAE: 0.0007
# ✅ XGBoost + EGARCH_pred for BMO — R²: 0.9040, RMSE: 0.0009, MAE: 0.0007
# ✅ CatBoost + EGARCH_pred for BMO — R²: 0.7935, RMSE: 0.0014, MAE: 0.0010
# ✅ AdaBoost + EGARCH_pred for BMO — R²: 0.7613, RMSE: 0.0015, MAE: 0.0012
# ✅ KNN + EGARCH_pred for BMO — R²: -1.0199, RMSE: 0.0043, MAE: 0.0038
# ✅ RandomForest + GARCH_pred for STT — R²: 0.8498, RMSE: 0.0025, MAE: 0.0016
# ✅ XGBoost + GARCH_pred for STT — R²: 0.8180, RMSE: 0.0027, MAE: 0.0018
# ✅ CatBoost + GARCH_pred for STT — R²: 0.8077, RMSE: 0.0028, MAE: 0.0019
# ✅ AdaBoost + GARCH_pred for STT — R²: 0.7778, RMSE: 0.0030, MAE: 0.0023
# ✅ KNN + GARCH_pred for STT — R²: -3.1754, RMSE: 0.0130, MAE: 0.0107
# ✅ RandomForest + GJR_pred for STT — R²: 0.8459, RMSE: 0.0025, MAE: 0.0016
# ✅ XGBoost + GJR_pred for STT — R²: 0.7945, RMSE: 0.0029, MAE: 0.0020
# ✅ CatBoost + GJR_pred for STT — R²: 0.8048, RMSE: 0.0028, MAE: 0.0020
# ✅ AdaBoost + GJR_pred for STT — R²: 0.7536, RMSE: 0.0032, MAE: 0.0025
# ✅ KNN + GJR_pred for STT — R²: -3.1754, RMSE: 0.0130, MAE: 0.0107
# ⚠️ STT EGARCH_pred+RandomForest failed: Input X contains infinity or a value too large for dtype('float32').
# ✅ XGBoost + EGARCH_pred for STT — R²: 0.8120, RMSE: 0.0028, MAE: 0.0020
# ✅ CatBoost + EGARCH_pred for STT — R²: 0.7735, RMSE: 0.0030, MAE: 0.0021
# ⚠️ STT EGARCH_pred+AdaBoost failed: Input X contains infinity or a value too large for dtype('float32').
# ✅ KNN + EGARCH_pred for STT — R²: -3.1951, RMSE: 0.0131, MAE: 0.0108
# ✅ RandomForest + GARCH_pred for HSBC — R²: 0.8572, RMSE: 0.0016, MAE: 0.0013
# ✅ XGBoost + GARCH_pred for HSBC — R²: 0.8160, RMSE: 0.0019, MAE: 0.0015
# ✅ CatBoost + GARCH_pred for HSBC — R²: 0.7325, RMSE: 0.0022, MAE: 0.0018
# ✅ AdaBoost + GARCH_pred for HSBC — R²: 0.7837, RMSE: 0.0020, MAE: 0.0016
# ✅ KNN + GARCH_pred for HSBC — R²: -3.3968, RMSE: 0.0091, MAE: 0.0081
# ✅ RandomForest + GJR_pred for HSBC — R²: 0.8595, RMSE: 0.0016, MAE: 0.0013
# ✅ XGBoost + GJR_pred for HSBC — R²: 0.8084, RMSE: 0.0019, MAE: 0.0015
# ✅ CatBoost + GJR_pred for HSBC — R²: 0.7829, RMSE: 0.0020, MAE: 0.0016
# ✅ AdaBoost + GJR_pred for HSBC — R²: 0.7561, RMSE: 0.0021, MAE: 0.0017
# ✅ KNN + GJR_pred for HSBC — R²: -3.3968, RMSE: 0.0091, MAE: 0.0081
# ✅ RandomForest + EGARCH_pred for HSBC — R²: 0.8567, RMSE: 0.0016, MAE: 0.0014
# ✅ XGBoost + EGARCH_pred for HSBC — R²: 0.8556, RMSE: 0.0017, MAE: 0.0014
# ✅ CatBoost + EGARCH_pred for HSBC — R²: 0.7589, RMSE: 0.0021, MAE: 0.0017
# ✅ AdaBoost + EGARCH_pred for HSBC — R²: 0.7898, RMSE: 0.0020, MAE: 0.0017
# ✅ KNN + EGARCH_pred for HSBC — R²: -3.3968, RMSE: 0.0091, MAE: 0.0081
# ✅ RandomForest + GARCH_pred for AXP — R²: 0.7452, RMSE: 0.0022, MAE: 0.0015
# ✅ XGBoost + GARCH_pred for AXP — R²: 0.4824, RMSE: 0.0032, MAE: 0.0020
# ✅ CatBoost + GARCH_pred for AXP — R²: 0.6546, RMSE: 0.0026, MAE: 0.0020
# ✅ AdaBoost + GARCH_pred for AXP — R²: 0.2460, RMSE: 0.0038, MAE: 0.0032
# ✅ KNN + GARCH_pred for AXP — R²: -17.3848, RMSE: 0.0188, MAE: 0.0155
# ✅ RandomForest + GJR_pred for AXP — R²: 0.7852, RMSE: 0.0020, MAE: 0.0014
# ✅ XGBoost + GJR_pred for AXP — R²: 0.5359, RMSE: 0.0030, MAE: 0.0020
# ✅ CatBoost + GJR_pred for AXP — R²: 0.5732, RMSE: 0.0029, MAE: 0.0022
# ✅ AdaBoost + GJR_pred for AXP — R²: 0.2604, RMSE: 0.0038, MAE: 0.0031
# ✅ KNN + GJR_pred for AXP — R²: -17.3848, RMSE: 0.0188, MAE: 0.0155
# ⚠️ AXP EGARCH_pred+RandomForest failed: Input X contains infinity or a value too large for dtype('float32').
# ✅ XGBoost + EGARCH_pred for AXP — R²: 0.5099, RMSE: 0.0031, MAE: 0.0020
# ✅ CatBoost + EGARCH_pred for AXP — R²: 0.5957, RMSE: 0.0028, MAE: 0.0021
# ⚠️ AXP EGARCH_pred+AdaBoost failed: Input X contains infinity or a value too large for dtype('float32').
# ✅ KNN + EGARCH_pred for AXP — R²: -17.3954, RMSE: 0.0188, MAE: 0.0155
# ✅ RandomForest + GARCH_pred for FITB — R²: 0.9001, RMSE: 0.0021, MAE: 0.0013
# ✅ XGBoost + GARCH_pred for FITB — R²: 0.8700, RMSE: 0.0023, MAE: 0.0017
# ✅ CatBoost + GARCH_pred for FITB — R²: 0.8325, RMSE: 0.0027, MAE: 0.0021
# ✅ AdaBoost + GARCH_pred for FITB — R²: 0.8362, RMSE: 0.0026, MAE: 0.0021
# ✅ KNN + GARCH_pred for FITB — R²: -0.1679, RMSE: 0.0070, MAE: 0.0059
# ✅ RandomForest + GJR_pred for FITB — R²: 0.8967, RMSE: 0.0021, MAE: 0.0013
# ✅ XGBoost + GJR_pred for FITB — R²: 0.8656, RMSE: 0.0024, MAE: 0.0017
# ✅ CatBoost + GJR_pred for FITB — R²: 0.8292, RMSE: 0.0027, MAE: 0.0021
# ✅ AdaBoost + GJR_pred for FITB — R²: 0.8154, RMSE: 0.0028, MAE: 0.0022
# ✅ KNN + GJR_pred for FITB — R²: -0.1679, RMSE: 0.0070, MAE: 0.0059
# ✅ RandomForest + EGARCH_pred for FITB — R²: 0.8935, RMSE: 0.0021, MAE: 0.0014
# ✅ XGBoost + EGARCH_pred for FITB — R²: 0.8480, RMSE: 0.0025, MAE: 0.0018
# ✅ CatBoost + EGARCH_pred for FITB — R²: 0.8091, RMSE: 0.0028, MAE: 0.0023
# ✅ AdaBoost + EGARCH_pred for FITB — R²: 0.8106, RMSE: 0.0028, MAE: 0.0022
# ✅ KNN + EGARCH_pred for FITB — R²: -0.1679, RMSE: 0.0070, MAE: 0.0059
# ✅ RandomForest + GARCH_pred for MTB — R²: 0.8359, RMSE: 0.0020, MAE: 0.0013
# ✅ XGBoost + GARCH_pred for MTB — R²: 0.8094, RMSE: 0.0022, MAE: 0.0016
# ✅ CatBoost + GARCH_pred for MTB — R²: 0.7775, RMSE: 0.0024, MAE: 0.0017
# ✅ AdaBoost + GARCH_pred for MTB — R²: 0.6698, RMSE: 0.0029, MAE: 0.0022
# ✅ KNN + GARCH_pred for MTB — R²: -23.2130, RMSE: 0.0249, MAE: 0.0211
# ✅ RandomForest + GJR_pred for MTB — R²: 0.8488, RMSE: 0.0020, MAE: 0.0012
# ✅ XGBoost + GJR_pred for MTB — R²: 0.8282, RMSE: 0.0021, MAE: 0.0014
# ✅ CatBoost + GJR_pred for MTB — R²: 0.7848, RMSE: 0.0023, MAE: 0.0017
# ✅ AdaBoost + GJR_pred for MTB — R²: 0.7288, RMSE: 0.0026, MAE: 0.0020
# ✅ KNN + GJR_pred for MTB — R²: -23.2130, RMSE: 0.0249, MAE: 0.0211
# ✅ RandomForest + EGARCH_pred for MTB — R²: 0.8398, RMSE: 0.0020, MAE: 0.0013
# ✅ XGBoost + EGARCH_pred for MTB — R²: 0.8110, RMSE: 0.0022, MAE: 0.0016
# ✅ CatBoost + EGARCH_pred for MTB — R²: 0.7919, RMSE: 0.0023, MAE: 0.0017
# ✅ AdaBoost + EGARCH_pred for MTB — R²: 0.6621, RMSE: 0.0029, MAE: 0.0023
# ✅ KNN + EGARCH_pred for MTB — R²: -23.2130, RMSE: 0.0249, MAE: 0.0211
# 💾 Saved fusion model results to fusion_model_results.csv
#     Stock              Fusion_Model       R2    RMSE       MSE     MAE
# 100   BMO  EGARCH_pred+RandomForest   0.9176  0.0009  0.000001  0.0007
# 90    BMO   GARCH_pred+RandomForest   0.9169  0.0009  0.000001  0.0007
# 95    BMO     GJR_pred+RandomForest   0.9141  0.0009  0.000001  0.0007
# 91    BMO        GARCH_pred+XGBoost   0.9073  0.0009  0.000001  0.0007
# 101   BMO       EGARCH_pred+XGBoost   0.9040  0.0009  0.000001  0.0007
# ..    ...                       ...      ...     ...       ...     ...
# 170   MTB              GJR_pred+KNN -23.2130  0.0249  0.000619  0.0211
# 175   MTB           EGARCH_pred+KNN -23.2130  0.0249  0.000619  0.0211
# 19    BAC            GARCH_pred+KNN -38.3875  0.0249  0.000621  0.0204
# 24    BAC              GJR_pred+KNN -38.3875  0.0249  0.000621  0.0204
# 29    BAC           EGARCH_pred+KNN -38.3875  0.0249  0.000621  0.0204
#
# [176 rows x 6 columns]
