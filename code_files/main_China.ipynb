# %%
import yfinance as yf
import pandas as pd
import numpy as np
from ta.momentum import RSIIndicator, StochasticOscillator
from ta.trend import MACD
from tqdm import tqdm

# Ticker symbols for the 12 stocks
tickers = [
    "601398.SS", "601988.SS", "601939.SS", "601288.SS", "600036.SS",
    "601328.SS", "601318.SS", "601628.SS", "601601.SS", "600016.SS",
    "601688.SS", "000776.SZ"
]

# Download historical OHLCV from 2014-01-01 to 2023-12-31
def download_data(ticker):
    data = yf.download(ticker, start="2014-01-01", end="2023-12-31")
    data = data.dropna()
    return data

stock_data = {ticker: download_data(ticker) for ticker in tqdm(tickers)}
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# 100%|██████████| 12/12 [00:04<00:00,  2.42it/s]

# %%
def compute_features(df):
    df = df.copy()

    # Ensure Close, High, Low are Series (1D)
    close = df["Close"].squeeze()
    high = df["High"].squeeze()
    low = df["Low"].squeeze()
    volume = df["Volume"].squeeze()

    print(f"Close dtype: {type(close)}, shape: {close.shape}")

    # Daily return
    df["Return"] = close.pct_change()

    # 30-day rolling volatility (target)
    df["Volatility"] = df["Return"].rolling(window=30).std()

    # RSI (14 days)
    df["RSI"] = RSIIndicator(close=close, window=14).rsi()

    # Momentum (5 days)
    df["MOM"] = close - close.shift(5)

    # OBV
    df["OBV"] = (np.sign(close.diff()) * volume).fillna(0).cumsum()

    # MACD
    macd = MACD(close=close, window_slow=26, window_fast=12, window_sign=9)
    df["MACD_LINE"] = macd.macd()
    df["MACD_SIGNAL"] = macd.macd_signal()
    df["MACD_HIST"] = macd.macd_diff()

    # Stochastic Oscillator
    stoch = StochasticOscillator(high=high, low=low, close=close, window=14, smooth_window=3)
    df["STO_K"] = stoch.stoch()           # formerly %K
    df["STO_D"] = stoch.stoch_signal()    # formerly %D

    # Lagged volatilities (t-1 to t-6)
    for i in range(1, 7):
        df[f"Vol_t_{i}"] = df["Volatility"].shift(i)

    # Volatility t+1 (our target)
    df["Vol_target"] = df["Volatility"].shift(-1)

    # Drop rows with NaNs
    df = df.dropna()

    return df

# %%
import os
import pickle

feature_data = {}
for ticker in tqdm(tickers):
    feature_data[ticker] = compute_features(stock_data[ticker])

feature_data_path = "china_feature_data.pkl"

if os.path.exists(feature_data_path):
    print("📦 Loading saved feature data from china_feature_data.pkl...")
    with open(feature_data_path, "rb") as f:
        feature_data = pickle.load(f)
else:
    print("⚙️ Computing feature data...")
    feature_data = {ticker: compute_features(stock_data[ticker]) for ticker in tqdm(tickers)}
    with open(feature_data_path, "wb") as f:
        pickle.dump(feature_data, f)
    print("💾 Saved feature data to china_feature_data.pkl")
# Out:
# 100%|██████████| 12/12 [00:00<00:00, 80.49it/s]
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2432,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2432,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2432,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2432,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2432,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2432,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2432,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2432,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2432,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2432,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2432,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2432,)
# ⚙️ Computing feature data...
#   0%|          | 0/12 [00:00<?, ?it/s]
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2432,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2432,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2432,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2432,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2432,)
# 100%|██████████| 12/12 [00:00<00:00, 82.62it/s]
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2432,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2432,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2432,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2432,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2432,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2432,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2432,)
# 💾 Saved feature data to china_feature_data.pkl

# %%
from arch import arch_model
import warnings

def add_garch_predictions(df, ticker=None, verbose=True):
    df = df.copy()
    returns = df["Return"].dropna().values
    preds = []
    window_size = 500
    scale_factor = 100  # recommended by arch package

    if verbose:
        print(f"\n🔍 GARCH modeling for {ticker} — total points: {len(returns)}")

    for i in range(window_size, len(returns)):
        train_window = returns[i-window_size:i] * scale_factor  # rescale

        try:
            with warnings.catch_warnings():
                warnings.simplefilter("ignore")
                model = arch_model(train_window, vol='Garch', p=1, q=1, dist='normal', rescale=False)
                model_fit = model.fit(disp="off")
                forecast = model_fit.forecast(horizon=1)
                pred_vol_scaled = np.sqrt(forecast.variance.values[-1][0])
                pred_vol = pred_vol_scaled / scale_factor  # unscale
        except Exception as e:
            if verbose:
                print(f"⚠️ Failed at i={i} — {e}")
            pred_vol = np.nan

        preds.append(pred_vol)

        if verbose and i % 250 == 0:
            print(f"  → Index {i} | Pred Vol (unscaled): {pred_vol:.5f}")

    full_preds = [np.nan] * window_size + preds
    df["GARCH_pred"] = full_preds

    before = len(df)
    df = df.dropna()
    after = len(df)

    if verbose:
        print(f"✅ Done {ticker} | Rows dropped: {before - after} | Final: {after} rows")

    return df

# %%
# === Try loading precomputed garch_data from disk ===
garch_data_path = "china_garch_data.pkl"

if os.path.exists(garch_data_path):
    print("📦 Loading saved GARCH data from china_garch_data.pkl...")
    with open(garch_data_path, "rb") as f:
        garch_data = pickle.load(f)
    print("✅ Loaded GARCH data successfully!")
else:
    print("⚙️ Computing GARCH data from scratch...")
    garch_data = {}
    for ticker in tickers:
        print(f"\n====================== {ticker} ======================")
        garch_data[ticker] = add_garch_predictions(feature_data[ticker], ticker=ticker)

    # Save to disk
    with open(garch_data_path, "wb") as f:
        pickle.dump(garch_data, f)
    print("💾 Saved GARCH data to china_garch_data.pkl")
# Out:
# ⚙️ Computing GARCH data from scratch...
#
# ====================== 601398.SS ======================
#
# 🔍 GARCH modeling for 601398.SS — total points: 2395
#   → Index 500 | Pred Vol (unscaled): 0.01529
#   → Index 750 | Pred Vol (unscaled): 0.00571
#   → Index 1000 | Pred Vol (unscaled): 0.01758
#   → Index 1250 | Pred Vol (unscaled): 0.01197
#   → Index 1500 | Pred Vol (unscaled): 0.00824
#   → Index 1750 | Pred Vol (unscaled): 0.01567
#   → Index 2000 | Pred Vol (unscaled): 0.00726
#   → Index 2250 | Pred Vol (unscaled): 0.01931
# ✅ Done 601398.SS | Rows dropped: 500 | Final: 1895 rows
#
# ====================== 601988.SS ======================
#
# 🔍 GARCH modeling for 601988.SS — total points: 2395
#   → Index 500 | Pred Vol (unscaled): 0.01635
#   → Index 750 | Pred Vol (unscaled): 0.00773
#   → Index 1000 | Pred Vol (unscaled): 0.01273
#   → Index 1250 | Pred Vol (unscaled): 0.00911
#   → Index 1500 | Pred Vol (unscaled): 0.00980
#   → Index 1750 | Pred Vol (unscaled): 0.00710
#   → Index 2000 | Pred Vol (unscaled): 0.00505
#   → Index 2250 | Pred Vol (unscaled): 0.02613
# ✅ Done 601988.SS | Rows dropped: 500 | Final: 1895 rows
#
# ====================== 601939.SS ======================
#
# 🔍 GARCH modeling for 601939.SS — total points: 2395
#   → Index 500 | Pred Vol (unscaled): 0.01193
#   → Index 750 | Pred Vol (unscaled): 0.00969
#   → Index 1000 | Pred Vol (unscaled): 0.01863
#   → Index 1250 | Pred Vol (unscaled): 0.01532
#   → Index 1500 | Pred Vol (unscaled): 0.01078
#   → Index 1750 | Pred Vol (unscaled): 0.01774
#   → Index 2000 | Pred Vol (unscaled): 0.00763
#   → Index 2250 | Pred Vol (unscaled): 0.02099
# ✅ Done 601939.SS | Rows dropped: 500 | Final: 1895 rows
#
# ====================== 601288.SS ======================
#
# 🔍 GARCH modeling for 601288.SS — total points: 2395
#   → Index 500 | Pred Vol (unscaled): 0.01488
#   → Index 750 | Pred Vol (unscaled): 0.00506
#   → Index 1000 | Pred Vol (unscaled): 0.01776
#   → Index 1250 | Pred Vol (unscaled): 0.01131
#   → Index 1500 | Pred Vol (unscaled): 0.00857
#   → Index 1750 | Pred Vol (unscaled): 0.00953
#   → Index 2000 | Pred Vol (unscaled): 0.00569
#   → Index 2250 | Pred Vol (unscaled): 0.01969
# ✅ Done 601288.SS | Rows dropped: 500 | Final: 1895 rows
#
# ====================== 600036.SS ======================
#
# 🔍 GARCH modeling for 600036.SS — total points: 2395
#   → Index 500 | Pred Vol (unscaled): 0.01941
#   → Index 750 | Pred Vol (unscaled): 0.00856
#   → Index 1000 | Pred Vol (unscaled): 0.01767
#   → Index 1250 | Pred Vol (unscaled): 0.01869
#   → Index 1500 | Pred Vol (unscaled): 0.01575
#   → Index 1750 | Pred Vol (unscaled): 0.01641
#   → Index 2000 | Pred Vol (unscaled): 0.02105
#   → Index 2250 | Pred Vol (unscaled): 0.01715
# ✅ Done 600036.SS | Rows dropped: 500 | Final: 1895 rows
#
# ====================== 601328.SS ======================
#
# 🔍 GARCH modeling for 601328.SS — total points: 2395
#   → Index 500 | Pred Vol (unscaled): 0.02067
#   → Index 750 | Pred Vol (unscaled): 0.00939
#   → Index 1000 | Pred Vol (unscaled): 0.00986
#   → Index 1250 | Pred Vol (unscaled): 0.01023
#   → Index 1500 | Pred Vol (unscaled): 0.00808
#   → Index 1750 | Pred Vol (unscaled): 0.01425
#   → Index 2000 | Pred Vol (unscaled): 0.00793
#   → Index 2250 | Pred Vol (unscaled): 0.01960
# ✅ Done 601328.SS | Rows dropped: 500 | Final: 1895 rows
#
# ====================== 601318.SS ======================
#
# 🔍 GARCH modeling for 601318.SS — total points: 2395
#   → Index 500 | Pred Vol (unscaled): 0.01851
#   → Index 750 | Pred Vol (unscaled): 0.00825
#   → Index 1000 | Pred Vol (unscaled): 0.02281
#   → Index 1250 | Pred Vol (unscaled): 0.01931
#   → Index 1500 | Pred Vol (unscaled): 0.01516
#   → Index 1750 | Pred Vol (unscaled): 0.01609
#   → Index 2000 | Pred Vol (unscaled): 0.01599
#   → Index 2250 | Pred Vol (unscaled): 0.01887
# ✅ Done 601318.SS | Rows dropped: 500 | Final: 1895 rows
#
# ====================== 601628.SS ======================
#
# 🔍 GARCH modeling for 601628.SS — total points: 2395
#   → Index 500 | Pred Vol (unscaled): 0.03595
#   → Index 750 | Pred Vol (unscaled): 0.01547
#   → Index 1000 | Pred Vol (unscaled): 0.01545
#   → Index 1250 | Pred Vol (unscaled): 0.02153
#   → Index 1500 | Pred Vol (unscaled): 0.02095
#   → Index 1750 | Pred Vol (unscaled): 0.02168
#   → Index 2000 | Pred Vol (unscaled): 0.01809
#   → Index 2250 | Pred Vol (unscaled): 0.02313
# ✅ Done 601628.SS | Rows dropped: 500 | Final: 1895 rows
#
# ====================== 601601.SS ======================
#
# 🔍 GARCH modeling for 601601.SS — total points: 2395
#   → Index 500 | Pred Vol (unscaled): 0.02097
#   → Index 750 | Pred Vol (unscaled): 0.00994
#   → Index 1000 | Pred Vol (unscaled): 0.02952
#   → Index 1250 | Pred Vol (unscaled): 0.02412
#   → Index 1500 | Pred Vol (unscaled): 0.02086
#   → Index 1750 | Pred Vol (unscaled): 0.01996
#   → Index 2000 | Pred Vol (unscaled): 0.02072
#   → Index 2250 | Pred Vol (unscaled): 0.02783
# ✅ Done 601601.SS | Rows dropped: 500 | Final: 1895 rows
#
# ====================== 600016.SS ======================
#
# 🔍 GARCH modeling for 600016.SS — total points: 2395
#   → Index 500 | Pred Vol (unscaled): 0.02179
#   → Index 750 | Pred Vol (unscaled): 0.00932
#   → Index 1000 | Pred Vol (unscaled): 0.01093
#   → Index 1250 | Pred Vol (unscaled): 0.01046
#   → Index 1500 | Pred Vol (unscaled): 0.00809
#   → Index 1750 | Pred Vol (unscaled): 0.00810
#   → Index 2000 | Pred Vol (unscaled): 0.00915
#   → Index 2250 | Pred Vol (unscaled): 0.01454
# ✅ Done 600016.SS | Rows dropped: 500 | Final: 1895 rows
#
# ====================== 601688.SS ======================
#
# 🔍 GARCH modeling for 601688.SS — total points: 2395
#   → Index 500 | Pred Vol (unscaled): 0.03634
#   → Index 750 | Pred Vol (unscaled): 0.01104
#   → Index 1000 | Pred Vol (unscaled): 0.02120
#   → Index 1250 | Pred Vol (unscaled): 0.02772
#   → Index 1500 | Pred Vol (unscaled): 0.02179
#   → Index 1750 | Pred Vol (unscaled): 0.01696
#   → Index 2000 | Pred Vol (unscaled): 0.01611
#   → Index 2250 | Pred Vol (unscaled): 0.01629
# ✅ Done 601688.SS | Rows dropped: 500 | Final: 1895 rows
#
# ====================== 000776.SZ ======================
#
# 🔍 GARCH modeling for 000776.SZ — total points: 2395
#   → Index 500 | Pred Vol (unscaled): 0.03710
#   → Index 750 | Pred Vol (unscaled): 0.01135
#   → Index 1000 | Pred Vol (unscaled): 0.01443
#   → Index 1250 | Pred Vol (unscaled): 0.02097
#   → Index 1500 | Pred Vol (unscaled): 0.01442
#   → Index 1750 | Pred Vol (unscaled): 0.01614
#   → Index 2000 | Pred Vol (unscaled): 0.02475
#   → Index 2250 | Pred Vol (unscaled): 0.01767
# ✅ Done 000776.SZ | Rows dropped: 500 | Final: 1895 rows
# 💾 Saved GARCH data to china_garch_data.pkl

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
import numpy as np
import warnings
warnings.filterwarnings("ignore")

def evaluate(y_true, y_pred):
    return {
        "R2": r2_score(y_true, y_pred),
        "RMSE": mean_squared_error(y_true, y_pred, squared=False),
        "MSE": mean_squared_error(y_true, y_pred),
        "MAE": mean_absolute_error(y_true, y_pred),
    }

def train_ml_models_baseline(df, ticker="TICKER"):
    print(f"\n📈 Training ML models for {ticker}...")

    # Feature and target selection
    features = [
        'RSI', 'MOM', 'OBV', 'MACD_LINE', 'MACD_SIGNAL', 'MACD_HIST',
        'STO_K', 'STO_D',
        'Vol_t_1', 'Vol_t_2', 'Vol_t_3', 'Vol_t_4', 'Vol_t_5', 'Vol_t_6'
    ]

    X = df[features].copy()
    # Sanitize column names just in case LightGBM is sensitive
    X.columns = [str(col).replace("-", "_").replace("%", "PCT").replace(".", "_DOT_") for col in X.columns]

    y = df["Vol_target"]

    # Static train-test split (same as paper: 2014–2020 train, 2021–2023 test)
    split_idx = int(len(df) * 0.7)
    X_train, X_test = X.iloc[:split_idx], X.iloc[split_idx:]
    y_train, y_test = y.iloc[:split_idx], y.iloc[split_idx:]

    models = {
        "KNN": KNeighborsRegressor(),
        "AdaBoost": AdaBoostRegressor(),
        "CatBoost": CatBoostRegressor(verbose=0),
        #"LightGBM": LGBMRegressor(),
        "XGBoost": XGBRegressor(verbosity=0),
        "RandomForest": RandomForestRegressor()
    }

    results = {}

    for name, model in models.items():
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        metrics = evaluate(y_test, y_pred)
        results[name] = metrics
        print(f"✅ {name} — R²: {metrics['R2']:.4f}, RMSE: {metrics['RMSE']:.4f}, MAE: {metrics['MAE']:.4f}")

    return results
# Out:
# /shared/home/ads066/.local/lib/python3.11/site-packages/xgboost/core.py:377: FutureWarning: Your system has an old version of glibc (< 2.28). We will stop supporting Linux distros with glibc older than 2.28 after **May 31, 2025**. Please upgrade to a recent Linux distro (with glibc >= 2.28) to use future versions of XGBoost.
# Note: You have installed the 'manylinux2014' variant of XGBoost. Certain features such as GPU algorithms or federated learning are not available. To use these features, please upgrade to a recent Linux distro with glibc 2.28+, and install the 'manylinux_2_28' variant.
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

def evaluate(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    return {
        "R2": r2_score(y_true, y_pred),
        "RMSE": np.sqrt(mse),
        "MSE": mse,
        "MAE": mean_absolute_error(y_true, y_pred),
    }

def train_all_stocks_ml_baseline(garch_data_dict, results_path="china_ml_baseline_results.csv"):
    # Check if results already exist
    if os.path.exists(results_path):
        print(f"📦 Loading existing results from {results_path}...")
        return pd.read_csv(results_path)

    final_results = []

    for ticker, df in garch_data_dict.items():
        print(f"\n================= {ticker} =================")
        results = train_ml_models_baseline(df, ticker=ticker)

        for model_name, metrics in results.items():
            final_results.append({
                "Stock": ticker,
                "Model": model_name,
                "R2": round(metrics["R2"], 4),
                "RMSE": round(metrics["RMSE"], 4),
                "MSE": round(metrics["MSE"], 6),
                "MAE": round(metrics["MAE"], 4),
            })

    # Save results
    results_df = pd.DataFrame(final_results)
    results_df.to_csv(results_path, index=False)
    print(f"💾 Saved results to {results_path}")

    return results_df

# Run training or load existing results
ml_all_results = train_all_stocks_ml_baseline(garch_data)
ml_all_results_sorted = ml_all_results.sort_values(by="R2", ascending=False)
display(ml_all_results_sorted)
# Out:
# ================= 601398.SS =================
#
# 📈 Training ML models for 601398.SS...
# ✅ KNN — R²: -2.4385, RMSE: 0.0064, MAE: 0.0055
# ✅ AdaBoost — R²: 0.7848, RMSE: 0.0016, MAE: 0.0013
# ✅ CatBoost — R²: 0.9492, RMSE: 0.0008, MAE: 0.0005
# ✅ XGBoost — R²: 0.9284, RMSE: 0.0009, MAE: 0.0006
# ✅ RandomForest — R²: 0.9438, RMSE: 0.0008, MAE: 0.0005
#
# ================= 601988.SS =================
#
# 📈 Training ML models for 601988.SS...
# ✅ KNN — R²: 0.0187, RMSE: 0.0055, MAE: 0.0042
# ✅ AdaBoost — R²: 0.8451, RMSE: 0.0022, MAE: 0.0013
# ✅ CatBoost — R²: 0.8192, RMSE: 0.0023, MAE: 0.0011
# ✅ XGBoost — R²: 0.8392, RMSE: 0.0022, MAE: 0.0012
# ✅ RandomForest — R²: 0.8686, RMSE: 0.0020, MAE: 0.0010
#
# ================= 601939.SS =================
#
# 📈 Training ML models for 601939.SS...
# ✅ KNN — R²: -2.6311, RMSE: 0.0068, MAE: 0.0059
# ✅ AdaBoost — R²: 0.7301, RMSE: 0.0019, MAE: 0.0014
# ✅ CatBoost — R²: 0.8568, RMSE: 0.0014, MAE: 0.0010
# ✅ XGBoost — R²: 0.8888, RMSE: 0.0012, MAE: 0.0008
# ✅ RandomForest — R²: 0.9101, RMSE: 0.0011, MAE: 0.0007
#
# ================= 601288.SS =================
#
# 📈 Training ML models for 601288.SS...
# ✅ KNN — R²: 0.1446, RMSE: 0.0040, MAE: 0.0029
# ✅ AdaBoost — R²: 0.8428, RMSE: 0.0017, MAE: 0.0013
# ✅ CatBoost — R²: 0.9122, RMSE: 0.0013, MAE: 0.0007
# ✅ XGBoost — R²: 0.9622, RMSE: 0.0008, MAE: 0.0005
# ✅ RandomForest — R²: 0.9438, RMSE: 0.0010, MAE: 0.0007
#
# ================= 600036.SS =================
#
# 📈 Training ML models for 600036.SS...
# ✅ KNN — R²: -0.0410, RMSE: 0.0059, MAE: 0.0047
# ✅ AdaBoost — R²: 0.8552, RMSE: 0.0022, MAE: 0.0015
# ✅ CatBoost — R²: 0.8661, RMSE: 0.0021, MAE: 0.0015
# ✅ XGBoost — R²: 0.7946, RMSE: 0.0026, MAE: 0.0017
# ✅ RandomForest — R²: 0.9036, RMSE: 0.0018, MAE: 0.0012
#
# ================= 601328.SS =================
#
# 📈 Training ML models for 601328.SS...
# ✅ KNN — R²: -0.4980, RMSE: 0.0049, MAE: 0.0042
# ✅ AdaBoost — R²: 0.8732, RMSE: 0.0014, MAE: 0.0011
# ✅ CatBoost — R²: 0.8857, RMSE: 0.0013, MAE: 0.0009
# ✅ XGBoost — R²: 0.8492, RMSE: 0.0015, MAE: 0.0010
# ✅ RandomForest — R²: 0.9082, RMSE: 0.0012, MAE: 0.0008
#
# ================= 601318.SS =================
#
# 📈 Training ML models for 601318.SS...
# ✅ KNN — R²: -0.3016, RMSE: 0.0053, MAE: 0.0042
# ✅ AdaBoost — R²: 0.8891, RMSE: 0.0015, MAE: 0.0011
# ✅ CatBoost — R²: 0.8925, RMSE: 0.0015, MAE: 0.0011
# ✅ XGBoost — R²: 0.8959, RMSE: 0.0015, MAE: 0.0010
# ✅ RandomForest — R²: 0.9045, RMSE: 0.0014, MAE: 0.0010
#
# ================= 601628.SS =================
#
# 📈 Training ML models for 601628.SS...
# ✅ KNN — R²: -4.2431, RMSE: 0.0108, MAE: 0.0098
# ✅ AdaBoost — R²: 0.7522, RMSE: 0.0023, MAE: 0.0018
# ✅ CatBoost — R²: 0.8545, RMSE: 0.0018, MAE: 0.0013
# ✅ XGBoost — R²: 0.8487, RMSE: 0.0018, MAE: 0.0013
# ✅ RandomForest — R²: 0.8501, RMSE: 0.0018, MAE: 0.0013
#
# ================= 601601.SS =================
#
# 📈 Training ML models for 601601.SS...
# ✅ KNN — R²: -0.1174, RMSE: 0.0061, MAE: 0.0049
# ✅ AdaBoost — R²: 0.8918, RMSE: 0.0019, MAE: 0.0013
# ✅ CatBoost — R²: 0.8941, RMSE: 0.0019, MAE: 0.0013
# ✅ XGBoost — R²: 0.9091, RMSE: 0.0017, MAE: 0.0012
# ✅ RandomForest — R²: 0.9124, RMSE: 0.0017, MAE: 0.0011
#
# ================= 600016.SS =================
#
# 📈 Training ML models for 600016.SS...
# ✅ KNN — R²: -0.1284, RMSE: 0.0050, MAE: 0.0036
# ✅ AdaBoost — R²: 0.8020, RMSE: 0.0021, MAE: 0.0012
# ✅ CatBoost — R²: 0.8303, RMSE: 0.0019, MAE: 0.0009
# ✅ XGBoost — R²: 0.8581, RMSE: 0.0018, MAE: 0.0008
# ✅ RandomForest — R²: 0.8537, RMSE: 0.0018, MAE: 0.0008
#
# ================= 601688.SS =================
#
# 📈 Training ML models for 601688.SS...
# ✅ KNN — R²: -7.7639, RMSE: 0.0125, MAE: 0.0117
# ✅ AdaBoost — R²: 0.8032, RMSE: 0.0019, MAE: 0.0016
# ✅ CatBoost — R²: 0.9063, RMSE: 0.0013, MAE: 0.0010
# ✅ XGBoost — R²: 0.8841, RMSE: 0.0014, MAE: 0.0011
# ✅ RandomForest — R²: 0.8978, RMSE: 0.0013, MAE: 0.0010
#
# ================= 000776.SZ =================
#
# 📈 Training ML models for 000776.SZ...
# ✅ KNN — R²: -1.0130, RMSE: 0.0132, MAE: 0.0113
# ✅ AdaBoost — R²: 0.8318, RMSE: 0.0038, MAE: 0.0027
# ✅ CatBoost — R²: 0.8780, RMSE: 0.0033, MAE: 0.0025
# ✅ XGBoost — R²: 0.8418, RMSE: 0.0037, MAE: 0.0025
# ✅ RandomForest — R²: 0.8788, RMSE: 0.0032, MAE: 0.0021
# 💾 Saved results to china_ml_baseline_results.csv
#         Stock         Model      R2    RMSE       MSE     MAE
# 18  601288.SS       XGBoost  0.9622  0.0008  0.000001  0.0005
# 2   601398.SS      CatBoost  0.9492  0.0008  0.000001  0.0005
# 4   601398.SS  RandomForest  0.9438  0.0008  0.000001  0.0005
# 19  601288.SS  RandomForest  0.9438  0.0010  0.000001  0.0007
# 3   601398.SS       XGBoost  0.9284  0.0009  0.000001  0.0006
# 44  601601.SS  RandomForest  0.9124  0.0017  0.000003  0.0011
# 17  601288.SS      CatBoost  0.9122  0.0013  0.000002  0.0007
# 14  601939.SS  RandomForest  0.9101  0.0011  0.000001  0.0007
# 43  601601.SS       XGBoost  0.9091  0.0017  0.000003  0.0012
# 29  601328.SS  RandomForest  0.9082  0.0012  0.000001  0.0008
# 52  601688.SS      CatBoost  0.9063  0.0013  0.000002  0.0010
# 34  601318.SS  RandomForest  0.9045  0.0014  0.000002  0.0010
# 24  600036.SS  RandomForest  0.9036  0.0018  0.000003  0.0012
# 54  601688.SS  RandomForest  0.8978  0.0013  0.000002  0.0010
# 33  601318.SS       XGBoost  0.8959  0.0015  0.000002  0.0010
# 42  601601.SS      CatBoost  0.8941  0.0019  0.000003  0.0013
# 32  601318.SS      CatBoost  0.8925  0.0015  0.000002  0.0011
# 41  601601.SS      AdaBoost  0.8918  0.0019  0.000004  0.0013
# 31  601318.SS      AdaBoost  0.8891  0.0015  0.000002  0.0011
# 13  601939.SS       XGBoost  0.8888  0.0012  0.000001  0.0008
# 27  601328.SS      CatBoost  0.8857  0.0013  0.000002  0.0009
# 53  601688.SS       XGBoost  0.8841  0.0014  0.000002  0.0011
# 59  000776.SZ  RandomForest  0.8788  0.0032  0.000011  0.0021
# 57  000776.SZ      CatBoost  0.8780  0.0033  0.000011  0.0025
# 26  601328.SS      AdaBoost  0.8732  0.0014  0.000002  0.0011
# 9   601988.SS  RandomForest  0.8686  0.0020  0.000004  0.0010
# 22  600036.SS      CatBoost  0.8661  0.0021  0.000004  0.0015
# 48  600016.SS       XGBoost  0.8581  0.0018  0.000003  0.0008
# 12  601939.SS      CatBoost  0.8568  0.0014  0.000002  0.0010
# 21  600036.SS      AdaBoost  0.8552  0.0022  0.000005  0.0015
# 37  601628.SS      CatBoost  0.8545  0.0018  0.000003  0.0013
# 49  600016.SS  RandomForest  0.8537  0.0018  0.000003  0.0008
# 39  601628.SS  RandomForest  0.8501  0.0018  0.000003  0.0013
# 28  601328.SS       XGBoost  0.8492  0.0015  0.000002  0.0010
# 38  601628.SS       XGBoost  0.8487  0.0018  0.000003  0.0013
# 6   601988.SS      AdaBoost  0.8451  0.0022  0.000005  0.0013
# 16  601288.SS      AdaBoost  0.8428  0.0017  0.000003  0.0013
# 58  000776.SZ       XGBoost  0.8418  0.0037  0.000014  0.0025
# 8   601988.SS       XGBoost  0.8392  0.0022  0.000005  0.0012
# 56  000776.SZ      AdaBoost  0.8318  0.0038  0.000015  0.0027
# 47  600016.SS      CatBoost  0.8303  0.0019  0.000004  0.0009
# 7   601988.SS      CatBoost  0.8192  0.0023  0.000005  0.0011
# 51  601688.SS      AdaBoost  0.8032  0.0019  0.000004  0.0016
# 46  600016.SS      AdaBoost  0.8020  0.0021  0.000004  0.0012
# 23  600036.SS       XGBoost  0.7946  0.0026  0.000007  0.0017
# 1   601398.SS      AdaBoost  0.7848  0.0016  0.000003  0.0013
# 36  601628.SS      AdaBoost  0.7522  0.0023  0.000006  0.0018
# 11  601939.SS      AdaBoost  0.7301  0.0019  0.000003  0.0014
# 15  601288.SS           KNN  0.1446  0.0040  0.000016  0.0029
# 5   601988.SS           KNN  0.0187  0.0055  0.000030  0.0042
# 20  600036.SS           KNN -0.0410  0.0059  0.000035  0.0047
# 40  601601.SS           KNN -0.1174  0.0061  0.000037  0.0049
# 45  600016.SS           KNN -0.1284  0.0050  0.000025  0.0036
# 30  601318.SS           KNN -0.3016  0.0053  0.000028  0.0042
# 25  601328.SS           KNN -0.4980  0.0049  0.000024  0.0042
# 55  000776.SZ           KNN -1.0130  0.0132  0.000175  0.0113
# 0   601398.SS           KNN -2.4385  0.0064  0.000041  0.0055
# 10  601939.SS           KNN -2.6311  0.0068  0.000047  0.0059
# 35  601628.SS           KNN -4.2431  0.0108  0.000117  0.0098
# 50  601688.SS           KNN -7.7639  0.0125  0.000156  0.0117

# %%
from arch import arch_model
import numpy as np
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

def evaluate_series(y_true, y_pred):
    return {
        "R2": r2_score(y_true, y_pred),
        "RMSE": mean_squared_error(y_true, y_pred, squared=False),
        "MSE": mean_squared_error(y_true, y_pred),
        "MAE": mean_absolute_error(y_true, y_pred),
    }

def forecast_volatility_arch(df, model_type="GARCH", ticker="TICKER", verbose=True):
    df = df.copy()

    # Flatten columns if MultiIndex
    if isinstance(df.columns, pd.MultiIndex):
        df.columns = ['_'.join([str(i) for i in col if i]) for col in df.columns]

    if "Vol_target" not in df.columns or "Return" not in df.columns:
        raise KeyError(f"Missing 'Vol_target' or 'Return' in {ticker}")

    returns = df["Return"].dropna().values
    preds = []
    window_size = 500
    scale_factor = 100  # fix for scale warning

    if verbose:
        print(f"\n🔮 Running {model_type} for {ticker}...")

    for i in range(window_size, len(returns)):
        train_window = returns[i-window_size:i] * scale_factor

        try:
            if model_type == "GARCH":
                model = arch_model(train_window, vol='GARCH', p=1, q=1, dist='normal', rescale=False)
            elif model_type == "GJR":
                model = arch_model(train_window, vol='GARCH', p=1, o=1, q=1, dist='normal', rescale=False)
            elif model_type == "EGARCH":
                model = arch_model(train_window, vol='EGARCH', p=1, q=1, dist='normal', rescale=False)
            else:
                raise ValueError("Invalid model_type")

            model_fit = model.fit(disp="off")
            forecast = model_fit.forecast(horizon=1)
            pred_vol = np.sqrt(forecast.variance.values[-1][0]) / scale_factor

        except Exception as e:
            if verbose:
                print(f"⚠️ {model_type} failed at index {i}: {e}")
            pred_vol = np.nan

        preds.append(pred_vol)

        if verbose and i % 250 == 0:
            print(f"  → {model_type} | index {i} | vol: {pred_vol:.5f}")

    df[f"{model_type}_pred"] = [np.nan] * window_size + preds
    df = df.dropna(subset=["Vol_target", f"{model_type}_pred"])

    metrics = evaluate_series(df["Vol_target"], df[f"{model_type}_pred"])
    if verbose:
        print(f"✅ {model_type} for {ticker} — R²: {metrics['R2']:.4f}, RMSE: {metrics['RMSE']:.4f}, MAE: {metrics['MAE']:.4f}")

    return df, metrics

# %%
import os
import pandas as pd

def evaluate_all_series_models(garch_data_dict, results_path="china_ts_model_results.csv"):
    # If results already exist, load them
    if os.path.exists(results_path):
        print(f"📦 Loading saved time series results from {results_path}...")
        return pd.read_csv(results_path)

    results = []

    for ticker, df in garch_data_dict.items():
        for model_type in ["GARCH", "GJR", "EGARCH"]:
            print(f"\n================= {ticker} - {model_type} =================")
            try:
                _, metrics = forecast_volatility_arch(df, model_type=model_type, ticker=ticker, verbose=True)
                results.append({
                    "Stock": ticker,
                    "Model": model_type,
                    "R2": round(metrics["R2"], 4),
                    "RMSE": round(metrics["RMSE"], 4),
                    "MSE": round(metrics["MSE"], 6),
                    "MAE": round(metrics["MAE"], 4),
                })
            except Exception as e:
                print(f"⚠️ Skipping {ticker} - {model_type}: {e}")

    df_results = pd.DataFrame(results)
    df_results.to_csv(results_path, index=False)
    print(f"💾 Saved time series model results to {results_path}")

    return df_results

ts_model_results = evaluate_all_series_models(garch_data)
ts_model_results_sorted = ts_model_results.sort_values(by="R2", ascending=False)
display(ts_model_results_sorted)
# Out:
# ================= 601398.SS - GARCH =================
#
# 🔮 Running GARCH for 601398.SS...
#   → GARCH | index 500 | vol: 0.01758
#   → GARCH | index 750 | vol: 0.01197
#   → GARCH | index 1000 | vol: 0.00824
#   → GARCH | index 1250 | vol: 0.01567
#   → GARCH | index 1500 | vol: 0.00726
#   → GARCH | index 1750 | vol: 0.01931
# ✅ GARCH for 601398.SS — R²: 0.4657, RMSE: 0.0031, MAE: 0.0022
#
# ================= 601398.SS - GJR =================
#
# 🔮 Running GJR for 601398.SS...
#   → GJR | index 500 | vol: 0.01344
#   → GJR | index 750 | vol: 0.01218
#   → GJR | index 1000 | vol: 0.00829
#   → GJR | index 1250 | vol: 0.01658
#   → GJR | index 1500 | vol: 0.00658
#   → GJR | index 1750 | vol: 0.01832
# ✅ GJR for 601398.SS — R²: 0.4465, RMSE: 0.0031, MAE: 0.0022
#
# ================= 601398.SS - EGARCH =================
#
# 🔮 Running EGARCH for 601398.SS...
#   → EGARCH | index 500 | vol: 0.01598
#   → EGARCH | index 750 | vol: 0.01242
#   → EGARCH | index 1000 | vol: 0.00842
#   → EGARCH | index 1250 | vol: 0.01420
#   → EGARCH | index 1500 | vol: 0.00777
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 1750 | vol: 0.01535
# ✅ EGARCH for 601398.SS — R²: 0.4655, RMSE: 0.0031, MAE: 0.0022
#
# ================= 601988.SS - GARCH =================
#
# 🔮 Running GARCH for 601988.SS...
#   → GARCH | index 500 | vol: 0.01273
#   → GARCH | index 750 | vol: 0.00911
#   → GARCH | index 1000 | vol: 0.00980
#   → GARCH | index 1250 | vol: 0.00710
#   → GARCH | index 1500 | vol: 0.00505
#   → GARCH | index 1750 | vol: 0.02613
# ✅ GARCH for 601988.SS — R²: 0.6200, RMSE: 0.0027, MAE: 0.0019
#
# ================= 601988.SS - GJR =================
#
# 🔮 Running GJR for 601988.SS...
#   → GJR | index 500 | vol: 0.00894
#   → GJR | index 750 | vol: 0.00953
#   → GJR | index 1000 | vol: 0.01000
#   → GJR | index 1250 | vol: 0.00706
#   → GJR | index 1500 | vol: 0.00481
#   → GJR | index 1750 | vol: 0.02733
# ✅ GJR for 601988.SS — R²: 0.5024, RMSE: 0.0031, MAE: 0.0020
#
# ================= 601988.SS - EGARCH =================
#
# 🔮 Running EGARCH for 601988.SS...
#   → EGARCH | index 500 | vol: 0.01238
#   → EGARCH | index 750 | vol: 0.00905
#   → EGARCH | index 1000 | vol: 0.01006
#   → EGARCH | index 1250 | vol: 0.00739
#   → EGARCH | index 1500 | vol: 0.00531
#   → EGARCH | index 1750 | vol: 0.02688
# ✅ EGARCH for 601988.SS — R²: 0.6404, RMSE: 0.0026, MAE: 0.0018
#
# ================= 601939.SS - GARCH =================
#
# 🔮 Running GARCH for 601939.SS...
#   → GARCH | index 500 | vol: 0.01863
#   → GARCH | index 750 | vol: 0.01532
#   → GARCH | index 1000 | vol: 0.01078
#   → GARCH | index 1250 | vol: 0.01774
#   → GARCH | index 1500 | vol: 0.00763
#   → GARCH | index 1750 | vol: 0.02099
# ✅ GARCH for 601939.SS — R²: 0.5220, RMSE: 0.0033, MAE: 0.0025
#
# ================= 601939.SS - GJR =================
#
# 🔮 Running GJR for 601939.SS...
#   → GJR | index 500 | vol: 0.01652
#   → GJR | index 750 | vol: 0.01554
#   → GJR | index 1000 | vol: 0.01083
#   → GJR | index 1250 | vol: 0.01775
#   → GJR | index 1500 | vol: 0.00752
#   → GJR | index 1750 | vol: 0.02084
# ✅ GJR for 601939.SS — R²: 0.5373, RMSE: 0.0033, MAE: 0.0024
#
# ================= 601939.SS - EGARCH =================
#
# 🔮 Running EGARCH for 601939.SS...
#   → EGARCH | index 500 | vol: 0.01845
#   → EGARCH | index 750 | vol: 0.01616
#   → EGARCH | index 1000 | vol: 0.01104
#   → EGARCH | index 1250 | vol: 0.01687
#   → EGARCH | index 1500 | vol: 0.00730
#   → EGARCH | index 1750 | vol: 0.01937
# ✅ EGARCH for 601939.SS — R²: 0.6009, RMSE: 0.0031, MAE: 0.0024
#
# ================= 601288.SS - GARCH =================
#
# 🔮 Running GARCH for 601288.SS...
#   → GARCH | index 500 | vol: 0.01776
#   → GARCH | index 750 | vol: 0.01131
#   → GARCH | index 1000 | vol: 0.00857
#   → GARCH | index 1250 | vol: 0.00953
#   → GARCH | index 1500 | vol: 0.00569
#   → GARCH | index 1750 | vol: 0.01969
# ✅ GARCH for 601288.SS — R²: 0.6329, RMSE: 0.0025, MAE: 0.0018
#
# ================= 601288.SS - GJR =================
#
# 🔮 Running GJR for 601288.SS...
#   → GJR | index 500 | vol: 0.01537
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → GJR | index 750 | vol: 0.01249
#   → GJR | index 1000 | vol: 0.00876
#   → GJR | index 1250 | vol: 0.00964
#   → GJR | index 1500 | vol: 0.00551
#   → GJR | index 1750 | vol: 0.01936
# ✅ GJR for 601288.SS — R²: 0.6249, RMSE: 0.0026, MAE: 0.0018
#
# ================= 601288.SS - EGARCH =================
#
# 🔮 Running EGARCH for 601288.SS...
#   → EGARCH | index 500 | vol: 0.01891
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 750 | vol: 0.01171
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 1000 | vol: 0.00874
#   → EGARCH | index 1250 | vol: 0.00934
#   → EGARCH | index 1500 | vol: 0.00566
#   → EGARCH | index 1750 | vol: 0.01746
# ✅ EGARCH for 601288.SS — R²: -17976199.6745, RMSE: 17.7967, MAE: 0.4818
#
# ================= 600036.SS - GARCH =================
#
# 🔮 Running GARCH for 600036.SS...
#   → GARCH | index 500 | vol: 0.01767
#   → GARCH | index 750 | vol: 0.01869
#   → GARCH | index 1000 | vol: 0.01575
#   → GARCH | index 1250 | vol: 0.01641
#   → GARCH | index 1500 | vol: 0.02105
#   → GARCH | index 1750 | vol: 0.01715
# ✅ GARCH for 600036.SS — R²: 0.4278, RMSE: 0.0038, MAE: 0.0029
#
# ================= 600036.SS - GJR =================
#
# 🔮 Running GJR for 600036.SS...
#   → GJR | index 500 | vol: 0.01351
#   → GJR | index 750 | vol: 0.01889
#   → GJR | index 1000 | vol: 0.01545
#   → GJR | index 1250 | vol: 0.01594
#   → GJR | index 1500 | vol: 0.02016
#   → GJR | index 1750 | vol: 0.01758
# ✅ GJR for 600036.SS — R²: 0.3218, RMSE: 0.0041, MAE: 0.0031
#
# ================= 600036.SS - EGARCH =================
#
# 🔮 Running EGARCH for 600036.SS...
#   → EGARCH | index 500 | vol: 0.01756
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 750 | vol: 0.00043
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 1000 | vol: 0.01588
#   → EGARCH | index 1250 | vol: 0.01742
#   → EGARCH | index 1500 | vol: 0.02099
#   → EGARCH | index 1750 | vol: 0.01803
# ✅ EGARCH for 600036.SS — R²: -.0000, RMSE: 3589803495847321968573347710569562866790391348954115321529010433816748805564286754642289273436758147834151857032376772169338599801476622081812921843712.0000, MAE: 96113318494211016191246457818745077868755192106337729491446439506092628392330099663671517917867336549798729447500086090008613583446197960489167749120.0000
#
# ================= 601328.SS - GARCH =================
#
# 🔮 Running GARCH for 601328.SS...
#   → GARCH | index 500 | vol: 0.00986
#   → GARCH | index 750 | vol: 0.01023
#   → GARCH | index 1000 | vol: 0.00808
#   → GARCH | index 1250 | vol: 0.01425
#   → GARCH | index 1500 | vol: 0.00793
#   → GARCH | index 1750 | vol: 0.01960
# ✅ GARCH for 601328.SS — R²: 0.3654, RMSE: 0.0029, MAE: 0.0021
#
# ================= 601328.SS - GJR =================
#
# 🔮 Running GJR for 601328.SS...
#   → GJR | index 500 | vol: 0.00845
#   → GJR | index 750 | vol: 0.00997
#   → GJR | index 1000 | vol: 0.00876
#   → GJR | index 1250 | vol: 0.01465
#   → GJR | index 1500 | vol: 0.00771
#   → GJR | index 1750 | vol: 0.02087
# ✅ GJR for 601328.SS — R²: 0.3321, RMSE: 0.0030, MAE: 0.0021
#
# ================= 601328.SS - EGARCH =================
#
# 🔮 Running EGARCH for 601328.SS...
#   → EGARCH | index 500 | vol: 0.00993
#   → EGARCH | index 750 | vol: 0.01056
#   → EGARCH | index 1000 | vol: 0.00794
#   → EGARCH | index 1250 | vol: 0.01273
#   → EGARCH | index 1500 | vol: 0.00838
#   → EGARCH | index 1750 | vol: 0.01913
# ✅ EGARCH for 601328.SS — R²: 0.5002, RMSE: 0.0026, MAE: 0.0020
#
# ================= 601318.SS - GARCH =================
#
# 🔮 Running GARCH for 601318.SS...
#   → GARCH | index 500 | vol: 0.02281
#   → GARCH | index 750 | vol: 0.01931
#   → GARCH | index 1000 | vol: 0.01516
#   → GARCH | index 1250 | vol: 0.01609
#   → GARCH | index 1500 | vol: 0.01599
#   → GARCH | index 1750 | vol: 0.01887
# ✅ GARCH for 601318.SS — R²: 0.4595, RMSE: 0.0033, MAE: 0.0026
#
# ================= 601318.SS - GJR =================
#
# 🔮 Running GJR for 601318.SS...
#   → GJR | index 500 | vol: 0.01812
#   → GJR | index 750 | vol: 0.02068
#   → GJR | index 1000 | vol: 0.01510
#   → GJR | index 1250 | vol: 0.01639
#   → GJR | index 1500 | vol: 0.01612
#   → GJR | index 1750 | vol: 0.01935
# ✅ GJR for 601318.SS — R²: 0.3036, RMSE: 0.0037, MAE: 0.0029
#
# ================= 601318.SS - EGARCH =================
#
# 🔮 Running EGARCH for 601318.SS...
#   → EGARCH | index 500 | vol: 0.02339
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 750 | vol: 0.01903
#   → EGARCH | index 1000 | vol: 0.01550
#   → EGARCH | index 1250 | vol: 0.01589
#   → EGARCH | index 1500 | vol: 0.01570
#   → EGARCH | index 1750 | vol: 0.01813
# ✅ EGARCH for 601318.SS — R²: -1.0626, RMSE: 0.0064, MAE: 0.0028
#
# ================= 601628.SS - GARCH =================
#
# 🔮 Running GARCH for 601628.SS...
#   → GARCH | index 500 | vol: 0.01545
#   → GARCH | index 750 | vol: 0.02153
#   → GARCH | index 1000 | vol: 0.02095
#   → GARCH | index 1250 | vol: 0.02168
#   → GARCH | index 1500 | vol: 0.01809
#   → GARCH | index 1750 | vol: 0.02313
# ✅ GARCH for 601628.SS — R²: 0.5654, RMSE: 0.0049, MAE: 0.0034
#
# ================= 601628.SS - GJR =================
#
# 🔮 Running GJR for 601628.SS...
#   → GJR | index 500 | vol: 0.01460
#   → GJR | index 750 | vol: 0.02264
#   → GJR | index 1000 | vol: 0.02144
#   → GJR | index 1250 | vol: 0.02183
#   → GJR | index 1500 | vol: 0.01847
#   → GJR | index 1750 | vol: 0.02245
# ✅ GJR for 601628.SS — R²: 0.5378, RMSE: 0.0050, MAE: 0.0035
#
# ================= 601628.SS - EGARCH =================
#
# 🔮 Running EGARCH for 601628.SS...
#   → EGARCH | index 500 | vol: 0.01575
#   → EGARCH | index 750 | vol: 0.02183
#   → EGARCH | index 1000 | vol: 0.01976
#   → EGARCH | index 1250 | vol: 0.02310
#   → EGARCH | index 1500 | vol: 0.01808
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 1750 | vol: 0.02329
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# ✅ EGARCH for 601628.SS — R²: -0.1010, RMSE: 0.0078, MAE: 0.0041
#
# ================= 601601.SS - GARCH =================
#
# 🔮 Running GARCH for 601601.SS...
#   → GARCH | index 500 | vol: 0.02952
#   → GARCH | index 750 | vol: 0.02412
#   → GARCH | index 1000 | vol: 0.02086
#   → GARCH | index 1250 | vol: 0.01996
#   → GARCH | index 1500 | vol: 0.02072
#   → GARCH | index 1750 | vol: 0.02783
# ✅ GARCH for 601601.SS — R²: 0.3668, RMSE: 0.0042, MAE: 0.0033
#
# ================= 601601.SS - GJR =================
#
# 🔮 Running GJR for 601601.SS...
#   → GJR | index 500 | vol: 0.02607
#   → GJR | index 750 | vol: 0.02412
#   → GJR | index 1000 | vol: 0.02015
#   → GJR | index 1250 | vol: 0.01957
#   → GJR | index 1500 | vol: 0.02063
#   → GJR | index 1750 | vol: 0.02980
# ✅ GJR for 601601.SS — R²: 0.3396, RMSE: 0.0043, MAE: 0.0033
#
# ================= 601601.SS - EGARCH =================
#
# 🔮 Running EGARCH for 601601.SS...
#   → EGARCH | index 500 | vol: 0.03087
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# ...
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 1000 | vol: 0.02221
#   → EGARCH | index 1250 | vol: 0.01704
#   → EGARCH | index 1500 | vol: 0.01576
#   → EGARCH | index 1750 | vol: 0.01639
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# ✅ EGARCH for 601688.SS — R²: -4953661286185424207936298941239263232.0000, RMSE: 14742012936515040.0000, MAE: 394702324584652.2500
#
# ================= 000776.SZ - GARCH =================
#
# 🔮 Running GARCH for 000776.SZ...
#   → GARCH | index 500 | vol: 0.01443
#   → GARCH | index 750 | vol: 0.02097
#   → GARCH | index 1000 | vol: 0.01442
#   → GARCH | index 1250 | vol: 0.01614
#   → GARCH | index 1500 | vol: 0.02475
#   → GARCH | index 1750 | vol: 0.01767
# ✅ GARCH for 000776.SZ — R²: 0.6584, RMSE: 0.0049, MAE: 0.0035
#
# ================= 000776.SZ - GJR =================
#
# 🔮 Running GJR for 000776.SZ...
#   → GJR | index 500 | vol: 0.01432
#   → GJR | index 750 | vol: 0.02181
#   → GJR | index 1000 | vol: 0.01404
#   → GJR | index 1250 | vol: 0.01604
#   → GJR | index 1500 | vol: 0.02458
#   → GJR | index 1750 | vol: 0.01771
# ✅ GJR for 000776.SZ — R²: 0.6350, RMSE: 0.0050, MAE: 0.0036
#
# ================= 000776.SZ - EGARCH =================
#
# 🔮 Running EGARCH for 000776.SZ...
#   → EGARCH | index 500 | vol: 0.01522
#   → EGARCH | index 750 | vol: 0.02201
#   → EGARCH | index 1000 | vol: 0.01427
#   → EGARCH | index 1250 | vol: 0.01588
#   → EGARCH | index 1500 | vol: 0.02446
#   → EGARCH | index 1750 | vol: 0.01850
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# ✅ EGARCH for 000776.SZ — R²: -31.1433, RMSE: 0.0472, MAE: 0.0054
# 💾 Saved time series model results to china_ts_model_results.csv
#         Stock   Model            R2           RMSE            MSE  \
# 33  000776.SZ   GARCH  6.584000e-01   4.900000e-03   2.400000e-05
# 5   601988.SS  EGARCH  6.404000e-01   2.600000e-03   7.000000e-06
# 34  000776.SZ     GJR  6.350000e-01   5.000000e-03   2.500000e-05
# 9   601288.SS   GARCH  6.329000e-01   2.500000e-03   6.000000e-06
# 10  601288.SS     GJR  6.249000e-01   2.600000e-03   7.000000e-06
# 3   601988.SS   GARCH  6.200000e-01   2.700000e-03   7.000000e-06
# 30  601688.SS   GARCH  6.142000e-01   4.100000e-03   1.700000e-05
# 8   601939.SS  EGARCH  6.009000e-01   3.100000e-03   9.000000e-06
# 31  601688.SS     GJR  5.938000e-01   4.200000e-03   1.800000e-05
# 21  601628.SS   GARCH  5.654000e-01   4.900000e-03   2.400000e-05
# 22  601628.SS     GJR  5.378000e-01   5.000000e-03   2.500000e-05
# 7   601939.SS     GJR  5.373000e-01   3.300000e-03   1.100000e-05
# 6   601939.SS   GARCH  5.220000e-01   3.300000e-03   1.100000e-05
# 4   601988.SS     GJR  5.024000e-01   3.100000e-03   9.000000e-06
# 17  601328.SS  EGARCH  5.002000e-01   2.600000e-03   7.000000e-06
# 0   601398.SS   GARCH  4.657000e-01   3.100000e-03   9.000000e-06
# 2   601398.SS  EGARCH  4.655000e-01   3.100000e-03   9.000000e-06
# 18  601318.SS   GARCH  4.595000e-01   3.300000e-03   1.100000e-05
# 1   601398.SS     GJR  4.465000e-01   3.100000e-03   1.000000e-05
# 12  600036.SS   GARCH  4.278000e-01   3.800000e-03   1.400000e-05
# 24  601601.SS   GARCH  3.668000e-01   4.200000e-03   1.800000e-05
# 15  601328.SS   GARCH  3.654000e-01   2.900000e-03   8.000000e-06
# 25  601601.SS     GJR  3.396000e-01   4.300000e-03   1.800000e-05
# 29  600016.SS  EGARCH  3.379000e-01   3.300000e-03   1.100000e-05
# 16  601328.SS     GJR  3.321000e-01   3.000000e-03   9.000000e-06
# 13  600036.SS     GJR  3.218000e-01   4.100000e-03   1.700000e-05
# 19  601318.SS     GJR  3.036000e-01   3.700000e-03   1.400000e-05
# 27  600016.SS   GARCH  2.916000e-01   3.400000e-03   1.200000e-05
# 28  600016.SS     GJR  1.954000e-01   3.700000e-03   1.300000e-05
# 23  601628.SS  EGARCH -1.010000e-01   7.800000e-03   6.100000e-05
# 20  601318.SS  EGARCH -1.062600e+00   6.400000e-03   4.100000e-05
# 35  000776.SZ  EGARCH -3.114330e+01   4.720000e-02   2.228000e-03
# 11  601288.SS  EGARCH -1.797620e+07   1.779670e+01   3.167217e+02
# 32  601688.SS  EGARCH -4.953661e+36   1.474201e+16   2.173269e+32
# 26  601601.SS  EGARCH          -inf  5.076749e+150  2.577338e+301
# 14  600036.SS  EGARCH          -inf  3.589803e+150  1.288669e+301
#
#               MAE
# 33   3.500000e-03
# 5    1.800000e-03
# 34   3.600000e-03
# 9    1.800000e-03
# 10   1.800000e-03
# 3    1.900000e-03
# 30   3.300000e-03
# 8    2.400000e-03
# 31   3.400000e-03
# 21   3.400000e-03
# 22   3.500000e-03
# 7    2.400000e-03
# 6    2.500000e-03
# 4    2.000000e-03
# 17   2.000000e-03
# 0    2.200000e-03
# 2    2.200000e-03
# 18   2.600000e-03
# 1    2.200000e-03
# 12   2.900000e-03
# 24   3.300000e-03
# 15   2.100000e-03
# 25   3.300000e-03
# 29   2.200000e-03
# 16   2.100000e-03
# 13   3.100000e-03
# 19   2.900000e-03
# 27   2.200000e-03
# 28   2.200000e-03
# 23   4.100000e-03
# 20   2.800000e-03
# 35   5.400000e-03
# 11   4.818000e-01
# 32   3.947023e+14
# 26  1.922266e+149
# 14  9.611332e+148

# %%
def train_fusion_model(df, model_name, ts_feature="GARCH_pred", ticker="TICKER"):
    from sklearn.model_selection import train_test_split
    from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
    from sklearn.neighbors import KNeighborsRegressor
    from catboost import CatBoostRegressor
    from lightgbm import LGBMRegressor
    from xgboost import XGBRegressor

    models = {
        "KNN": KNeighborsRegressor(),
        "AdaBoost": AdaBoostRegressor(),
        "CatBoost": CatBoostRegressor(verbose=0),
        "XGBoost": XGBRegressor(verbosity=0),
        "RandomForest": RandomForestRegressor()
    }

    if model_name not in models:
        raise ValueError(f"Model '{model_name}' not recognized.")

    df = df.copy()

    # Flatten if needed
    if isinstance(df.columns, pd.MultiIndex):
        df.columns = ['_'.join([str(i) for i in col if i]) for col in df.columns]

    if ts_feature not in df.columns:
        raise ValueError(f"'{ts_feature}' not found in DataFrame for {ticker}")

    feature_cols = [
        'RSI', 'MOM', 'OBV', 'MACD_LINE', 'MACD_SIGNAL', 'MACD_HIST',
        'STO_K', 'STO_D', 'Vol_t_1', 'Vol_t_2', 'Vol_t_3',
        'Vol_t_4', 'Vol_t_5', 'Vol_t_6', ts_feature
    ]

    X = df[feature_cols].copy()
    y = df["Vol_target"]

    split_idx = int(len(df) * 0.7)
    X_train, X_test = X.iloc[:split_idx], X.iloc[split_idx:]
    y_train, y_test = y.iloc[:split_idx], y.iloc[split_idx:]

    model = models[model_name]
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    metrics = evaluate_series(y_test, y_pred)

    print(f"✅ {model_name} + {ts_feature} for {ticker} — R²: {metrics['R2']:.4f}, RMSE: {metrics['RMSE']:.4f}, MAE: {metrics['MAE']:.4f}")

    return metrics

# %%
import os
import pandas as pd

# Reuse existing forecast function
for ticker in tqdm(garch_data.keys()):
    for model_type in ["GJR", "EGARCH"]:
        print(f"\n📈 Adding {model_type}_pred to {ticker}...")
        df = garch_data[ticker]

        try:
            df, _ = forecast_volatility_arch(df, model_type=model_type, ticker=ticker, verbose=False)
            garch_data[ticker] = df  # Update with new column
        except Exception as e:
            print(f"⚠️ {model_type} failed for {ticker}: {e}")

def train_all_fusion_models(garch_data_dict, results_path="china_fusion_model_results.csv"):
    # Load existing results if file exists
    if os.path.exists(results_path):
        print(f"📦 Loading saved fusion model results from {results_path}...")
        return pd.read_csv(results_path)

    results = []

    for ticker, df in garch_data_dict.items():
        for ts_feature in ["GARCH_pred", "GJR_pred", "EGARCH_pred"]:
            if ts_feature not in df.columns:
                print(f"⚠️ Skipping {ticker} - missing {ts_feature}")
                continue

            for model_name in ["RandomForest", "XGBoost", "CatBoost", "AdaBoost", "KNN"]:
                try:
                    metrics = train_fusion_model(df, model_name, ts_feature=ts_feature, ticker=ticker)
                    results.append({
                        "Stock": ticker,
                        "Fusion_Model": f"{ts_feature}+{model_name}",
                        "R2": round(metrics["R2"], 4),
                        "RMSE": round(metrics["RMSE"], 4),
                        "MSE": round(metrics["MSE"], 6),
                        "MAE": round(metrics["MAE"], 4),
                    })
                except Exception as e:
                    print(f"⚠️ {ticker} {ts_feature}+{model_name} failed: {e}")

    fusion_df = pd.DataFrame(results)
    fusion_df.to_csv(results_path, index=False)
    print(f"💾 Saved fusion model results to {results_path}")

    return fusion_df

fusion_results_df = train_all_fusion_models(garch_data)
fusion_results_sorted = fusion_results_df.sort_values(by="R2", ascending=False)
display(fusion_results_sorted)
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
# 📈 Adding GJR_pred to 601398.SS...
#
# 📈 Adding EGARCH_pred to 601398.SS...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   8%|▊         | 1/12 [00:35<06:26, 35.15s/it]
# 📈 Adding GJR_pred to 601988.SS...
#
# 📈 Adding EGARCH_pred to 601988.SS...
#  17%|█▋        | 2/12 [01:10<05:53, 35.35s/it]
# 📈 Adding GJR_pred to 601939.SS...
#
# 📈 Adding EGARCH_pred to 601939.SS...
#  25%|██▌       | 3/12 [01:46<05:18, 35.42s/it]
# 📈 Adding GJR_pred to 601288.SS...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# 📈 Adding EGARCH_pred to 601288.SS...
#  33%|███▎      | 4/12 [02:22<04:44, 35.61s/it]
# 📈 Adding GJR_pred to 600036.SS...
#
# 📈 Adding EGARCH_pred to 600036.SS...
#  42%|████▏     | 5/12 [02:56<04:05, 35.03s/it]
# 📈 Adding GJR_pred to 601328.SS...
#
# 📈 Adding EGARCH_pred to 601328.SS...
#  50%|█████     | 6/12 [03:29<03:27, 34.66s/it]
# 📈 Adding GJR_pred to 601318.SS...
#
# 📈 Adding EGARCH_pred to 601318.SS...
#  58%|█████▊    | 7/12 [04:02<02:50, 34.06s/it]
# 📈 Adding GJR_pred to 601628.SS...
#
# 📈 Adding EGARCH_pred to 601628.SS...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  67%|██████▋   | 8/12 [04:38<02:18, 34.64s/it]
# 📈 Adding GJR_pred to 601601.SS...
#
# 📈 Adding EGARCH_pred to 601601.SS...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  75%|███████▌  | 9/12 [05:14<01:44, 35.00s/it]
# 📈 Adding GJR_pred to 600016.SS...
#
# 📈 Adding EGARCH_pred to 600016.SS...
#  83%|████████▎ | 10/12 [05:47<01:08, 34.41s/it]
# 📈 Adding GJR_pred to 601688.SS...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# 📈 Adding EGARCH_pred to 601688.SS...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  92%|█████████▏| 11/12 [06:25<00:35, 35.58s/it]
# 📈 Adding GJR_pred to 000776.SZ...
#
# 📈 Adding EGARCH_pred to 000776.SZ...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# 100%|██████████| 12/12 [07:04<00:00, 35.35s/it]
# ✅ RandomForest + GARCH_pred for 601398.SS — R²: 0.8882, RMSE: 0.0014, MAE: 0.0009
# ✅ XGBoost + GARCH_pred for 601398.SS — R²: 0.8544, RMSE: 0.0016, MAE: 0.0010
# ✅ CatBoost + GARCH_pred for 601398.SS — R²: 0.8656, RMSE: 0.0016, MAE: 0.0011
# ✅ AdaBoost + GARCH_pred for 601398.SS — R²: 0.7935, RMSE: 0.0019, MAE: 0.0014
# ✅ KNN + GARCH_pred for 601398.SS — R²: 0.0676, RMSE: 0.0041, MAE: 0.0030
# ✅ RandomForest + GJR_pred for 601398.SS — R²: 0.8914, RMSE: 0.0014, MAE: 0.0009
# ✅ XGBoost + GJR_pred for 601398.SS — R²: 0.8580, RMSE: 0.0016, MAE: 0.0010
# ✅ CatBoost + GJR_pred for 601398.SS — R²: 0.8725, RMSE: 0.0015, MAE: 0.0010
# ✅ AdaBoost + GJR_pred for 601398.SS — R²: 0.7744, RMSE: 0.0020, MAE: 0.0013
# ✅ KNN + GJR_pred for 601398.SS — R²: 0.0676, RMSE: 0.0041, MAE: 0.0030
# ✅ RandomForest + EGARCH_pred for 601398.SS — R²: 0.8775, RMSE: 0.0015, MAE: 0.0010
# ✅ XGBoost + EGARCH_pred for 601398.SS — R²: 0.8554, RMSE: 0.0016, MAE: 0.0010
# ✅ CatBoost + EGARCH_pred for 601398.SS — R²: 0.8676, RMSE: 0.0016, MAE: 0.0010
# ✅ AdaBoost + EGARCH_pred for 601398.SS — R²: 0.7766, RMSE: 0.0020, MAE: 0.0014
# ✅ KNN + EGARCH_pred for 601398.SS — R²: 0.0676, RMSE: 0.0041, MAE: 0.0030
# ✅ RandomForest + GARCH_pred for 601988.SS — R²: 0.4404, RMSE: 0.0049, MAE: 0.0027
# ✅ XGBoost + GARCH_pred for 601988.SS — R²: 0.4245, RMSE: 0.0050, MAE: 0.0026
# ✅ CatBoost + GARCH_pred for 601988.SS — R²: 0.4325, RMSE: 0.0049, MAE: 0.0025
# ✅ AdaBoost + GARCH_pred for 601988.SS — R²: 0.4768, RMSE: 0.0047, MAE: 0.0028
# ✅ KNN + GARCH_pred for 601988.SS — R²: -0.5464, RMSE: 0.0081, MAE: 0.0054
# ✅ RandomForest + GJR_pred for 601988.SS — R²: 0.4249, RMSE: 0.0050, MAE: 0.0028
# ✅ XGBoost + GJR_pred for 601988.SS — R²: 0.4337, RMSE: 0.0049, MAE: 0.0026
# ✅ CatBoost + GJR_pred for 601988.SS — R²: 0.4155, RMSE: 0.0050, MAE: 0.0025
# ✅ AdaBoost + GJR_pred for 601988.SS — R²: 0.4767, RMSE: 0.0047, MAE: 0.0028
# ✅ KNN + GJR_pred for 601988.SS — R²: -0.5464, RMSE: 0.0081, MAE: 0.0054
# ✅ RandomForest + EGARCH_pred for 601988.SS — R²: 0.3949, RMSE: 0.0051, MAE: 0.0028
# ✅ XGBoost + EGARCH_pred for 601988.SS — R²: 0.4320, RMSE: 0.0049, MAE: 0.0026
# ✅ CatBoost + EGARCH_pred for 601988.SS — R²: 0.4405, RMSE: 0.0049, MAE: 0.0025
# ✅ AdaBoost + EGARCH_pred for 601988.SS — R²: 0.4658, RMSE: 0.0048, MAE: 0.0029
# ✅ KNN + EGARCH_pred for 601988.SS — R²: -0.5464, RMSE: 0.0081, MAE: 0.0054
# ✅ RandomForest + GARCH_pred for 601939.SS — R²: 0.9182, RMSE: 0.0011, MAE: 0.0008
# ✅ XGBoost + GARCH_pred for 601939.SS — R²: 0.8980, RMSE: 0.0013, MAE: 0.0009
# ✅ CatBoost + GARCH_pred for 601939.SS — R²: 0.9250, RMSE: 0.0011, MAE: 0.0009
# ✅ AdaBoost + GARCH_pred for 601939.SS — R²: 0.9420, RMSE: 0.0010, MAE: 0.0007
# ✅ KNN + GARCH_pred for 601939.SS — R²: -1.1241, RMSE: 0.0058, MAE: 0.0045
# ✅ RandomForest + GJR_pred for 601939.SS — R²: 0.9361, RMSE: 0.0010, MAE: 0.0008
# ✅ XGBoost + GJR_pred for 601939.SS — R²: 0.8927, RMSE: 0.0013, MAE: 0.0009
# ✅ CatBoost + GJR_pred for 601939.SS — R²: 0.9290, RMSE: 0.0011, MAE: 0.0008
# ✅ AdaBoost + GJR_pred for 601939.SS — R²: 0.9454, RMSE: 0.0009, MAE: 0.0007
# ✅ KNN + GJR_pred for 601939.SS — R²: -1.1241, RMSE: 0.0058, MAE: 0.0045
# ✅ RandomForest + EGARCH_pred for 601939.SS — R²: 0.9299, RMSE: 0.0010, MAE: 0.0008
# ✅ XGBoost + EGARCH_pred for 601939.SS — R²: 0.9030, RMSE: 0.0012, MAE: 0.0009
# ✅ CatBoost + EGARCH_pred for 601939.SS — R²: 0.9310, RMSE: 0.0010, MAE: 0.0008
# ✅ AdaBoost + EGARCH_pred for 601939.SS — R²: 0.9423, RMSE: 0.0009, MAE: 0.0008
# ✅ KNN + EGARCH_pred for 601939.SS — R²: -1.1241, RMSE: 0.0058, MAE: 0.0045
# ✅ RandomForest + GARCH_pred for 601288.SS — R²: 0.7107, RMSE: 0.0028, MAE: 0.0016
# ✅ XGBoost + GARCH_pred for 601288.SS — R²: 0.6985, RMSE: 0.0029, MAE: 0.0018
# ✅ CatBoost + GARCH_pred for 601288.SS — R²: 0.6316, RMSE: 0.0032, MAE: 0.0016
# ✅ AdaBoost + GARCH_pred for 601288.SS — R²: 0.7463, RMSE: 0.0027, MAE: 0.0016
# ✅ KNN + GARCH_pred for 601288.SS — R²: -0.7412, RMSE: 0.0070, MAE: 0.0050
# ✅ RandomForest + GJR_pred for 601288.SS — R²: 0.7245, RMSE: 0.0028, MAE: 0.0016
# ✅ XGBoost + GJR_pred for 601288.SS — R²: 0.6968, RMSE: 0.0029, MAE: 0.0019
# ✅ CatBoost + GJR_pred for 601288.SS — R²: 0.6127, RMSE: 0.0033, MAE: 0.0017
# ✅ AdaBoost + GJR_pred for 601288.SS — R²: 0.7379, RMSE: 0.0027, MAE: 0.0017
# ✅ KNN + GJR_pred for 601288.SS — R²: -0.7412, RMSE: 0.0070, MAE: 0.0050
# ✅ RandomForest + EGARCH_pred for 601288.SS — R²: 0.7330, RMSE: 0.0027, MAE: 0.0016
# ✅ XGBoost + EGARCH_pred for 601288.SS — R²: 0.6827, RMSE: 0.0030, MAE: 0.0019
# ✅ CatBoost + EGARCH_pred for 601288.SS — R²: 0.6264, RMSE: 0.0032, MAE: 0.0017
# ✅ AdaBoost + EGARCH_pred for 601288.SS — R²: 0.7356, RMSE: 0.0027, MAE: 0.0017
# ✅ KNN + EGARCH_pred for 601288.SS — R²: -0.7412, RMSE: 0.0070, MAE: 0.0050
# ✅ RandomForest + GARCH_pred for 600036.SS — R²: 0.8724, RMSE: 0.0018, MAE: 0.0014
# ✅ XGBoost + GARCH_pred for 600036.SS — R²: 0.6749, RMSE: 0.0030, MAE: 0.0023
# ✅ CatBoost + GARCH_pred for 600036.SS — R²: 0.7790, RMSE: 0.0024, MAE: 0.0019
# ✅ AdaBoost + GARCH_pred for 600036.SS — R²: 0.7782, RMSE: 0.0024, MAE: 0.0019
# ✅ KNN + GARCH_pred for 600036.SS — R²: -1.2963, RMSE: 0.0078, MAE: 0.0062
# ✅ RandomForest + GJR_pred for 600036.SS — R²: 0.8636, RMSE: 0.0019, MAE: 0.0015
# ✅ XGBoost + GJR_pred for 600036.SS — R²: 0.7699, RMSE: 0.0025, MAE: 0.0019
# ✅ CatBoost + GJR_pred for 600036.SS — R²: 0.7378, RMSE: 0.0026, MAE: 0.0021
# ✅ AdaBoost + GJR_pred for 600036.SS — R²: 0.8051, RMSE: 0.0023, MAE: 0.0018
# ✅ KNN + GJR_pred for 600036.SS — R²: -1.2963, RMSE: 0.0078, MAE: 0.0062
# ✅ RandomForest + EGARCH_pred for 600036.SS — R²: 0.8722, RMSE: 0.0018, MAE: 0.0014
# ✅ XGBoost + EGARCH_pred for 600036.SS — R²: 0.7513, RMSE: 0.0026, MAE: 0.0020
# ✅ CatBoost + EGARCH_pred for 600036.SS — R²: 0.7816, RMSE: 0.0024, MAE: 0.0019
# ✅ AdaBoost + EGARCH_pred for 600036.SS — R²: 0.7613, RMSE: 0.0025, MAE: 0.0019
# ✅ KNN + EGARCH_pred for 600036.SS — R²: -1.2963, RMSE: 0.0078, MAE: 0.0062
# ✅ RandomForest + GARCH_pred for 601328.SS — R²: 0.7058, RMSE: 0.0024, MAE: 0.0013
# ✅ XGBoost + GARCH_pred for 601328.SS — R²: 0.7275, RMSE: 0.0023, MAE: 0.0014
# ✅ CatBoost + GARCH_pred for 601328.SS — R²: 0.7088, RMSE: 0.0023, MAE: 0.0014
# ✅ AdaBoost + GARCH_pred for 601328.SS — R²: 0.7297, RMSE: 0.0023, MAE: 0.0015
# ✅ KNN + GARCH_pred for 601328.SS — R²: 0.0619, RMSE: 0.0042, MAE: 0.0033
# ✅ RandomForest + GJR_pred for 601328.SS — R²: 0.7021, RMSE: 0.0024, MAE: 0.0013
# ✅ XGBoost + GJR_pred for 601328.SS — R²: 0.7357, RMSE: 0.0022, MAE: 0.0013
# ✅ CatBoost + GJR_pred for 601328.SS — R²: 0.7029, RMSE: 0.0024, MAE: 0.0014
# ✅ AdaBoost + GJR_pred for 601328.SS — R²: 0.6798, RMSE: 0.0025, MAE: 0.0015
# ✅ KNN + GJR_pred for 601328.SS — R²: 0.0619, RMSE: 0.0042, MAE: 0.0033
# ✅ RandomForest + EGARCH_pred for 601328.SS — R²: 0.6779, RMSE: 0.0025, MAE: 0.0014
# ✅ XGBoost + EGARCH_pred for 601328.SS — R²: 0.7324, RMSE: 0.0023, MAE: 0.0013
# ✅ CatBoost + EGARCH_pred for 601328.SS — R²: 0.7075, RMSE: 0.0024, MAE: 0.0014
# ✅ AdaBoost + EGARCH_pred for 601328.SS — R²: 0.6863, RMSE: 0.0024, MAE: 0.0016
# ✅ KNN + EGARCH_pred for 601328.SS — R²: 0.0619, RMSE: 0.0042, MAE: 0.0033
# ✅ RandomForest + GARCH_pred for 601318.SS — R²: 0.9002, RMSE: 0.0016, MAE: 0.0010
# ✅ XGBoost + GARCH_pred for 601318.SS — R²: 0.9005, RMSE: 0.0016, MAE: 0.0010
# ✅ CatBoost + GARCH_pred for 601318.SS — R²: 0.8903, RMSE: 0.0017, MAE: 0.0011
# ✅ AdaBoost + GARCH_pred for 601318.SS — R²: 0.8846, RMSE: 0.0017, MAE: 0.0012
# ✅ KNN + GARCH_pred for 601318.SS — R²: -0.4310, RMSE: 0.0060, MAE: 0.0046
# ✅ RandomForest + GJR_pred for 601318.SS — R²: 0.9016, RMSE: 0.0016, MAE: 0.0010
# ✅ XGBoost + GJR_pred for 601318.SS — R²: 0.8804, RMSE: 0.0017, MAE: 0.0011
# ✅ CatBoost + GJR_pred for 601318.SS — R²: 0.8892, RMSE: 0.0017, MAE: 0.0011
# ✅ AdaBoost + GJR_pred for 601318.SS — R²: 0.8672, RMSE: 0.0018, MAE: 0.0012
# ✅ KNN + GJR_pred for 601318.SS — R²: -0.4310, RMSE: 0.0060, MAE: 0.0046
# ✅ RandomForest + EGARCH_pred for 601318.SS — R²: 0.9009, RMSE: 0.0016, MAE: 0.0010
# ✅ XGBoost + EGARCH_pred for 601318.SS — R²: 0.8870, RMSE: 0.0017, MAE: 0.0011
# ✅ CatBoost + EGARCH_pred for 601318.SS — R²: 0.8986, RMSE: 0.0016, MAE: 0.0011
# ✅ AdaBoost + EGARCH_pred for 601318.SS — R²: 0.8799, RMSE: 0.0017, MAE: 0.0011
# ✅ KNN + EGARCH_pred for 601318.SS — R²: -0.4310, RMSE: 0.0060, MAE: 0.0046
# ✅ RandomForest + GARCH_pred for 601628.SS — R²: 0.8507, RMSE: 0.0018, MAE: 0.0013
# ✅ XGBoost + GARCH_pred for 601628.SS — R²: 0.8205, RMSE: 0.0019, MAE: 0.0015
# ✅ CatBoost + GARCH_pred for 601628.SS — R²: 0.8384, RMSE: 0.0018, MAE: 0.0014
# ✅ AdaBoost + GARCH_pred for 601628.SS — R²: 0.7277, RMSE: 0.0024, MAE: 0.0019
# ✅ KNN + GARCH_pred for 601628.SS — R²: -0.1489, RMSE: 0.0049, MAE: 0.0041
# ✅ RandomForest + GJR_pred for 601628.SS — R²: 0.8438, RMSE: 0.0018, MAE: 0.0013
# ✅ XGBoost + GJR_pred for 601628.SS — R²: 0.8124, RMSE: 0.0020, MAE: 0.0014
# ✅ CatBoost + GJR_pred for 601628.SS — R²: 0.8454, RMSE: 0.0018, MAE: 0.0014
# ✅ AdaBoost + GJR_pred for 601628.SS — R²: 0.7735, RMSE: 0.0022, MAE: 0.0018
# ✅ KNN + GJR_pred for 601628.SS — R²: -0.1489, RMSE: 0.0049, MAE: 0.0041
# ✅ RandomForest + EGARCH_pred for 601628.SS — R²: 0.8526, RMSE: 0.0018, MAE: 0.0013
# ✅ XGBoost + EGARCH_pred for 601628.SS — R²: 0.8419, RMSE: 0.0018, MAE: 0.0013
# ✅ CatBoost + EGARCH_pred for 601628.SS — R²: 0.8782, RMSE: 0.0016, MAE: 0.0012
# ✅ AdaBoost + EGARCH_pred for 601628.SS — R²: 0.8073, RMSE: 0.0020, MAE: 0.0016
# ✅ KNN + EGARCH_pred for 601628.SS — R²: -0.1489, RMSE: 0.0049, MAE: 0.0041
# ✅ RandomForest + GARCH_pred for 601601.SS — R²: 0.8769, RMSE: 0.0020, MAE: 0.0014
# ✅ XGBoost + GARCH_pred for 601601.SS — R²: 0.8699, RMSE: 0.0020, MAE: 0.0015
# ✅ CatBoost + GARCH_pred for 601601.SS — R²: 0.8519, RMSE: 0.0021, MAE: 0.0016
# ✅ AdaBoost + GARCH_pred for 601601.SS — R²: 0.8392, RMSE: 0.0022, MAE: 0.0017
# ✅ KNN + GARCH_pred for 601601.SS — R²: -0.7167, RMSE: 0.0073, MAE: 0.0059
# ✅ RandomForest + GJR_pred for 601601.SS — R²: 0.8713, RMSE: 0.0020, MAE: 0.0015
# ✅ XGBoost + GJR_pred for 601601.SS — R²: 0.8673, RMSE: 0.0020, MAE: 0.0015
# ✅ CatBoost + GJR_pred for 601601.SS — R²: 0.8592, RMSE: 0.0021, MAE: 0.0016
# ✅ AdaBoost + GJR_pred for 601601.SS — R²: 0.8605, RMSE: 0.0021, MAE: 0.0015
# ✅ KNN + GJR_pred for 601601.SS — R²: -0.7167, RMSE: 0.0073, MAE: 0.0059
# ✅ RandomForest + EGARCH_pred for 601601.SS — R²: 0.8850, RMSE: 0.0019, MAE: 0.0013
# ✅ XGBoost + EGARCH_pred for 601601.SS — R²: 0.8776, RMSE: 0.0020, MAE: 0.0014
# ✅ CatBoost + EGARCH_pred for 601601.SS — R²: 0.8623, RMSE: 0.0021, MAE: 0.0015
# ✅ AdaBoost + EGARCH_pred for 601601.SS — R²: 0.8654, RMSE: 0.0020, MAE: 0.0015
# ✅ KNN + EGARCH_pred for 601601.SS — R²: -0.7167, RMSE: 0.0073, MAE: 0.0059
# ✅ RandomForest + GARCH_pred for 600016.SS — R²: 0.6378, RMSE: 0.0035, MAE: 0.0018
# ✅ XGBoost + GARCH_pred for 600016.SS — R²: 0.4717, RMSE: 0.0043, MAE: 0.0022
# ✅ CatBoost + GARCH_pred for 600016.SS — R²: 0.7179, RMSE: 0.0031, MAE: 0.0015
# ✅ AdaBoost + GARCH_pred for 600016.SS — R²: 0.7497, RMSE: 0.0029, MAE: 0.0018
# ✅ KNN + GARCH_pred for 600016.SS — R²: 0.0723, RMSE: 0.0056, MAE: 0.0042
# ✅ RandomForest + GJR_pred for 600016.SS — R²: 0.6428, RMSE: 0.0035, MAE: 0.0018
# ✅ XGBoost + GJR_pred for 600016.SS — R²: 0.4761, RMSE: 0.0042, MAE: 0.0022
# ✅ CatBoost + GJR_pred for 600016.SS — R²: 0.7202, RMSE: 0.0031, MAE: 0.0015
# ✅ AdaBoost + GJR_pred for 600016.SS — R²: 0.7278, RMSE: 0.0031, MAE: 0.0019
# ✅ KNN + GJR_pred for 600016.SS — R²: 0.0723, RMSE: 0.0056, MAE: 0.0042
# ✅ RandomForest + EGARCH_pred for 600016.SS — R²: 0.6021, RMSE: 0.0037, MAE: 0.0018
# ✅ XGBoost + EGARCH_pred for 600016.SS — R²: 0.4773, RMSE: 0.0042, MAE: 0.0022
# ✅ CatBoost + EGARCH_pred for 600016.SS — R²: 0.7216, RMSE: 0.0031, MAE: 0.0015
# ✅ AdaBoost + EGARCH_pred for 600016.SS — R²: 0.7287, RMSE: 0.0031, MAE: 0.0018
# ✅ KNN + EGARCH_pred for 600016.SS — R²: 0.0723, RMSE: 0.0056, MAE: 0.0042
# ✅ RandomForest + GARCH_pred for 601688.SS — R²: 0.8898, RMSE: 0.0014, MAE: 0.0010
# ✅ XGBoost + GARCH_pred for 601688.SS — R²: 0.8791, RMSE: 0.0015, MAE: 0.0011
# ✅ CatBoost + GARCH_pred for 601688.SS — R²: 0.8351, RMSE: 0.0017, MAE: 0.0013
# ✅ AdaBoost + GARCH_pred for 601688.SS — R²: 0.8531, RMSE: 0.0016, MAE: 0.0012
# ✅ KNN + GARCH_pred for 601688.SS — R²: -0.0869, RMSE: 0.0045, MAE: 0.0036
# ✅ RandomForest + GJR_pred for 601688.SS — R²: 0.8874, RMSE: 0.0014, MAE: 0.0010
# ✅ XGBoost + GJR_pred for 601688.SS — R²: 0.8581, RMSE: 0.0016, MAE: 0.0012
# ✅ CatBoost + GJR_pred for 601688.SS — R²: 0.8485, RMSE: 0.0017, MAE: 0.0013
# ✅ AdaBoost + GJR_pred for 601688.SS — R²: 0.8467, RMSE: 0.0017, MAE: 0.0013
# ✅ KNN + GJR_pred for 601688.SS — R²: -0.0869, RMSE: 0.0045, MAE: 0.0036
# ✅ RandomForest + EGARCH_pred for 601688.SS — R²: 0.8747, RMSE: 0.0015, MAE: 0.0011
# ✅ XGBoost + EGARCH_pred for 601688.SS — R²: 0.8656, RMSE: 0.0016, MAE: 0.0011
# ✅ CatBoost + EGARCH_pred for 601688.SS — R²: 0.8260, RMSE: 0.0018, MAE: 0.0014
# ✅ AdaBoost + EGARCH_pred for 601688.SS — R²: 0.8494, RMSE: 0.0017, MAE: 0.0013
# ✅ KNN + EGARCH_pred for 601688.SS — R²: -0.0869, RMSE: 0.0045, MAE: 0.0036
# ✅ RandomForest + GARCH_pred for 000776.SZ — R²: 0.8839, RMSE: 0.0020, MAE: 0.0015
# ✅ XGBoost + GARCH_pred for 000776.SZ — R²: 0.8186, RMSE: 0.0026, MAE: 0.0019
# ✅ CatBoost + GARCH_pred for 000776.SZ — R²: 0.6513, RMSE: 0.0035, MAE: 0.0030
# ✅ AdaBoost + GARCH_pred for 000776.SZ — R²: 0.7527, RMSE: 0.0030, MAE: 0.0024
# ✅ KNN + GARCH_pred for 000776.SZ — R²: -2.1375, RMSE: 0.0106, MAE: 0.0092
# ✅ RandomForest + GJR_pred for 000776.SZ — R²: 0.8796, RMSE: 0.0021, MAE: 0.0016
# ✅ XGBoost + GJR_pred for 000776.SZ — R²: 0.8043, RMSE: 0.0027, MAE: 0.0020
# ✅ CatBoost + GJR_pred for 000776.SZ — R²: 0.6194, RMSE: 0.0037, MAE: 0.0031
# ✅ AdaBoost + GJR_pred for 000776.SZ — R²: 0.7365, RMSE: 0.0031, MAE: 0.0025
# ✅ KNN + GJR_pred for 000776.SZ — R²: -2.1375, RMSE: 0.0106, MAE: 0.0092
# ✅ RandomForest + EGARCH_pred for 000776.SZ — R²: 0.8906, RMSE: 0.0020, MAE: 0.0015
# ✅ XGBoost + EGARCH_pred for 000776.SZ — R²: 0.8311, RMSE: 0.0025, MAE: 0.0019
# ✅ CatBoost + EGARCH_pred for 000776.SZ — R²: 0.5869, RMSE: 0.0039, MAE: 0.0032
# ✅ AdaBoost + EGARCH_pred for 000776.SZ — R²: 0.6915, RMSE: 0.0033, MAE: 0.0026
# ✅ KNN + EGARCH_pred for 000776.SZ — R²: -2.1375, RMSE: 0.0106, MAE: 0.0092
# 💾 Saved fusion model results to china_fusion_model_results.csv
#          Stock           Fusion_Model      R2    RMSE       MSE     MAE
# 38   601939.SS      GJR_pred+AdaBoost  0.9454  0.0009  0.000001  0.0007
# 43   601939.SS   EGARCH_pred+AdaBoost  0.9423  0.0009  0.000001  0.0008
# 33   601939.SS    GARCH_pred+AdaBoost  0.9420  0.0010  0.000001  0.0007
# 35   601939.SS  GJR_pred+RandomForest  0.9361  0.0010  0.000001  0.0008
# 42   601939.SS   EGARCH_pred+CatBoost  0.9310  0.0010  0.000001  0.0008
# ..         ...                    ...     ...     ...       ...     ...
# 69   600036.SS           GJR_pred+KNN -1.2963  0.0078  0.000061  0.0062
# 74   600036.SS        EGARCH_pred+KNN -1.2963  0.0078  0.000061  0.0062
# 169  000776.SZ         GARCH_pred+KNN -2.1375  0.0106  0.000113  0.0092
# 174  000776.SZ           GJR_pred+KNN -2.1375  0.0106  0.000113  0.0092
# 179  000776.SZ        EGARCH_pred+KNN -2.1375  0.0106  0.000113  0.0092
#
# [180 rows x 6 columns]
