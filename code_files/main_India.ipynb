# %%
import yfinance as yf
import pandas as pd
import numpy as np
from ta.momentum import RSIIndicator, StochasticOscillator
from ta.trend import MACD
from tqdm import tqdm

# Ticker symbols for the 12 stocks
tickers = [
    "HDFCBANK.NS", "ICICIBANK.NS", "SBIN.NS", "KOTAKBANK.NS", "AXISBANK.NS",
    "PNB.NS", "INDUSINDBK.NS", "BANDHANBNK.NS", "LICHSGFIN.NS", "HDFCLIFE.NS",
    "SBILIFE.NS", "UTIAMC.NS"
]

# Download historical OHLCV from 2014-01-01 to 2023-12-31
def download_data(ticker):
    data = yf.download(ticker, start="2014-01-01", end="2023-12-31")
    data = data.dropna()
    return data

stock_data = {ticker: download_data(ticker) for ticker in tqdm(tickers)}
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# 100%|██████████| 12/12 [00:05<00:00,  2.09it/s]

# %%
def compute_features(df):
    df = df.copy()

    # Ensure Close, High, Low are Series (1D)
    close = df["Close"].squeeze()
    high = df["High"].squeeze()
    low = df["Low"].squeeze()
    volume = df["Volume"].squeeze()

    print(f"Close dtype: {type(close)}, shape: {close.shape}")

    # Daily return
    df["Return"] = close.pct_change()

    # 30-day rolling volatility (target)
    df["Volatility"] = df["Return"].rolling(window=30).std()

    # RSI (14 days)
    df["RSI"] = RSIIndicator(close=close, window=14).rsi()

    # Momentum (5 days)
    df["MOM"] = close - close.shift(5)

    # OBV
    df["OBV"] = (np.sign(close.diff()) * volume).fillna(0).cumsum()

    # MACD
    macd = MACD(close=close, window_slow=26, window_fast=12, window_sign=9)
    df["MACD_LINE"] = macd.macd()
    df["MACD_SIGNAL"] = macd.macd_signal()
    df["MACD_HIST"] = macd.macd_diff()

    # Stochastic Oscillator
    stoch = StochasticOscillator(high=high, low=low, close=close, window=14, smooth_window=3)
    df["STO_K"] = stoch.stoch()           # formerly %K
    df["STO_D"] = stoch.stoch_signal()    # formerly %D

    # Lagged volatilities (t-1 to t-6)
    for i in range(1, 7):
        df[f"Vol_t_{i}"] = df["Volatility"].shift(i)

    # Volatility t+1 (our target)
    df["Vol_target"] = df["Volatility"].shift(-1)

    # Drop rows with NaNs
    df = df.dropna()

    return df

# %%
import os
import pickle

feature_data = {}
for ticker in tqdm(tickers):
    feature_data[ticker] = compute_features(stock_data[ticker])

feature_data_path = "India_feature_data.pkl"

if os.path.exists(feature_data_path):
    print("📦 Loading saved feature data from India_feature_data.pkl...")
    with open(feature_data_path, "rb") as f:
        feature_data = pickle.load(f)
else:
    print("⚙️ Computing feature data...")
    feature_data = {ticker: compute_features(stock_data[ticker]) for ticker in tqdm(tickers)}
    with open(feature_data_path, "wb") as f:
        pickle.dump(feature_data, f)
    print("💾 Saved feature data to India_feature_data.pkl")
# Out:
# 100%|██████████| 12/12 [00:00<00:00, 80.65it/s]
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2465,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2465,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2465,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2465,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2465,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2465,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2465,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (1423,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2465,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (1511,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (1543,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (797,)
# ⚙️ Computing feature data...
#   0%|          | 0/12 [00:00<?, ?it/s]
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2465,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2465,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2465,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2465,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2465,)
# 100%|██████████| 12/12 [00:00<00:00, 82.97it/s]
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2465,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2465,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (1423,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (2465,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (1511,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (1543,)
# Close dtype: <class 'pandas.core.series.Series'>, shape: (797,)
# 💾 Saved feature data to India_feature_data.pkl

# %%
from arch import arch_model
import warnings

def add_garch_predictions(df, ticker=None, verbose=True):
    df = df.copy()
    returns = df["Return"].dropna().values
    preds = []
    window_size = 500
    scale_factor = 100  # recommended by arch package

    if verbose:
        print(f"\n🔍 GARCH modeling for {ticker} — total points: {len(returns)}")

    for i in range(window_size, len(returns)):
        train_window = returns[i-window_size:i] * scale_factor  # rescale

        try:
            with warnings.catch_warnings():
                warnings.simplefilter("ignore")
                model = arch_model(train_window, vol='Garch', p=1, q=1, dist='normal', rescale=False)
                model_fit = model.fit(disp="off")
                forecast = model_fit.forecast(horizon=1)
                pred_vol_scaled = np.sqrt(forecast.variance.values[-1][0])
                pred_vol = pred_vol_scaled / scale_factor  # unscale
        except Exception as e:
            if verbose:
                print(f"⚠️ Failed at i={i} — {e}")
            pred_vol = np.nan

        preds.append(pred_vol)

        if verbose and i % 250 == 0:
            print(f"  → Index {i} | Pred Vol (unscaled): {pred_vol:.5f}")

    full_preds = [np.nan] * window_size + preds
    df["GARCH_pred"] = full_preds

    before = len(df)
    df = df.dropna()
    after = len(df)

    if verbose:
        print(f"✅ Done {ticker} | Rows dropped: {before - after} | Final: {after} rows")

    return df

# %%
# === Try loading precomputed garch_data from disk ===
garch_data_path = "India_garch_data.pkl"

if os.path.exists(garch_data_path):
    print("📦 Loading saved GARCH data from India_garch_data.pkl...")
    with open(garch_data_path, "rb") as f:
        garch_data = pickle.load(f)
    print("✅ Loaded GARCH data successfully!")
else:
    print("⚙️ Computing GARCH data from scratch...")
    garch_data = {}
    for ticker in tickers:
        print(f"\n====================== {ticker} ======================")
        garch_data[ticker] = add_garch_predictions(feature_data[ticker], ticker=ticker)

    # Save to disk
    with open(garch_data_path, "wb") as f:
        pickle.dump(garch_data, f)
    print("💾 Saved GARCH data to India_garch_data.pkl")
# Out:
# ⚙️ Computing GARCH data from scratch...
#
# ====================== HDFCBANK.NS ======================
#
# 🔍 GARCH modeling for HDFCBANK.NS — total points: 2428
#   → Index 500 | Pred Vol (unscaled): 0.01166
#   → Index 750 | Pred Vol (unscaled): 0.00910
#   → Index 1000 | Pred Vol (unscaled): 0.00954
#   → Index 1250 | Pred Vol (unscaled): 0.00975
#   → Index 1500 | Pred Vol (unscaled): 0.05400
#   → Index 1750 | Pred Vol (unscaled): 0.02548
#   → Index 2000 | Pred Vol (unscaled): 0.03073
#   → Index 2250 | Pred Vol (unscaled): 0.01220
# ✅ Done HDFCBANK.NS | Rows dropped: 500 | Final: 1928 rows
#
# ====================== ICICIBANK.NS ======================
#
# 🔍 GARCH modeling for ICICIBANK.NS — total points: 2428
#   → Index 500 | Pred Vol (unscaled): 0.01937
#   → Index 750 | Pred Vol (unscaled): 0.02107
#   → Index 1000 | Pred Vol (unscaled): 0.01896
#   → Index 1250 | Pred Vol (unscaled): 0.01590
#   → Index 1500 | Pred Vol (unscaled): 0.06086
#   → Index 1750 | Pred Vol (unscaled): 0.02125
#   → Index 2000 | Pred Vol (unscaled): 0.01926
#   → Index 2250 | Pred Vol (unscaled): 0.01404
# ✅ Done ICICIBANK.NS | Rows dropped: 500 | Final: 1928 rows
#
# ====================== SBIN.NS ======================
#
# 🔍 GARCH modeling for SBIN.NS — total points: 2428
#   → Index 500 | Pred Vol (unscaled): 0.03784
#   → Index 750 | Pred Vol (unscaled): 0.01386
#   → Index 1000 | Pred Vol (unscaled): 0.01483
#   → Index 1250 | Pred Vol (unscaled): 0.01998
#   → Index 1500 | Pred Vol (unscaled): 0.04680
#   → Index 1750 | Pred Vol (unscaled): 0.02135
#   → Index 2000 | Pred Vol (unscaled): 0.01934
#   → Index 2250 | Pred Vol (unscaled): 0.01494
# ✅ Done SBIN.NS | Rows dropped: 500 | Final: 1928 rows
#
# ====================== KOTAKBANK.NS ======================
#
# 🔍 GARCH modeling for KOTAKBANK.NS — total points: 2428
#   → Index 500 | Pred Vol (unscaled): 0.01732
#   → Index 750 | Pred Vol (unscaled): 0.01344
#   → Index 1000 | Pred Vol (unscaled): 0.01208
#   → Index 1250 | Pred Vol (unscaled): 0.01316
#   → Index 1500 | Pred Vol (unscaled): 0.03833
#   → Index 1750 | Pred Vol (unscaled): 0.01895
#   → Index 2000 | Pred Vol (unscaled): 0.01833
#   → Index 2250 | Pred Vol (unscaled): 0.01028
# ✅ Done KOTAKBANK.NS | Rows dropped: 500 | Final: 1928 rows
#
# ====================== AXISBANK.NS ======================
#
# 🔍 GARCH modeling for AXISBANK.NS — total points: 2428
#   → Index 500 | Pred Vol (unscaled): 0.01970
#   → Index 750 | Pred Vol (unscaled): 0.01799
#   → Index 1000 | Pred Vol (unscaled): 0.01741
#   → Index 1250 | Pred Vol (unscaled): 0.01594
#   → Index 1500 | Pred Vol (unscaled): 0.07273
#   → Index 1750 | Pred Vol (unscaled): 0.01991
#   → Index 2000 | Pred Vol (unscaled): 0.01981
#   → Index 2250 | Pred Vol (unscaled): 0.01452
# ✅ Done AXISBANK.NS | Rows dropped: 500 | Final: 1928 rows
#
# ====================== PNB.NS ======================
#
# 🔍 GARCH modeling for PNB.NS — total points: 2428
#   → Index 500 | Pred Vol (unscaled): 0.03075
#   → Index 750 | Pred Vol (unscaled): 0.01929
#   → Index 1000 | Pred Vol (unscaled): 0.02365
#   → Index 1250 | Pred Vol (unscaled): 0.02862
#   → Index 1500 | Pred Vol (unscaled): 0.02760
#   → Index 1750 | Pred Vol (unscaled): 0.02836
#   → Index 2000 | Pred Vol (unscaled): 0.02513
#   → Index 2250 | Pred Vol (unscaled): 0.02415
# ✅ Done PNB.NS | Rows dropped: 500 | Final: 1928 rows
#
# ====================== INDUSINDBK.NS ======================
#
# 🔍 GARCH modeling for INDUSINDBK.NS — total points: 2428
#   → Index 500 | Pred Vol (unscaled): 0.01706
#   → Index 750 | Pred Vol (unscaled): 0.01470
#   → Index 1000 | Pred Vol (unscaled): 0.01306
#   → Index 1250 | Pred Vol (unscaled): 0.01591
#   → Index 1500 | Pred Vol (unscaled): 0.17478
#   → Index 1750 | Pred Vol (unscaled): 0.02921
#   → Index 2000 | Pred Vol (unscaled): 0.02252
#   → Index 2250 | Pred Vol (unscaled): 0.01841
# ✅ Done INDUSINDBK.NS | Rows dropped: 500 | Final: 1928 rows
#
# ====================== BANDHANBNK.NS ======================
#
# 🔍 GARCH modeling for BANDHANBNK.NS — total points: 1386
#   → Index 500 | Pred Vol (unscaled): 0.04986
#   → Index 750 | Pred Vol (unscaled): 0.02561
#   → Index 1000 | Pred Vol (unscaled): 0.02482
#   → Index 1250 | Pred Vol (unscaled): 0.02241
# ✅ Done BANDHANBNK.NS | Rows dropped: 500 | Final: 886 rows
#
# ====================== LICHSGFIN.NS ======================
#
# 🔍 GARCH modeling for LICHSGFIN.NS — total points: 2428
#   → Index 500 | Pred Vol (unscaled): 0.02198
#   → Index 750 | Pred Vol (unscaled): 0.01862
#   → Index 1000 | Pred Vol (unscaled): 0.01794
#   → Index 1250 | Pred Vol (unscaled): 0.02079
#   → Index 1500 | Pred Vol (unscaled): 0.05649
#   → Index 1750 | Pred Vol (unscaled): 0.02483
#   → Index 2000 | Pred Vol (unscaled): 0.02418
#   → Index 2250 | Pred Vol (unscaled): 0.01929
# ✅ Done LICHSGFIN.NS | Rows dropped: 500 | Final: 1928 rows
#
# ====================== HDFCLIFE.NS ======================
#
# 🔍 GARCH modeling for HDFCLIFE.NS — total points: 1474
#   → Index 500 | Pred Vol (unscaled): 0.01588
#   → Index 750 | Pred Vol (unscaled): 0.01578
#   → Index 1000 | Pred Vol (unscaled): 0.01468
#   → Index 1250 | Pred Vol (unscaled): 0.01322
# ✅ Done HDFCLIFE.NS | Rows dropped: 500 | Final: 974 rows
#
# ====================== SBILIFE.NS ======================
#
# 🔍 GARCH modeling for SBILIFE.NS — total points: 1506
#   → Index 500 | Pred Vol (unscaled): 0.01752
#   → Index 750 | Pred Vol (unscaled): 0.01663
#   → Index 1000 | Pred Vol (unscaled): 0.01493
#   → Index 1250 | Pred Vol (unscaled): 0.01243
#   → Index 1500 | Pred Vol (unscaled): 0.01356
# ✅ Done SBILIFE.NS | Rows dropped: 500 | Final: 1006 rows
#
# ====================== UTIAMC.NS ======================
#
# 🔍 GARCH modeling for UTIAMC.NS — total points: 760
#   → Index 500 | Pred Vol (unscaled): 0.02656
#   → Index 750 | Pred Vol (unscaled): 0.01912
# ✅ Done UTIAMC.NS | Rows dropped: 500 | Final: 260 rows
# 💾 Saved GARCH data to India_garch_data.pkl

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
import numpy as np
import warnings
warnings.filterwarnings("ignore")

def evaluate(y_true, y_pred):
    return {
        "R2": r2_score(y_true, y_pred),
        "RMSE": mean_squared_error(y_true, y_pred, squared=False),
        "MSE": mean_squared_error(y_true, y_pred),
        "MAE": mean_absolute_error(y_true, y_pred),
    }

def train_ml_models_baseline(df, ticker="TICKER"):
    print(f"\n📈 Training ML models for {ticker}...")

    # Feature and target selection
    features = [
        'RSI', 'MOM', 'OBV', 'MACD_LINE', 'MACD_SIGNAL', 'MACD_HIST',
        'STO_K', 'STO_D',
        'Vol_t_1', 'Vol_t_2', 'Vol_t_3', 'Vol_t_4', 'Vol_t_5', 'Vol_t_6'
    ]

    X = df[features].copy()
    # Sanitize column names just in case LightGBM is sensitive
    X.columns = [str(col).replace("-", "_").replace("%", "PCT").replace(".", "_DOT_") for col in X.columns]

    y = df["Vol_target"]

    # Static train-test split (same as paper: 2014–2020 train, 2021–2023 test)
    split_idx = int(len(df) * 0.7)
    X_train, X_test = X.iloc[:split_idx], X.iloc[split_idx:]
    y_train, y_test = y.iloc[:split_idx], y.iloc[split_idx:]

    models = {
        "KNN": KNeighborsRegressor(),
        "AdaBoost": AdaBoostRegressor(),
        "CatBoost": CatBoostRegressor(verbose=0),
        #"LightGBM": LGBMRegressor(),
        "XGBoost": XGBRegressor(verbosity=0),
        "RandomForest": RandomForestRegressor()
    }

    results = {}

    for name, model in models.items():
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        metrics = evaluate(y_test, y_pred)
        results[name] = metrics
        print(f"✅ {name} — R²: {metrics['R2']:.4f}, RMSE: {metrics['RMSE']:.4f}, MAE: {metrics['MAE']:.4f}")

    return results
# Out:
# /shared/home/ads066/.local/lib/python3.11/site-packages/xgboost/core.py:377: FutureWarning: Your system has an old version of glibc (< 2.28). We will stop supporting Linux distros with glibc older than 2.28 after **May 31, 2025**. Please upgrade to a recent Linux distro (with glibc >= 2.28) to use future versions of XGBoost.
# Note: You have installed the 'manylinux2014' variant of XGBoost. Certain features such as GPU algorithms or federated learning are not available. To use these features, please upgrade to a recent Linux distro with glibc 2.28+, and install the 'manylinux_2_28' variant.
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

def evaluate(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    return {
        "R2": r2_score(y_true, y_pred),
        "RMSE": np.sqrt(mse),
        "MSE": mse,
        "MAE": mean_absolute_error(y_true, y_pred),
    }

def train_all_stocks_ml_baseline(garch_data_dict, results_path="India_ml_baseline_results.csv"):
    # Check if results already exist
    if os.path.exists(results_path):
        print(f"📦 Loading existing results from {results_path}...")
        return pd.read_csv(results_path)

    final_results = []

    for ticker, df in garch_data_dict.items():
        print(f"\n================= {ticker} =================")
        results = train_ml_models_baseline(df, ticker=ticker)

        for model_name, metrics in results.items():
            final_results.append({
                "Stock": ticker,
                "Model": model_name,
                "R2": round(metrics["R2"], 4),
                "RMSE": round(metrics["RMSE"], 4),
                "MSE": round(metrics["MSE"], 6),
                "MAE": round(metrics["MAE"], 4),
            })

    # Save results
    results_df = pd.DataFrame(final_results)
    results_df.to_csv(results_path, index=False)
    print(f"💾 Saved results to {results_path}")

    return results_df

# Run training or load existing results
ml_all_results = train_all_stocks_ml_baseline(garch_data)
ml_all_results_sorted = ml_all_results.sort_values(by="R2", ascending=False)
display(ml_all_results_sorted)
# Out:
# ================= HDFCBANK.NS =================
#
# 📈 Training ML models for HDFCBANK.NS...
# ✅ KNN — R²: -2.0136, RMSE: 0.0077, MAE: 0.0068
# ✅ AdaBoost — R²: 0.8690, RMSE: 0.0016, MAE: 0.0011
# ✅ CatBoost — R²: 0.8649, RMSE: 0.0016, MAE: 0.0012
# ✅ XGBoost — R²: 0.8966, RMSE: 0.0014, MAE: 0.0009
# ✅ RandomForest — R²: 0.9185, RMSE: 0.0013, MAE: 0.0008
#
# ================= ICICIBANK.NS =================
#
# 📈 Training ML models for ICICIBANK.NS...
# ✅ KNN — R²: -11.1402, RMSE: 0.0153, MAE: 0.0144
# ✅ AdaBoost — R²: -0.0277, RMSE: 0.0045, MAE: 0.0037
# ✅ CatBoost — R²: 0.6083, RMSE: 0.0027, MAE: 0.0022
# ✅ XGBoost — R²: 0.1282, RMSE: 0.0041, MAE: 0.0028
# ✅ RandomForest — R²: 0.6080, RMSE: 0.0027, MAE: 0.0019
#
# ================= SBIN.NS =================
#
# 📈 Training ML models for SBIN.NS...
# ✅ KNN — R²: -0.3261, RMSE: 0.0042, MAE: 0.0034
# ✅ AdaBoost — R²: 0.3450, RMSE: 0.0029, MAE: 0.0025
# ✅ CatBoost — R²: 0.7158, RMSE: 0.0019, MAE: 0.0014
# ✅ XGBoost — R²: 0.5728, RMSE: 0.0024, MAE: 0.0013
# ✅ RandomForest — R²: 0.4707, RMSE: 0.0026, MAE: 0.0015
#
# ================= KOTAKBANK.NS =================
#
# 📈 Training ML models for KOTAKBANK.NS...
# ✅ KNN — R²: -0.9131, RMSE: 0.0056, MAE: 0.0044
# ✅ AdaBoost — R²: 0.6920, RMSE: 0.0022, MAE: 0.0018
# ✅ CatBoost — R²: 0.8980, RMSE: 0.0013, MAE: 0.0009
# ✅ XGBoost — R²: 0.8798, RMSE: 0.0014, MAE: 0.0010
# ✅ RandomForest — R²: 0.8918, RMSE: 0.0013, MAE: 0.0009
#
# ================= AXISBANK.NS =================
#
# 📈 Training ML models for AXISBANK.NS...
# ✅ KNN — R²: -3.1630, RMSE: 0.0089, MAE: 0.0080
# ✅ AdaBoost — R²: 0.5088, RMSE: 0.0030, MAE: 0.0026
# ✅ CatBoost — R²: 0.8767, RMSE: 0.0015, MAE: 0.0011
# ✅ XGBoost — R²: 0.8674, RMSE: 0.0016, MAE: 0.0011
# ✅ RandomForest — R²: 0.8625, RMSE: 0.0016, MAE: 0.0012
#
# ================= PNB.NS =================
#
# 📈 Training ML models for PNB.NS...
# ✅ KNN — R²: -1.1367, RMSE: 0.0090, MAE: 0.0075
# ✅ AdaBoost — R²: 0.4622, RMSE: 0.0045, MAE: 0.0028
# ✅ CatBoost — R²: 0.7261, RMSE: 0.0032, MAE: 0.0021
# ✅ XGBoost — R²: 0.6857, RMSE: 0.0035, MAE: 0.0022
# ✅ RandomForest — R²: 0.7220, RMSE: 0.0033, MAE: 0.0019
#
# ================= INDUSINDBK.NS =================
#
# 📈 Training ML models for INDUSINDBK.NS...
# ✅ KNN — R²: -7.6979, RMSE: 0.0164, MAE: 0.0146
# ✅ AdaBoost — R²: 0.8756, RMSE: 0.0020, MAE: 0.0014
# ✅ CatBoost — R²: 0.9058, RMSE: 0.0017, MAE: 0.0013
# ✅ XGBoost — R²: 0.9159, RMSE: 0.0016, MAE: 0.0011
# ✅ RandomForest — R²: 0.9119, RMSE: 0.0017, MAE: 0.0011
#
# ================= BANDHANBNK.NS =================
#
# 📈 Training ML models for BANDHANBNK.NS...
# ✅ KNN — R²: -3.2783, RMSE: 0.0063, MAE: 0.0058
# ✅ AdaBoost — R²: -0.0988, RMSE: 0.0032, MAE: 0.0027
# ✅ CatBoost — R²: -0.0917, RMSE: 0.0032, MAE: 0.0025
# ✅ XGBoost — R²: 0.6509, RMSE: 0.0018, MAE: 0.0014
# ✅ RandomForest — R²: 0.7088, RMSE: 0.0017, MAE: 0.0012
#
# ================= LICHSGFIN.NS =================
#
# 📈 Training ML models for LICHSGFIN.NS...
# ✅ KNN — R²: -0.1571, RMSE: 0.0057, MAE: 0.0041
# ✅ AdaBoost — R²: 0.8632, RMSE: 0.0020, MAE: 0.0014
# ✅ CatBoost — R²: 0.8593, RMSE: 0.0020, MAE: 0.0015
# ✅ XGBoost — R²: 0.8548, RMSE: 0.0020, MAE: 0.0014
# ✅ RandomForest — R²: 0.8786, RMSE: 0.0018, MAE: 0.0012
#
# ================= HDFCLIFE.NS =================
#
# 📈 Training ML models for HDFCLIFE.NS...
# ✅ KNN — R²: -0.3792, RMSE: 0.0056, MAE: 0.0050
# ✅ AdaBoost — R²: 0.8552, RMSE: 0.0018, MAE: 0.0011
# ✅ CatBoost — R²: 0.8184, RMSE: 0.0020, MAE: 0.0014
# ✅ XGBoost — R²: 0.8748, RMSE: 0.0017, MAE: 0.0011
# ✅ RandomForest — R²: 0.8745, RMSE: 0.0017, MAE: 0.0010
#
# ================= SBILIFE.NS =================
#
# 📈 Training ML models for SBILIFE.NS...
# ✅ KNN — R²: -2.7521, RMSE: 0.0062, MAE: 0.0059
# ✅ AdaBoost — R²: 0.1704, RMSE: 0.0029, MAE: 0.0027
# ✅ CatBoost — R²: 0.7239, RMSE: 0.0017, MAE: 0.0012
# ✅ XGBoost — R²: 0.7970, RMSE: 0.0014, MAE: 0.0010
# ✅ RandomForest — R²: 0.8386, RMSE: 0.0013, MAE: 0.0009
#
# ================= UTIAMC.NS =================
#
# 📈 Training ML models for UTIAMC.NS...
# ✅ KNN — R²: -19.0613, RMSE: 0.0081, MAE: 0.0079
# ✅ AdaBoost — R²: 0.4779, RMSE: 0.0013, MAE: 0.0010
# ✅ CatBoost — R²: 0.1953, RMSE: 0.0016, MAE: 0.0012
# ✅ XGBoost — R²: -0.8279, RMSE: 0.0024, MAE: 0.0019
# ✅ RandomForest — R²: -0.0113, RMSE: 0.0018, MAE: 0.0014
# 💾 Saved results to India_ml_baseline_results.csv
#             Stock         Model       R2    RMSE       MSE     MAE
# 4     HDFCBANK.NS  RandomForest   0.9185  0.0013  0.000002  0.0008
# 33  INDUSINDBK.NS       XGBoost   0.9159  0.0016  0.000003  0.0011
# 34  INDUSINDBK.NS  RandomForest   0.9119  0.0017  0.000003  0.0011
# 32  INDUSINDBK.NS      CatBoost   0.9058  0.0017  0.000003  0.0013
# 17   KOTAKBANK.NS      CatBoost   0.8980  0.0013  0.000002  0.0009
# 3     HDFCBANK.NS       XGBoost   0.8966  0.0014  0.000002  0.0009
# 19   KOTAKBANK.NS  RandomForest   0.8918  0.0013  0.000002  0.0009
# 18   KOTAKBANK.NS       XGBoost   0.8798  0.0014  0.000002  0.0010
# 44   LICHSGFIN.NS  RandomForest   0.8786  0.0018  0.000003  0.0012
# 22    AXISBANK.NS      CatBoost   0.8767  0.0015  0.000002  0.0011
# 31  INDUSINDBK.NS      AdaBoost   0.8756  0.0020  0.000004  0.0014
# 48    HDFCLIFE.NS       XGBoost   0.8748  0.0017  0.000003  0.0011
# 49    HDFCLIFE.NS  RandomForest   0.8745  0.0017  0.000003  0.0010
# 1     HDFCBANK.NS      AdaBoost   0.8690  0.0016  0.000003  0.0011
# 23    AXISBANK.NS       XGBoost   0.8674  0.0016  0.000003  0.0011
# 2     HDFCBANK.NS      CatBoost   0.8649  0.0016  0.000003  0.0012
# 41   LICHSGFIN.NS      AdaBoost   0.8632  0.0020  0.000004  0.0014
# 24    AXISBANK.NS  RandomForest   0.8625  0.0016  0.000003  0.0012
# 42   LICHSGFIN.NS      CatBoost   0.8593  0.0020  0.000004  0.0015
# 46    HDFCLIFE.NS      AdaBoost   0.8552  0.0018  0.000003  0.0011
# 43   LICHSGFIN.NS       XGBoost   0.8548  0.0020  0.000004  0.0014
# 54     SBILIFE.NS  RandomForest   0.8386  0.0013  0.000002  0.0009
# 47    HDFCLIFE.NS      CatBoost   0.8184  0.0020  0.000004  0.0014
# 53     SBILIFE.NS       XGBoost   0.7970  0.0014  0.000002  0.0010
# 27         PNB.NS      CatBoost   0.7261  0.0032  0.000010  0.0021
# 52     SBILIFE.NS      CatBoost   0.7239  0.0017  0.000003  0.0012
# 29         PNB.NS  RandomForest   0.7220  0.0033  0.000011  0.0019
# 12        SBIN.NS      CatBoost   0.7158  0.0019  0.000004  0.0014
# 39  BANDHANBNK.NS  RandomForest   0.7088  0.0017  0.000003  0.0012
# 16   KOTAKBANK.NS      AdaBoost   0.6920  0.0022  0.000005  0.0018
# 28         PNB.NS       XGBoost   0.6857  0.0035  0.000012  0.0022
# 38  BANDHANBNK.NS       XGBoost   0.6509  0.0018  0.000003  0.0014
# 7    ICICIBANK.NS      CatBoost   0.6083  0.0027  0.000008  0.0022
# 9    ICICIBANK.NS  RandomForest   0.6080  0.0027  0.000008  0.0019
# 13        SBIN.NS       XGBoost   0.5728  0.0024  0.000006  0.0013
# 21    AXISBANK.NS      AdaBoost   0.5088  0.0030  0.000009  0.0026
# 56      UTIAMC.NS      AdaBoost   0.4779  0.0013  0.000002  0.0010
# 14        SBIN.NS  RandomForest   0.4707  0.0026  0.000007  0.0015
# 26         PNB.NS      AdaBoost   0.4622  0.0045  0.000021  0.0028
# 11        SBIN.NS      AdaBoost   0.3450  0.0029  0.000009  0.0025
# 57      UTIAMC.NS      CatBoost   0.1953  0.0016  0.000003  0.0012
# 51     SBILIFE.NS      AdaBoost   0.1704  0.0029  0.000009  0.0027
# 8    ICICIBANK.NS       XGBoost   0.1282  0.0041  0.000017  0.0028
# 59      UTIAMC.NS  RandomForest  -0.0113  0.0018  0.000003  0.0014
# 6    ICICIBANK.NS      AdaBoost  -0.0277  0.0045  0.000020  0.0037
# 37  BANDHANBNK.NS      CatBoost  -0.0917  0.0032  0.000010  0.0025
# 36  BANDHANBNK.NS      AdaBoost  -0.0988  0.0032  0.000010  0.0027
# 40   LICHSGFIN.NS           KNN  -0.1571  0.0057  0.000032  0.0041
# 10        SBIN.NS           KNN  -0.3261  0.0042  0.000017  0.0034
# 45    HDFCLIFE.NS           KNN  -0.3792  0.0056  0.000032  0.0050
# 58      UTIAMC.NS       XGBoost  -0.8279  0.0024  0.000006  0.0019
# 15   KOTAKBANK.NS           KNN  -0.9131  0.0056  0.000031  0.0044
# 25         PNB.NS           KNN  -1.1367  0.0090  0.000082  0.0075
# 0     HDFCBANK.NS           KNN  -2.0136  0.0077  0.000060  0.0068
# 50     SBILIFE.NS           KNN  -2.7521  0.0062  0.000039  0.0059
# 20    AXISBANK.NS           KNN  -3.1630  0.0089  0.000079  0.0080
# 35  BANDHANBNK.NS           KNN  -3.2783  0.0063  0.000040  0.0058
# 30  INDUSINDBK.NS           KNN  -7.6979  0.0164  0.000270  0.0146
# 5    ICICIBANK.NS           KNN -11.1402  0.0153  0.000234  0.0144
# 55      UTIAMC.NS           KNN -19.0613  0.0081  0.000065  0.0079

# %%
from arch import arch_model
import numpy as np
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

def evaluate_series(y_true, y_pred):
    return {
        "R2": r2_score(y_true, y_pred),
        "RMSE": mean_squared_error(y_true, y_pred, squared=False),
        "MSE": mean_squared_error(y_true, y_pred),
        "MAE": mean_absolute_error(y_true, y_pred),
    }

def forecast_volatility_arch(df, model_type="GARCH", ticker="TICKER", verbose=True):
    df = df.copy()

    # Flatten columns if MultiIndex
    if isinstance(df.columns, pd.MultiIndex):
        df.columns = ['_'.join([str(i) for i in col if i]) for col in df.columns]

    if "Vol_target" not in df.columns or "Return" not in df.columns:
        raise KeyError(f"Missing 'Vol_target' or 'Return' in {ticker}")

    returns = df["Return"].dropna().values
    preds = []
    window_size = 500
    scale_factor = 100  # fix for scale warning

    if verbose:
        print(f"\n🔮 Running {model_type} for {ticker}...")

    for i in range(window_size, len(returns)):
        train_window = returns[i-window_size:i] * scale_factor

        try:
            if model_type == "GARCH":
                model = arch_model(train_window, vol='GARCH', p=1, q=1, dist='normal', rescale=False)
            elif model_type == "GJR":
                model = arch_model(train_window, vol='GARCH', p=1, o=1, q=1, dist='normal', rescale=False)
            elif model_type == "EGARCH":
                model = arch_model(train_window, vol='EGARCH', p=1, q=1, dist='normal', rescale=False)
            else:
                raise ValueError("Invalid model_type")

            model_fit = model.fit(disp="off")
            forecast = model_fit.forecast(horizon=1)
            pred_vol = np.sqrt(forecast.variance.values[-1][0]) / scale_factor

        except Exception as e:
            if verbose:
                print(f"⚠️ {model_type} failed at index {i}: {e}")
            pred_vol = np.nan

        preds.append(pred_vol)

        if verbose and i % 250 == 0:
            print(f"  → {model_type} | index {i} | vol: {pred_vol:.5f}")

    df[f"{model_type}_pred"] = [np.nan] * window_size + preds
    df = df.dropna(subset=["Vol_target", f"{model_type}_pred"])

    metrics = evaluate_series(df["Vol_target"], df[f"{model_type}_pred"])
    if verbose:
        print(f"✅ {model_type} for {ticker} — R²: {metrics['R2']:.4f}, RMSE: {metrics['RMSE']:.4f}, MAE: {metrics['MAE']:.4f}")

    return df, metrics

# %%
import os
import pandas as pd

def evaluate_all_series_models(garch_data_dict, results_path="India_ts_model_results.csv"):
    # If results already exist, load them
    if os.path.exists(results_path):
        print(f"📦 Loading saved time series results from {results_path}...")
        return pd.read_csv(results_path)

    results = []

    for ticker, df in garch_data_dict.items():
        for model_type in ["GARCH", "GJR", "EGARCH"]:
            print(f"\n================= {ticker} - {model_type} =================")
            try:
                _, metrics = forecast_volatility_arch(df, model_type=model_type, ticker=ticker, verbose=True)
                results.append({
                    "Stock": ticker,
                    "Model": model_type,
                    "R2": round(metrics["R2"], 4),
                    "RMSE": round(metrics["RMSE"], 4),
                    "MSE": round(metrics["MSE"], 6),
                    "MAE": round(metrics["MAE"], 4),
                })
            except Exception as e:
                print(f"⚠️ Skipping {ticker} - {model_type}: {e}")

    df_results = pd.DataFrame(results)
    df_results.to_csv(results_path, index=False)
    print(f"💾 Saved time series model results to {results_path}")

    return df_results

ts_model_results = evaluate_all_series_models(garch_data)
ts_model_results_sorted = ts_model_results.sort_values(by="R2", ascending=False)
display(ts_model_results_sorted)
# Out:
# ================= HDFCBANK.NS - GARCH =================
#
# 🔮 Running GARCH for HDFCBANK.NS...
#   → GARCH | index 500 | vol: 0.00954
#   → GARCH | index 750 | vol: 0.00975
#   → GARCH | index 1000 | vol: 0.05400
#   → GARCH | index 1250 | vol: 0.02548
#   → GARCH | index 1500 | vol: 0.03073
#   → GARCH | index 1750 | vol: 0.01220
# ✅ GARCH for HDFCBANK.NS — R²: 0.6730, RMSE: 0.0043, MAE: 0.0026
#
# ================= HDFCBANK.NS - GJR =================
#
# 🔮 Running GJR for HDFCBANK.NS...
#   → GJR | index 500 | vol: 0.00973
#   → GJR | index 750 | vol: 0.00977
#   → GJR | index 1000 | vol: 0.05564
#   → GJR | index 1250 | vol: 0.02526
#   → GJR | index 1500 | vol: 0.02704
#   → GJR | index 1750 | vol: 0.01152
# ✅ GJR for HDFCBANK.NS — R²: 0.5902, RMSE: 0.0049, MAE: 0.0027
#
# ================= HDFCBANK.NS - EGARCH =================
#
# 🔮 Running EGARCH for HDFCBANK.NS...
#   → EGARCH | index 500 | vol: 0.00956
#   → EGARCH | index 750 | vol: 0.01008
#   → EGARCH | index 1000 | vol: 0.04784
#   → EGARCH | index 1250 | vol: 0.02533
#   → EGARCH | index 1500 | vol: 0.02726
#   → EGARCH | index 1750 | vol: 0.01186
# ✅ EGARCH for HDFCBANK.NS — R²: 0.6276, RMSE: 0.0046, MAE: 0.0026
#
# ================= ICICIBANK.NS - GARCH =================
#
# 🔮 Running GARCH for ICICIBANK.NS...
#   → GARCH | index 500 | vol: 0.01896
#   → GARCH | index 750 | vol: 0.01590
#   → GARCH | index 1000 | vol: 0.06086
#   → GARCH | index 1250 | vol: 0.02125
#   → GARCH | index 1500 | vol: 0.01926
#   → GARCH | index 1750 | vol: 0.01404
# ✅ GARCH for ICICIBANK.NS — R²: 0.7662, RMSE: 0.0048, MAE: 0.0035
#
# ================= ICICIBANK.NS - GJR =================
#
# 🔮 Running GJR for ICICIBANK.NS...
#   → GJR | index 500 | vol: 0.02227
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → GJR | index 750 | vol: 0.01428
#   → GJR | index 1000 | vol: 0.08117
#   → GJR | index 1250 | vol: 0.02285
#   → GJR | index 1500 | vol: 0.01971
#   → GJR | index 1750 | vol: 0.01380
# ✅ GJR for ICICIBANK.NS — R²: 0.7145, RMSE: 0.0053, MAE: 0.0036
#
# ================= ICICIBANK.NS - EGARCH =================
#
# 🔮 Running EGARCH for ICICIBANK.NS...
#   → EGARCH | index 500 | vol: 0.02011
#   → EGARCH | index 750 | vol: 0.01582
#   → EGARCH | index 1000 | vol: 0.05663
#   → EGARCH | index 1250 | vol: 0.02397
#   → EGARCH | index 1500 | vol: 0.01919
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 1750 | vol: 0.01369
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# ✅ EGARCH for ICICIBANK.NS — R²: -9.7854, RMSE: 0.0324, MAE: 0.0054
#
# ================= SBIN.NS - GARCH =================
#
# 🔮 Running GARCH for SBIN.NS...
#   → GARCH | index 500 | vol: 0.01483
#   → GARCH | index 750 | vol: 0.01998
#   → GARCH | index 1000 | vol: 0.04680
#   → GARCH | index 1250 | vol: 0.02135
#   → GARCH | index 1500 | vol: 0.01934
#   → GARCH | index 1750 | vol: 0.01494
# ✅ GARCH for SBIN.NS — R²: 0.3347, RMSE: 0.0064, MAE: 0.0042
#
# ================= SBIN.NS - GJR =================
#
# 🔮 Running GJR for SBIN.NS...
#   → GJR | index 500 | vol: 0.01468
#   → GJR | index 750 | vol: 0.01790
#   → GJR | index 1000 | vol: 0.05375
#   → GJR | index 1250 | vol: 0.02148
#   → GJR | index 1500 | vol: 0.01941
#   → GJR | index 1750 | vol: 0.01465
# ✅ GJR for SBIN.NS — R²: 0.3382, RMSE: 0.0064, MAE: 0.0041
#
# ================= SBIN.NS - EGARCH =================
#
# 🔮 Running EGARCH for SBIN.NS...
#   → EGARCH | index 500 | vol: 0.01641
#   → EGARCH | index 750 | vol: 0.02095
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 1000 | vol: 0.04525
#   → EGARCH | index 1250 | vol: 0.02179
#   → EGARCH | index 1500 | vol: 0.01950
#   → EGARCH | index 1750 | vol: 0.01486
# ✅ EGARCH for SBIN.NS — R²: 0.3033, RMSE: 0.0066, MAE: 0.0041
#
# ================= KOTAKBANK.NS - GARCH =================
#
# 🔮 Running GARCH for KOTAKBANK.NS...
#   → GARCH | index 500 | vol: 0.01208
#   → GARCH | index 750 | vol: 0.01316
#   → GARCH | index 1000 | vol: 0.03833
#   → GARCH | index 1250 | vol: 0.01895
#   → GARCH | index 1500 | vol: 0.01833
#   → GARCH | index 1750 | vol: 0.01028
# ✅ GARCH for KOTAKBANK.NS — R²: 0.5702, RMSE: 0.0052, MAE: 0.0031
#
# ================= KOTAKBANK.NS - GJR =================
#
# 🔮 Running GJR for KOTAKBANK.NS...
#   → GJR | index 500 | vol: 0.01159
#   → GJR | index 750 | vol: 0.01406
#   → GJR | index 1000 | vol: 0.04146
#   → GJR | index 1250 | vol: 0.01837
#   → GJR | index 1500 | vol: 0.01820
#   → GJR | index 1750 | vol: 0.01031
# ✅ GJR for KOTAKBANK.NS — R²: 0.4921, RMSE: 0.0057, MAE: 0.0032
#
# ================= KOTAKBANK.NS - EGARCH =================
#
# 🔮 Running EGARCH for KOTAKBANK.NS...
#   → EGARCH | index 500 | vol: 0.01228
#   → EGARCH | index 750 | vol: 0.01339
#   → EGARCH | index 1000 | vol: 0.03650
#   → EGARCH | index 1250 | vol: 0.01933
#   → EGARCH | index 1500 | vol: 0.01975
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 1750 | vol: 0.01090
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# ✅ EGARCH for KOTAKBANK.NS — R²: -1.8216, RMSE: 0.0133, MAE: 0.0045
#
# ================= AXISBANK.NS - GARCH =================
#
# 🔮 Running GARCH for AXISBANK.NS...
#   → GARCH | index 500 | vol: 0.01741
#   → GARCH | index 750 | vol: 0.01594
#   → GARCH | index 1000 | vol: 0.07273
#   → GARCH | index 1250 | vol: 0.01991
#   → GARCH | index 1500 | vol: 0.01981
#   → GARCH | index 1750 | vol: 0.01452
# ✅ GARCH for AXISBANK.NS — R²: 0.7944, RMSE: 0.0052, MAE: 0.0033
#
# ================= AXISBANK.NS - GJR =================
#
# 🔮 Running GJR for AXISBANK.NS...
#   → GJR | index 500 | vol: 0.01751
#   → GJR | index 750 | vol: 0.01408
#   → GJR | index 1000 | vol: 0.10624
#   → GJR | index 1250 | vol: 0.02203
#   → GJR | index 1500 | vol: 0.02009
#   → GJR | index 1750 | vol: 0.01514
# ✅ GJR for AXISBANK.NS — R²: 0.6335, RMSE: 0.0070, MAE: 0.0037
#
# ================= AXISBANK.NS - EGARCH =================
#
# 🔮 Running EGARCH for AXISBANK.NS...
#   → EGARCH | index 500 | vol: 0.01756
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 750 | vol: 0.01575
#   → EGARCH | index 1000 | vol: 0.06822
#   → EGARCH | index 1250 | vol: 0.02098
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 1500 | vol: 0.01994
#   → EGARCH | index 1750 | vol: 0.01406
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# ✅ EGARCH for AXISBANK.NS — R²: -2728990818470082600235954438208817883957803210078420992.0000, RMSE: 19121642898076908004573184.0000, MAE: 506012330261282375598080.0000
#
# ================= PNB.NS - GARCH =================
#
# 🔮 Running GARCH for PNB.NS...
#   → GARCH | index 500 | vol: 0.02365
#   → GARCH | index 750 | vol: 0.02862
#   → GARCH | index 1000 | vol: 0.02760
#   → GARCH | index 1250 | vol: 0.02836
#   → GARCH | index 1500 | vol: 0.02513
#   → GARCH | index 1750 | vol: 0.02415
# ✅ GARCH for PNB.NS — R²: -0.3923, RMSE: 0.0078, MAE: 0.0054
#
# ================= PNB.NS - GJR =================
#
# 🔮 Running GJR for PNB.NS...
#   → GJR | index 500 | vol: 0.02352
#   → GJR | index 750 | vol: 0.02598
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → GJR | index 1000 | vol: 0.03360
#   → GJR | index 1250 | vol: 0.02851
#   → GJR | index 1500 | vol: 0.02514
#   → GJR | index 1750 | vol: 0.02415
# ✅ GJR for PNB.NS — R²: -0.1339, RMSE: 0.0071, MAE: 0.0051
#
# ================= PNB.NS - EGARCH =================
#
# 🔮 Running EGARCH for PNB.NS...
#   → EGARCH | index 500 | vol: 0.02120
#   → EGARCH | index 750 | vol: 0.02930
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 1000 | vol: 0.02827
#   → EGARCH | index 1250 | vol: 0.02921
#   → EGARCH | index 1500 | vol: 0.02363
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 1750 | vol: 0.02428
# ✅ EGARCH for PNB.NS — R²: -9.0306, RMSE: 0.0210, MAE: 0.0081
#
# ================= INDUSINDBK.NS - GARCH =================
#
# 🔮 Running GARCH for INDUSINDBK.NS...
#   → GARCH | index 500 | vol: 0.01306
#   → GARCH | index 750 | vol: 0.01591
#   → GARCH | index 1000 | vol: 0.17478
#   → GARCH | index 1250 | vol: 0.02921
#   → GARCH | index 1500 | vol: 0.02252
#   → GARCH | index 1750 | vol: 0.01841
# ✅ GARCH for INDUSINDBK.NS — R²: 0.6981, RMSE: 0.0096, MAE: 0.0052
#
# ================= INDUSINDBK.NS - GJR =================
#
# 🔮 Running GJR for INDUSINDBK.NS...
#   → GJR | index 500 | vol: 0.01224
#   → GJR | index 750 | vol: 0.01289
#   → GJR | index 1000 | vol: 0.15863
#   → GJR | index 1250 | vol: 0.02694
#   → GJR | index 1500 | vol: 0.02182
#   → GJR | index 1750 | vol: 0.01834
# ✅ GJR for INDUSINDBK.NS — R²: 0.6906, RMSE: 0.0097, MAE: 0.0054
#
# ================= INDUSINDBK.NS - EGARCH =================
#
# 🔮 Running EGARCH for INDUSINDBK.NS...
#   → EGARCH | index 500 | vol: 0.01249
#   → EGARCH | index 750 | vol: 0.01552
#   → EGARCH | index 1000 | vol: 0.16599
#   → EGARCH | index 1250 | vol: 0.02780
#   → EGARCH | index 1500 | vol: 0.02296
#   → EGARCH | index 1750 | vol: 0.01955
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# ✅ EGARCH for INDUSINDBK.NS — R²: -.0000, RMSE: 3548082228336249489277175280857200682944659959820583704956787519648408840093070639391484899816766605183701185402606591756104108714640102741963261870080.0000, MAE: 93892212394554880359968352884840155023734561447374586723114122614165815188560035724142319670825774971336611121019123484563167480685498826377012445184.0000
#
# ================= BANDHANBNK.NS - GARCH =================
#
# 🔮 Running GARCH for BANDHANBNK.NS...
#   → GARCH | index 500 | vol: 0.02482
#   → GARCH | index 750 | vol: 0.02241
# ✅ GARCH for BANDHANBNK.NS — R²: 0.0313, RMSE: 0.0046, MAE: 0.0038
#
# ================= BANDHANBNK.NS - GJR =================
#
# 🔮 Running GJR for BANDHANBNK.NS...
#   → GJR | index 500 | vol: 0.02514
#   → GJR | index 750 | vol: 0.02254
# ✅ GJR for BANDHANBNK.NS — R²: -0.0646, RMSE: 0.0048, MAE: 0.0040
#
# ================= BANDHANBNK.NS - EGARCH =================
#
# 🔮 Running EGARCH for BANDHANBNK.NS...
#   → EGARCH | index 500 | vol: 0.02524
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 750 | vol: 0.02272
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# ✅ EGARCH for BANDHANBNK.NS — R²: -7.7342, RMSE: 0.0139, MAE: 0.0070
#
# ================= LICHSGFIN.NS - GARCH =================
#
# 🔮 Running GARCH for LICHSGFIN.NS...
#   → GARCH | index 500 | vol: 0.01794
#   → GARCH | index 750 | vol: 0.02079
#   → GARCH | index 1000 | vol: 0.05649
#   → GARCH | index 1250 | vol: 0.02483
#   → GARCH | index 1500 | vol: 0.02418
#   → GARCH | index 1750 | vol: 0.01929
# ✅ GARCH for LICHSGFIN.NS — R²: 0.8003, RMSE: 0.0042, MAE: 0.0033
#
# ================= LICHSGFIN.NS - GJR =================
#
# 🔮 Running GJR for LICHSGFIN.NS...
#   → GJR | index 500 | vol: 0.01710
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → GJR | index 750 | vol: 0.02079
#   → GJR | index 1000 | vol: 0.05772
#   → GJR | index 1250 | vol: 0.02605
#   → GJR | index 1500 | vol: 0.02498
#   → GJR | index 1750 | vol: 0.01875
# ✅ GJR for LICHSGFIN.NS — R²: 0.7598, RMSE: 0.0046, MAE: 0.0036
#
# ================= LICHSGFIN.NS - EGARCH =================
#
# 🔮 Running EGARCH for LICHSGFIN.NS...
#   → EGARCH | index 500 | vol: 0.01822
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# ...
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 750 | vol: 0.00000
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   → EGARCH | index 1000 | vol: 0.06123
#   → EGARCH | index 1250 | vol: 0.02617
#   → EGARCH | index 1500 | vol: 0.02408
#   → EGARCH | index 1750 | vol: 0.01989
# ✅ EGARCH for LICHSGFIN.NS — R²: -50811803394610269564306657902592.0000, RMSE: 66958676969591.5000, MAE: 1771914492138.2888
#
# ================= HDFCLIFE.NS - GARCH =================
#
# 🔮 Running GARCH for HDFCLIFE.NS...
#   → GARCH | index 500 | vol: 0.01468
#   → GARCH | index 750 | vol: 0.01322
# ✅ GARCH for HDFCLIFE.NS — R²: -0.1147, RMSE: 0.0053, MAE: 0.0037
#
# ================= HDFCLIFE.NS - GJR =================
#
# 🔮 Running GJR for HDFCLIFE.NS...
#   → GJR | index 500 | vol: 0.01510
#   → GJR | index 750 | vol: 0.01281
# ✅ GJR for HDFCLIFE.NS — R²: -0.0420, RMSE: 0.0051, MAE: 0.0035
#
# ================= HDFCLIFE.NS - EGARCH =================
#
# 🔮 Running EGARCH for HDFCLIFE.NS...
#   → EGARCH | index 500 | vol: 0.01533
#   → EGARCH | index 750 | vol: 0.01225
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# ✅ EGARCH for HDFCLIFE.NS — R²: -1.2272, RMSE: 0.0074, MAE: 0.0041
#
# ================= SBILIFE.NS - GARCH =================
#
# 🔮 Running GARCH for SBILIFE.NS...
#   → GARCH | index 500 | vol: 0.01493
#   → GARCH | index 750 | vol: 0.01243
#   → GARCH | index 1000 | vol: 0.01356
# ✅ GARCH for SBILIFE.NS — R²: 0.3573, RMSE: 0.0032, MAE: 0.0026
#
# ================= SBILIFE.NS - GJR =================
#
# 🔮 Running GJR for SBILIFE.NS...
#   → GJR | index 500 | vol: 0.01552
#   → GJR | index 750 | vol: 0.01247
#   → GJR | index 1000 | vol: 0.01388
# ✅ GJR for SBILIFE.NS — R²: 0.3092, RMSE: 0.0033, MAE: 0.0027
#
# ================= SBILIFE.NS - EGARCH =================
#
# 🔮 Running EGARCH for SBILIFE.NS...
#   → EGARCH | index 500 | vol: 0.01621
#   → EGARCH | index 750 | vol: 0.01243
#   → EGARCH | index 1000 | vol: 0.01363
# ✅ EGARCH for SBILIFE.NS — R²: 0.5022, RMSE: 0.0028, MAE: 0.0024
#
# ================= UTIAMC.NS - GARCH =================
#
# 🔮 Running GARCH for UTIAMC.NS...
# ⚠️ Skipping UTIAMC.NS - GARCH: Length of values (500) does not match length of index (260)
#
# ================= UTIAMC.NS - GJR =================
#
# 🔮 Running GJR for UTIAMC.NS...
# ⚠️ Skipping UTIAMC.NS - GJR: Length of values (500) does not match length of index (260)
#
# ================= UTIAMC.NS - EGARCH =================
#
# 🔮 Running EGARCH for UTIAMC.NS...
# ⚠️ Skipping UTIAMC.NS - EGARCH: Length of values (500) does not match length of index (260)
# 💾 Saved time series model results to India_ts_model_results.csv
#             Stock   Model            R2           RMSE            MSE  \
# 24   LICHSGFIN.NS   GARCH  8.003000e-01   4.200000e-03   1.800000e-05
# 12    AXISBANK.NS   GARCH  7.944000e-01   5.200000e-03   2.800000e-05
# 3    ICICIBANK.NS   GARCH  7.662000e-01   4.800000e-03   2.300000e-05
# 25   LICHSGFIN.NS     GJR  7.598000e-01   4.600000e-03   2.100000e-05
# 4    ICICIBANK.NS     GJR  7.145000e-01   5.300000e-03   2.800000e-05
# 18  INDUSINDBK.NS   GARCH  6.981000e-01   9.600000e-03   9.200000e-05
# 19  INDUSINDBK.NS     GJR  6.906000e-01   9.700000e-03   9.400000e-05
# 0     HDFCBANK.NS   GARCH  6.730000e-01   4.300000e-03   1.900000e-05
# 13    AXISBANK.NS     GJR  6.335000e-01   7.000000e-03   4.900000e-05
# 2     HDFCBANK.NS  EGARCH  6.276000e-01   4.600000e-03   2.100000e-05
# 1     HDFCBANK.NS     GJR  5.902000e-01   4.900000e-03   2.400000e-05
# 9    KOTAKBANK.NS   GARCH  5.702000e-01   5.200000e-03   2.700000e-05
# 32     SBILIFE.NS  EGARCH  5.022000e-01   2.800000e-03   8.000000e-06
# 10   KOTAKBANK.NS     GJR  4.921000e-01   5.700000e-03   3.200000e-05
# 30     SBILIFE.NS   GARCH  3.573000e-01   3.200000e-03   1.000000e-05
# 7         SBIN.NS     GJR  3.382000e-01   6.400000e-03   4.100000e-05
# 6         SBIN.NS   GARCH  3.347000e-01   6.400000e-03   4.100000e-05
# 31     SBILIFE.NS     GJR  3.092000e-01   3.300000e-03   1.100000e-05
# 8         SBIN.NS  EGARCH  3.033000e-01   6.600000e-03   4.300000e-05
# 21  BANDHANBNK.NS   GARCH  3.130000e-02   4.600000e-03   2.100000e-05
# 28    HDFCLIFE.NS     GJR -4.200000e-02   5.100000e-03   2.600000e-05
# 22  BANDHANBNK.NS     GJR -6.460000e-02   4.800000e-03   2.300000e-05
# 27    HDFCLIFE.NS   GARCH -1.147000e-01   5.300000e-03   2.800000e-05
# 16         PNB.NS     GJR -1.339000e-01   7.100000e-03   5.000000e-05
# 15         PNB.NS   GARCH -3.923000e-01   7.800000e-03   6.100000e-05
# 29    HDFCLIFE.NS  EGARCH -1.227200e+00   7.400000e-03   5.500000e-05
# 11   KOTAKBANK.NS  EGARCH -1.821600e+00   1.330000e-02   1.780000e-04
# 23  BANDHANBNK.NS  EGARCH -7.734200e+00   1.390000e-02   1.930000e-04
# 17         PNB.NS  EGARCH -9.030600e+00   2.100000e-02   4.400000e-04
# 5    ICICIBANK.NS  EGARCH -9.785400e+00   3.240000e-02   1.049000e-03
# 26   LICHSGFIN.NS  EGARCH -5.081180e+31   6.695868e+13   4.483464e+27
# 14    AXISBANK.NS  EGARCH -2.728991e+54   1.912164e+25   3.656372e+50
# 20  INDUSINDBK.NS  EGARCH          -inf  3.548082e+150  1.258889e+301
#
#               MAE
# 24   3.300000e-03
# 12   3.300000e-03
# 3    3.500000e-03
# 25   3.600000e-03
# 4    3.600000e-03
# 18   5.200000e-03
# 19   5.400000e-03
# 0    2.600000e-03
# 13   3.700000e-03
# 2    2.600000e-03
# 1    2.700000e-03
# 9    3.100000e-03
# 32   2.400000e-03
# 10   3.200000e-03
# 30   2.600000e-03
# 7    4.100000e-03
# 6    4.200000e-03
# 31   2.700000e-03
# 8    4.100000e-03
# 21   3.800000e-03
# 28   3.500000e-03
# 22   4.000000e-03
# 27   3.700000e-03
# 16   5.100000e-03
# 15   5.400000e-03
# 29   4.100000e-03
# 11   4.500000e-03
# 23   7.000000e-03
# 17   8.100000e-03
# 5    5.400000e-03
# 26   1.771914e+12
# 14   5.060123e+23
# 20  9.389221e+148

# %%
def train_fusion_model(df, model_name, ts_feature="GARCH_pred", ticker="TICKER"):
    from sklearn.model_selection import train_test_split
    from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
    from sklearn.neighbors import KNeighborsRegressor
    from catboost import CatBoostRegressor
    from lightgbm import LGBMRegressor
    from xgboost import XGBRegressor

    models = {
        "KNN": KNeighborsRegressor(),
        "AdaBoost": AdaBoostRegressor(),
        "CatBoost": CatBoostRegressor(verbose=0),
        "XGBoost": XGBRegressor(verbosity=0),
        "RandomForest": RandomForestRegressor()
    }

    if model_name not in models:
        raise ValueError(f"Model '{model_name}' not recognized.")

    df = df.copy()

    # Flatten if needed
    if isinstance(df.columns, pd.MultiIndex):
        df.columns = ['_'.join([str(i) for i in col if i]) for col in df.columns]

    if ts_feature not in df.columns:
        raise ValueError(f"'{ts_feature}' not found in DataFrame for {ticker}")

    feature_cols = [
        'RSI', 'MOM', 'OBV', 'MACD_LINE', 'MACD_SIGNAL', 'MACD_HIST',
        'STO_K', 'STO_D', 'Vol_t_1', 'Vol_t_2', 'Vol_t_3',
        'Vol_t_4', 'Vol_t_5', 'Vol_t_6', ts_feature
    ]

    X = df[feature_cols].copy()
    y = df["Vol_target"]

    split_idx = int(len(df) * 0.7)
    X_train, X_test = X.iloc[:split_idx], X.iloc[split_idx:]
    y_train, y_test = y.iloc[:split_idx], y.iloc[split_idx:]

    model = models[model_name]
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    metrics = evaluate_series(y_test, y_pred)

    print(f"✅ {model_name} + {ts_feature} for {ticker} — R²: {metrics['R2']:.4f}, RMSE: {metrics['RMSE']:.4f}, MAE: {metrics['MAE']:.4f}")

    return metrics

# %%
import os
import pandas as pd

# Reuse existing forecast function
for ticker in tqdm(garch_data.keys()):
    for model_type in ["GJR", "EGARCH"]:
        print(f"\n📈 Adding {model_type}_pred to {ticker}...")
        df = garch_data[ticker]

        try:
            df, _ = forecast_volatility_arch(df, model_type=model_type, ticker=ticker, verbose=False)
            garch_data[ticker] = df  # Update with new column
        except Exception as e:
            print(f"⚠️ {model_type} failed for {ticker}: {e}")

def train_all_fusion_models(garch_data_dict, results_path="India_fusion_model_results.csv"):
    # Load existing results if file exists
    if os.path.exists(results_path):
        print(f"📦 Loading saved fusion model results from {results_path}...")
        return pd.read_csv(results_path)

    results = []

    for ticker, df in garch_data_dict.items():
        for ts_feature in ["GARCH_pred", "GJR_pred", "EGARCH_pred"]:
            if ts_feature not in df.columns:
                print(f"⚠️ Skipping {ticker} - missing {ts_feature}")
                continue

            for model_name in ["RandomForest", "XGBoost", "CatBoost", "AdaBoost", "KNN"]:
                try:
                    metrics = train_fusion_model(df, model_name, ts_feature=ts_feature, ticker=ticker)
                    results.append({
                        "Stock": ticker,
                        "Fusion_Model": f"{ts_feature}+{model_name}",
                        "R2": round(metrics["R2"], 4),
                        "RMSE": round(metrics["RMSE"], 4),
                        "MSE": round(metrics["MSE"], 6),
                        "MAE": round(metrics["MAE"], 4),
                    })
                except Exception as e:
                    print(f"⚠️ {ticker} {ts_feature}+{model_name} failed: {e}")

    fusion_df = pd.DataFrame(results)
    fusion_df.to_csv(results_path, index=False)
    print(f"💾 Saved fusion model results to {results_path}")

    return fusion_df

fusion_results_df = train_all_fusion_models(garch_data)
fusion_results_sorted = fusion_results_df.sort_values(by="R2", ascending=False)
display(fusion_results_sorted)
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
# 📈 Adding GJR_pred to HDFCBANK.NS...
#
# 📈 Adding EGARCH_pred to HDFCBANK.NS...
#   8%|▊         | 1/12 [00:33<06:05, 33.27s/it]
# 📈 Adding GJR_pred to ICICIBANK.NS...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# 📈 Adding EGARCH_pred to ICICIBANK.NS...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  17%|█▋        | 2/12 [01:10<05:58, 35.83s/it]
# 📈 Adding GJR_pred to SBIN.NS...
#
# 📈 Adding EGARCH_pred to SBIN.NS...
#  25%|██▌       | 3/12 [01:47<05:24, 36.01s/it]
# 📈 Adding GJR_pred to KOTAKBANK.NS...
#
# 📈 Adding EGARCH_pred to KOTAKBANK.NS...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  33%|███▎      | 4/12 [02:24<04:52, 36.55s/it]
# 📈 Adding GJR_pred to AXISBANK.NS...
#
# 📈 Adding EGARCH_pred to AXISBANK.NS...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  42%|████▏     | 5/12 [03:00<04:14, 36.34s/it]
# 📈 Adding GJR_pred to PNB.NS...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# 📈 Adding EGARCH_pred to PNB.NS...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  50%|█████     | 6/12 [03:38<03:42, 37.08s/it]
# 📈 Adding GJR_pred to INDUSINDBK.NS...
#
# 📈 Adding EGARCH_pred to INDUSINDBK.NS...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  58%|█████▊    | 7/12 [04:13<03:01, 36.39s/it]
# 📈 Adding GJR_pred to BANDHANBNK.NS...
#  67%|██████▋   | 8/12 [04:21<01:48, 27.15s/it]
# 📈 Adding EGARCH_pred to BANDHANBNK.NS...
# ⚠️ EGARCH failed for BANDHANBNK.NS: Length of values (500) does not match length of index (386)
#
# 📈 Adding GJR_pred to LICHSGFIN.NS...
# /shared/home/ads066/.local/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# 📈 Adding EGARCH_pred to LICHSGFIN.NS...
#  75%|███████▌  | 9/12 [04:57<01:30, 30.02s/it]
# 📈 Adding GJR_pred to HDFCLIFE.NS...
#  83%|████████▎ | 10/12 [05:06<00:47, 23.63s/it]
# 📈 Adding EGARCH_pred to HDFCLIFE.NS...
# ⚠️ EGARCH failed for HDFCLIFE.NS: Length of values (500) does not match length of index (474)
#
# 📈 Adding GJR_pred to SBILIFE.NS...
# 100%|██████████| 12/12 [05:16<00:00, 26.34s/it]
# 📈 Adding EGARCH_pred to SBILIFE.NS...
#
# 📈 Adding GJR_pred to UTIAMC.NS...
# ⚠️ GJR failed for UTIAMC.NS: Length of values (500) does not match length of index (260)
#
# 📈 Adding EGARCH_pred to UTIAMC.NS...
# ⚠️ EGARCH failed for UTIAMC.NS: Length of values (500) does not match length of index (260)
# ✅ RandomForest + GARCH_pred for HDFCBANK.NS — R²: 0.6636, RMSE: 0.0012, MAE: 0.0008
# ✅ XGBoost + GARCH_pred for HDFCBANK.NS — R²: 0.6274, RMSE: 0.0013, MAE: 0.0009
# ✅ CatBoost + GARCH_pred for HDFCBANK.NS — R²: 0.2466, RMSE: 0.0019, MAE: 0.0014
# ✅ AdaBoost + GARCH_pred for HDFCBANK.NS — R²: 0.3336, RMSE: 0.0017, MAE: 0.0013
# ✅ KNN + GARCH_pred for HDFCBANK.NS — R²: -17.7165, RMSE: 0.0092, MAE: 0.0084
# ✅ RandomForest + GJR_pred for HDFCBANK.NS — R²: 0.6727, RMSE: 0.0012, MAE: 0.0008
# ✅ XGBoost + GJR_pred for HDFCBANK.NS — R²: 0.4746, RMSE: 0.0015, MAE: 0.0012
# ✅ CatBoost + GJR_pred for HDFCBANK.NS — R²: 0.1597, RMSE: 0.0020, MAE: 0.0016
# ✅ AdaBoost + GJR_pred for HDFCBANK.NS — R²: 0.2206, RMSE: 0.0019, MAE: 0.0014
# ✅ KNN + GJR_pred for HDFCBANK.NS — R²: -17.7165, RMSE: 0.0092, MAE: 0.0084
# ✅ RandomForest + EGARCH_pred for HDFCBANK.NS — R²: 0.6931, RMSE: 0.0012, MAE: 0.0008
# ✅ XGBoost + EGARCH_pred for HDFCBANK.NS — R²: 0.5596, RMSE: 0.0014, MAE: 0.0010
# ✅ CatBoost + EGARCH_pred for HDFCBANK.NS — R²: 0.4447, RMSE: 0.0016, MAE: 0.0012
# ✅ AdaBoost + EGARCH_pred for HDFCBANK.NS — R²: 0.3574, RMSE: 0.0017, MAE: 0.0012
# ✅ KNN + EGARCH_pred for HDFCBANK.NS — R²: -17.7165, RMSE: 0.0092, MAE: 0.0084
# ✅ RandomForest + GARCH_pred for ICICIBANK.NS — R²: -0.7053, RMSE: 0.0026, MAE: 0.0022
# ✅ XGBoost + GARCH_pred for ICICIBANK.NS — R²: -1.3631, RMSE: 0.0031, MAE: 0.0026
# ✅ CatBoost + GARCH_pred for ICICIBANK.NS — R²: -2.1615, RMSE: 0.0035, MAE: 0.0031
# ✅ AdaBoost + GARCH_pred for ICICIBANK.NS — R²: -4.2685, RMSE: 0.0046, MAE: 0.0043
# ✅ KNN + GARCH_pred for ICICIBANK.NS — R²: -2.6543, RMSE: 0.0038, MAE: 0.0034
# ✅ RandomForest + GJR_pred for ICICIBANK.NS — R²: -0.6269, RMSE: 0.0025, MAE: 0.0022
# ✅ XGBoost + GJR_pred for ICICIBANK.NS — R²: -1.3584, RMSE: 0.0031, MAE: 0.0026
# ✅ CatBoost + GJR_pred for ICICIBANK.NS — R²: -1.5713, RMSE: 0.0032, MAE: 0.0028
# ✅ AdaBoost + GJR_pred for ICICIBANK.NS — R²: -7.1132, RMSE: 0.0057, MAE: 0.0053
# ✅ KNN + GJR_pred for ICICIBANK.NS — R²: -2.6543, RMSE: 0.0038, MAE: 0.0034
# ✅ RandomForest + EGARCH_pred for ICICIBANK.NS — R²: -0.6831, RMSE: 0.0026, MAE: 0.0022
# ✅ XGBoost + EGARCH_pred for ICICIBANK.NS — R²: -1.2213, RMSE: 0.0030, MAE: 0.0025
# ✅ CatBoost + EGARCH_pred for ICICIBANK.NS — R²: -2.2800, RMSE: 0.0036, MAE: 0.0031
# ✅ AdaBoost + EGARCH_pred for ICICIBANK.NS — R²: -4.0641, RMSE: 0.0045, MAE: 0.0041
# ✅ KNN + EGARCH_pred for ICICIBANK.NS — R²: -2.6543, RMSE: 0.0038, MAE: 0.0034
# ✅ RandomForest + GARCH_pred for SBIN.NS — R²: 0.7398, RMSE: 0.0016, MAE: 0.0012
# ✅ XGBoost + GARCH_pred for SBIN.NS — R²: 0.5056, RMSE: 0.0022, MAE: 0.0018
# ✅ CatBoost + GARCH_pred for SBIN.NS — R²: 0.4416, RMSE: 0.0023, MAE: 0.0020
# ✅ AdaBoost + GARCH_pred for SBIN.NS — R²: 0.4649, RMSE: 0.0023, MAE: 0.0018
# ✅ KNN + GARCH_pred for SBIN.NS — R²: -1.4428, RMSE: 0.0049, MAE: 0.0044
# ✅ RandomForest + GJR_pred for SBIN.NS — R²: 0.7319, RMSE: 0.0016, MAE: 0.0012
# ✅ XGBoost + GJR_pred for SBIN.NS — R²: 0.5146, RMSE: 0.0022, MAE: 0.0017
# ✅ CatBoost + GJR_pred for SBIN.NS — R²: 0.4606, RMSE: 0.0023, MAE: 0.0020
# ✅ AdaBoost + GJR_pred for SBIN.NS — R²: 0.4799, RMSE: 0.0023, MAE: 0.0018
# ✅ KNN + GJR_pred for SBIN.NS — R²: -1.4428, RMSE: 0.0049, MAE: 0.0044
# ✅ RandomForest + EGARCH_pred for SBIN.NS — R²: 0.7657, RMSE: 0.0015, MAE: 0.0011
# ✅ XGBoost + EGARCH_pred for SBIN.NS — R²: 0.5475, RMSE: 0.0021, MAE: 0.0017
# ✅ CatBoost + EGARCH_pred for SBIN.NS — R²: 0.5160, RMSE: 0.0022, MAE: 0.0018
# ✅ AdaBoost + EGARCH_pred for SBIN.NS — R²: 0.4187, RMSE: 0.0024, MAE: 0.0019
# ✅ KNN + EGARCH_pred for SBIN.NS — R²: -1.4428, RMSE: 0.0049, MAE: 0.0044
# ✅ RandomForest + GARCH_pred for KOTAKBANK.NS — R²: 0.5138, RMSE: 0.0013, MAE: 0.0009
# ✅ XGBoost + GARCH_pred for KOTAKBANK.NS — R²: 0.5087, RMSE: 0.0013, MAE: 0.0009
# ✅ CatBoost + GARCH_pred for KOTAKBANK.NS — R²: 0.1489, RMSE: 0.0017, MAE: 0.0013
# ✅ AdaBoost + GARCH_pred for KOTAKBANK.NS — R²: -0.1380, RMSE: 0.0019, MAE: 0.0016
# ✅ KNN + GARCH_pred for KOTAKBANK.NS — R²: -13.7676, RMSE: 0.0070, MAE: 0.0065
# ✅ RandomForest + GJR_pred for KOTAKBANK.NS — R²: 0.5432, RMSE: 0.0012, MAE: 0.0009
# ✅ XGBoost + GJR_pred for KOTAKBANK.NS — R²: 0.3894, RMSE: 0.0014, MAE: 0.0011
# ✅ CatBoost + GJR_pred for KOTAKBANK.NS — R²: 0.1033, RMSE: 0.0017, MAE: 0.0014
# ✅ AdaBoost + GJR_pred for KOTAKBANK.NS — R²: -0.3544, RMSE: 0.0021, MAE: 0.0018
# ✅ KNN + GJR_pred for KOTAKBANK.NS — R²: -13.7676, RMSE: 0.0070, MAE: 0.0065
# ✅ RandomForest + EGARCH_pred for KOTAKBANK.NS — R²: 0.4845, RMSE: 0.0013, MAE: 0.0010
# ✅ XGBoost + EGARCH_pred for KOTAKBANK.NS — R²: 0.2325, RMSE: 0.0016, MAE: 0.0013
# ✅ CatBoost + EGARCH_pred for KOTAKBANK.NS — R²: -0.3367, RMSE: 0.0021, MAE: 0.0016
# ✅ AdaBoost + EGARCH_pred for KOTAKBANK.NS — R²: -0.3049, RMSE: 0.0021, MAE: 0.0018
# ✅ KNN + EGARCH_pred for KOTAKBANK.NS — R²: -13.7676, RMSE: 0.0070, MAE: 0.0065
# ✅ RandomForest + GARCH_pred for AXISBANK.NS — R²: 0.3154, RMSE: 0.0022, MAE: 0.0018
# ✅ XGBoost + GARCH_pred for AXISBANK.NS — R²: 0.1220, RMSE: 0.0025, MAE: 0.0020
# ✅ CatBoost + GARCH_pred for AXISBANK.NS — R²: -0.0992, RMSE: 0.0028, MAE: 0.0024
# ✅ AdaBoost + GARCH_pred for AXISBANK.NS — R²: -0.7470, RMSE: 0.0036, MAE: 0.0032
# ✅ KNN + GARCH_pred for AXISBANK.NS — R²: -17.7653, RMSE: 0.0117, MAE: 0.0114
# ✅ RandomForest + GJR_pred for AXISBANK.NS — R²: 0.3692, RMSE: 0.0021, MAE: 0.0017
# ✅ XGBoost + GJR_pred for AXISBANK.NS — R²: 0.3689, RMSE: 0.0021, MAE: 0.0017
# ✅ CatBoost + GJR_pred for AXISBANK.NS — R²: -0.5273, RMSE: 0.0033, MAE: 0.0029
# ✅ AdaBoost + GJR_pred for AXISBANK.NS — R²: -0.6792, RMSE: 0.0035, MAE: 0.0031
# ✅ KNN + GJR_pred for AXISBANK.NS — R²: -17.7653, RMSE: 0.0117, MAE: 0.0114
# ✅ RandomForest + EGARCH_pred for AXISBANK.NS — R²: 0.3576, RMSE: 0.0022, MAE: 0.0017
# ✅ XGBoost + EGARCH_pred for AXISBANK.NS — R²: 0.3481, RMSE: 0.0022, MAE: 0.0018
# ✅ CatBoost + EGARCH_pred for AXISBANK.NS — R²: -0.0610, RMSE: 0.0028, MAE: 0.0024
# ✅ AdaBoost + EGARCH_pred for AXISBANK.NS — R²: -0.5844, RMSE: 0.0034, MAE: 0.0030
# ✅ KNN + EGARCH_pred for AXISBANK.NS — R²: -17.7653, RMSE: 0.0117, MAE: 0.0114
# ✅ RandomForest + GARCH_pred for PNB.NS — R²: 0.8238, RMSE: 0.0022, MAE: 0.0018
# ✅ XGBoost + GARCH_pred for PNB.NS — R²: 0.6949, RMSE: 0.0029, MAE: 0.0024
# ✅ CatBoost + GARCH_pred for PNB.NS — R²: 0.6660, RMSE: 0.0030, MAE: 0.0025
# ✅ AdaBoost + GARCH_pred for PNB.NS — R²: 0.7477, RMSE: 0.0026, MAE: 0.0022
# ✅ KNN + GARCH_pred for PNB.NS — R²: -2.3638, RMSE: 0.0097, MAE: 0.0082
# ✅ RandomForest + GJR_pred for PNB.NS — R²: 0.7594, RMSE: 0.0026, MAE: 0.0020
# ✅ XGBoost + GJR_pred for PNB.NS — R²: 0.6605, RMSE: 0.0031, MAE: 0.0023
# ✅ CatBoost + GJR_pred for PNB.NS — R²: 0.7327, RMSE: 0.0027, MAE: 0.0022
# ✅ AdaBoost + GJR_pred for PNB.NS — R²: 0.6899, RMSE: 0.0029, MAE: 0.0024
# ✅ KNN + GJR_pred for PNB.NS — R²: -2.3638, RMSE: 0.0097, MAE: 0.0082
# ✅ RandomForest + EGARCH_pred for PNB.NS — R²: 0.8426, RMSE: 0.0021, MAE: 0.0017
# ✅ XGBoost + EGARCH_pred for PNB.NS — R²: 0.7213, RMSE: 0.0028, MAE: 0.0022
# ✅ CatBoost + EGARCH_pred for PNB.NS — R²: 0.6717, RMSE: 0.0030, MAE: 0.0025
# ✅ AdaBoost + EGARCH_pred for PNB.NS — R²: 0.7554, RMSE: 0.0026, MAE: 0.0021
# ✅ KNN + EGARCH_pred for PNB.NS — R²: -2.3638, RMSE: 0.0097, MAE: 0.0082
# ✅ RandomForest + GARCH_pred for INDUSINDBK.NS — R²: 0.8307, RMSE: 0.0014, MAE: 0.0010
# ✅ XGBoost + GARCH_pred for INDUSINDBK.NS — R²: 0.7376, RMSE: 0.0017, MAE: 0.0012
# ✅ CatBoost + GARCH_pred for INDUSINDBK.NS — R²: 0.7004, RMSE: 0.0018, MAE: 0.0013
# ✅ AdaBoost + GARCH_pred for INDUSINDBK.NS — R²: 0.4344, RMSE: 0.0025, MAE: 0.0021
# ✅ KNN + GARCH_pred for INDUSINDBK.NS — R²: -2.8554, RMSE: 0.0065, MAE: 0.0059
# ✅ RandomForest + GJR_pred for INDUSINDBK.NS — R²: 0.8208, RMSE: 0.0014, MAE: 0.0010
# ✅ XGBoost + GJR_pred for INDUSINDBK.NS — R²: 0.7505, RMSE: 0.0017, MAE: 0.0012
# ✅ CatBoost + GJR_pred for INDUSINDBK.NS — R²: 0.7180, RMSE: 0.0018, MAE: 0.0013
# ✅ AdaBoost + GJR_pred for INDUSINDBK.NS — R²: 0.1111, RMSE: 0.0031, MAE: 0.0025
# ✅ KNN + GJR_pred for INDUSINDBK.NS — R²: -2.8554, RMSE: 0.0065, MAE: 0.0059
# ⚠️ INDUSINDBK.NS EGARCH_pred+RandomForest failed: Input X contains infinity or a value too large for dtype('float32').
# ✅ XGBoost + EGARCH_pred for INDUSINDBK.NS — R²: 0.7250, RMSE: 0.0017, MAE: 0.0013
# ✅ CatBoost + EGARCH_pred for INDUSINDBK.NS — R²: 0.5232, RMSE: 0.0023, MAE: 0.0015
# ⚠️ INDUSINDBK.NS EGARCH_pred+AdaBoost failed: Input X contains infinity or a value too large for dtype('float32').
# ✅ KNN + EGARCH_pred for INDUSINDBK.NS — R²: -5.9866, RMSE: 0.0087, MAE: 0.0062
# ✅ RandomForest + GARCH_pred for BANDHANBNK.NS — R²: 0.1376, RMSE: 0.0020, MAE: 0.0015
# ✅ XGBoost + GARCH_pred for BANDHANBNK.NS — R²: 0.1847, RMSE: 0.0019, MAE: 0.0015
# ✅ CatBoost + GARCH_pred for BANDHANBNK.NS — R²: -0.0656, RMSE: 0.0022, MAE: 0.0017
# ✅ AdaBoost + GARCH_pred for BANDHANBNK.NS — R²: -0.3898, RMSE: 0.0025, MAE: 0.0020
# ✅ KNN + GARCH_pred for BANDHANBNK.NS — R²: -2.0553, RMSE: 0.0037, MAE: 0.0030
# ✅ RandomForest + GJR_pred for BANDHANBNK.NS — R²: 0.1022, RMSE: 0.0020, MAE: 0.0016
# ✅ XGBoost + GJR_pred for BANDHANBNK.NS — R²: 0.0038, RMSE: 0.0021, MAE: 0.0017
# ✅ CatBoost + GJR_pred for BANDHANBNK.NS — R²: -0.1030, RMSE: 0.0022, MAE: 0.0017
# ✅ AdaBoost + GJR_pred for BANDHANBNK.NS — R²: -0.3134, RMSE: 0.0024, MAE: 0.0019
# ✅ KNN + GJR_pred for BANDHANBNK.NS — R²: -2.0553, RMSE: 0.0037, MAE: 0.0030
# ⚠️ Skipping BANDHANBNK.NS - missing EGARCH_pred
# ✅ RandomForest + GARCH_pred for LICHSGFIN.NS — R²: 0.5926, RMSE: 0.0019, MAE: 0.0014
# ✅ XGBoost + GARCH_pred for LICHSGFIN.NS — R²: 0.5435, RMSE: 0.0020, MAE: 0.0015
# ✅ CatBoost + GARCH_pred for LICHSGFIN.NS — R²: 0.6743, RMSE: 0.0017, MAE: 0.0012
# ✅ AdaBoost + GARCH_pred for LICHSGFIN.NS — R²: 0.3039, RMSE: 0.0025, MAE: 0.0019
# ✅ KNN + GARCH_pred for LICHSGFIN.NS — R²: -1.5667, RMSE: 0.0049, MAE: 0.0039
# ✅ RandomForest + GJR_pred for LICHSGFIN.NS — R²: 0.6819, RMSE: 0.0017, MAE: 0.0012
# ✅ XGBoost + GJR_pred for LICHSGFIN.NS — R²: 0.6801, RMSE: 0.0017, MAE: 0.0012
# ✅ CatBoost + GJR_pred for LICHSGFIN.NS — R²: 0.6769, RMSE: 0.0017, MAE: 0.0013
# ✅ AdaBoost + GJR_pred for LICHSGFIN.NS — R²: 0.3851, RMSE: 0.0024, MAE: 0.0020
# ✅ KNN + GJR_pred for LICHSGFIN.NS — R²: -1.5667, RMSE: 0.0049, MAE: 0.0039
# ✅ RandomForest + EGARCH_pred for LICHSGFIN.NS — R²: 0.6562, RMSE: 0.0018, MAE: 0.0013
# ✅ XGBoost + EGARCH_pred for LICHSGFIN.NS — R²: 0.6937, RMSE: 0.0017, MAE: 0.0012
# ✅ CatBoost + EGARCH_pred for LICHSGFIN.NS — R²: 0.6796, RMSE: 0.0017, MAE: 0.0012
# ✅ AdaBoost + EGARCH_pred for LICHSGFIN.NS — R²: 0.5729, RMSE: 0.0020, MAE: 0.0016
# ✅ KNN + EGARCH_pred for LICHSGFIN.NS — R²: -1.5667, RMSE: 0.0049, MAE: 0.0039
# ✅ RandomForest + GARCH_pred for HDFCLIFE.NS — R²: 0.7283, RMSE: 0.0020, MAE: 0.0015
# ✅ XGBoost + GARCH_pred for HDFCLIFE.NS — R²: 0.6921, RMSE: 0.0021, MAE: 0.0016
# ✅ CatBoost + GARCH_pred for HDFCLIFE.NS — R²: 0.6090, RMSE: 0.0024, MAE: 0.0018
# ✅ AdaBoost + GARCH_pred for HDFCLIFE.NS — R²: 0.7052, RMSE: 0.0021, MAE: 0.0016
# ✅ KNN + GARCH_pred for HDFCLIFE.NS — R²: -0.0968, RMSE: 0.0040, MAE: 0.0036
# ✅ RandomForest + GJR_pred for HDFCLIFE.NS — R²: 0.7517, RMSE: 0.0019, MAE: 0.0015
# ✅ XGBoost + GJR_pred for HDFCLIFE.NS — R²: 0.7105, RMSE: 0.0020, MAE: 0.0016
# ✅ CatBoost + GJR_pred for HDFCLIFE.NS — R²: 0.6837, RMSE: 0.0021, MAE: 0.0016
# ✅ AdaBoost + GJR_pred for HDFCLIFE.NS — R²: 0.7156, RMSE: 0.0020, MAE: 0.0015
# ✅ KNN + GJR_pred for HDFCLIFE.NS — R²: -0.0968, RMSE: 0.0040, MAE: 0.0036
# ⚠️ Skipping HDFCLIFE.NS - missing EGARCH_pred
# ✅ RandomForest + GARCH_pred for SBILIFE.NS — R²: -5.6471, RMSE: 0.0006, MAE: 0.0005
# ✅ XGBoost + GARCH_pred for SBILIFE.NS — R²: -4.3481, RMSE: 0.0005, MAE: 0.0005
# ✅ CatBoost + GARCH_pred for SBILIFE.NS — R²: -7.0382, RMSE: 0.0006, MAE: 0.0006
# ✅ AdaBoost + GARCH_pred for SBILIFE.NS — R²: -11.1070, RMSE: 0.0008, MAE: 0.0008
# ⚠️ SBILIFE.NS GARCH_pred+KNN failed: Expected n_neighbors <= n_samples_fit, but n_neighbors = 5, n_samples_fit = 4, n_samples = 2
# ✅ RandomForest + GJR_pred for SBILIFE.NS — R²: -6.9578, RMSE: 0.0006, MAE: 0.0006
# ✅ XGBoost + GJR_pred for SBILIFE.NS — R²: -4.3481, RMSE: 0.0005, MAE: 0.0005
# ✅ CatBoost + GJR_pred for SBILIFE.NS — R²: -7.4795, RMSE: 0.0007, MAE: 0.0006
# ✅ AdaBoost + GJR_pred for SBILIFE.NS — R²: -11.1070, RMSE: 0.0008, MAE: 0.0008
# ⚠️ SBILIFE.NS GJR_pred+KNN failed: Expected n_neighbors <= n_samples_fit, but n_neighbors = 5, n_samples_fit = 4, n_samples = 2
# ✅ RandomForest + EGARCH_pred for SBILIFE.NS — R²: -5.9246, RMSE: 0.0006, MAE: 0.0006
# ✅ XGBoost + EGARCH_pred for SBILIFE.NS — R²: -4.3481, RMSE: 0.0005, MAE: 0.0005
# ✅ CatBoost + EGARCH_pred for SBILIFE.NS — R²: -7.1947, RMSE: 0.0006, MAE: 0.0006
# ✅ AdaBoost + EGARCH_pred for SBILIFE.NS — R²: -11.1070, RMSE: 0.0008, MAE: 0.0008
# ⚠️ SBILIFE.NS EGARCH_pred+KNN failed: Expected n_neighbors <= n_samples_fit, but n_neighbors = 5, n_samples_fit = 4, n_samples = 2
# ✅ RandomForest + GARCH_pred for UTIAMC.NS — R²: 0.1269, RMSE: 0.0017, MAE: 0.0013
# ✅ XGBoost + GARCH_pred for UTIAMC.NS — R²: -0.2196, RMSE: 0.0020, MAE: 0.0016
# ✅ CatBoost + GARCH_pred for UTIAMC.NS — R²: 0.2765, RMSE: 0.0015, MAE: 0.0010
# ✅ AdaBoost + GARCH_pred for UTIAMC.NS — R²: 0.3004, RMSE: 0.0015, MAE: 0.0011
# ✅ KNN + GARCH_pred for UTIAMC.NS — R²: -19.0613, RMSE: 0.0081, MAE: 0.0079
# ⚠️ Skipping UTIAMC.NS - missing GJR_pred
# ⚠️ Skipping UTIAMC.NS - missing EGARCH_pred
# 💾 Saved fusion model results to India_fusion_model_results.csv
#              Stock              Fusion_Model       R2    RMSE       MSE  \
# 85          PNB.NS  EGARCH_pred+RandomForest   0.8426  0.0021  0.000004
# 90   INDUSINDBK.NS   GARCH_pred+RandomForest   0.8307  0.0014  0.000002
# 75          PNB.NS   GARCH_pred+RandomForest   0.8238  0.0022  0.000005
# 95   INDUSINDBK.NS     GJR_pred+RandomForest   0.8208  0.0014  0.000002
# 40         SBIN.NS  EGARCH_pred+RandomForest   0.7657  0.0015  0.000002
# ..             ...                       ...      ...     ...       ...
# 9      HDFCBANK.NS              GJR_pred+KNN -17.7165  0.0092  0.000085
# 69     AXISBANK.NS              GJR_pred+KNN -17.7653  0.0117  0.000137
# 64     AXISBANK.NS            GARCH_pred+KNN -17.7653  0.0117  0.000137
# 74     AXISBANK.NS           EGARCH_pred+KNN -17.7653  0.0117  0.000137
# 154      UTIAMC.NS            GARCH_pred+KNN -19.0613  0.0081  0.000065
#
#         MAE
# 85   0.0017
# 90   0.0010
# 75   0.0018
# 95   0.0010
# 40   0.0011
# ..      ...
# 9    0.0084
# 69   0.0114
# 64   0.0114
# 74   0.0114
# 154  0.0079
#
# [155 rows x 6 columns]
